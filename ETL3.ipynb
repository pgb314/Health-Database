# %%
import pandas as pd
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import numpy as np
import csv
import multiprocessing as mp
from selenium import webdriver
import requests as req
from bs4 import BeautifulSoup as bs

# %%
import time   # para manejar tiempo

from selenium.webdriver.chrome.options import Options

from selenium.webdriver.common.by import By   # para buscar segun tag, id, class, etc...

from selenium.webdriver.support.ui import WebDriverWait   # es para esperar

from selenium.webdriver.support import expected_conditions as EC  # condiciones esperadas...

from selenium.webdriver import ActionChains as AC   # acciones encadenadas, rollo doble click

from selenium.webdriver.common.keys import Keys  # manejar teclas


import warnings
warnings.filterwarnings('ignore')

# %%
path = r'C:\Users\pabli\apuntes_de_clase\Proyecto-ETL\data\cause_of_deaths.csv'
data_kaggle = pd.read_csv(path)

# %%
data_kaggle.drop(columns= "Unnamed: 0",inplace = True)

# %%
data_kaggle
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...

# %%
all = pd.read_csv(r'C:\Users\pabli\apuntes_de_clase\Proyecto-ETL\data\lsta_all.csv')

# %%
all[all.country=="Afghanistan"]
# Out:
#       Unnamed: 0  rank      country  population  year
# 0              0  46.0  Afghanistan    22461348  2000
# 228            0  46.0  Afghanistan    22507460  2001
# 456            0  45.0  Afghanistan    23600088  2002
# 684            0  42.0  Afghanistan    25005388  2003
# 912            0  42.0  Afghanistan    25697636  2004
# 1140           0  42.0  Afghanistan    26334702  2005
# 1368           0  41.0  Afghanistan    27154386  2006
# 1596           0  42.0  Afghanistan    27387084  2007
# 1824           0  42.0  Afghanistan    27705724  2008
# 2052           0  42.0  Afghanistan    28483632  2009
# 2280           0  40.0  Afghanistan    29120728  2010
# 2508           0  40.0  Afghanistan    29757566  2011
# 2736           0  40.0  Afghanistan    30419928  2012
# 2964           0  40.0  Afghanistan    31108076  2013
# 3192           0  40.0  Afghanistan    31822848  2014
# 3420           0  40.0  Afghanistan    32564342  2015
# ...

# %%
all_sort=all.sort_values(by=["country","year"])

# %%
all_sort.head()
# Out:
#      Unnamed: 0  rank      country  population  year
# 0             0  46.0  Afghanistan    22461348  2000
# 228           0  46.0  Afghanistan    22507460  2001
# 456           0  45.0  Afghanistan    23600088  2002
# 684           0  42.0  Afghanistan    25005388  2003
# 912           0  42.0  Afghanistan    25697636  2004

# %%
all_sort.reset_index(inplace=True)

# %%
for i in range(19,len(all_sort.year),20):
    all_sort.year[i]= 2019

# %%
all_sort.head(20)
# Out:
#     index  Unnamed: 0  rank      country  population  year
# 0       0           0  46.0  Afghanistan    22461348  2000
# 1     228           0  46.0  Afghanistan    22507460  2001
# 2     456           0  45.0  Afghanistan    23600088  2002
# 3     684           0  42.0  Afghanistan    25005388  2003
# 4     912           0  42.0  Afghanistan    25697636  2004
# 5    1140           0  42.0  Afghanistan    26334702  2005
# 6    1368           0  41.0  Afghanistan    27154386  2006
# 7    1596           0  42.0  Afghanistan    27387084  2007
# 8    1824           0  42.0  Afghanistan    27705724  2008
# 9    2052           0  42.0  Afghanistan    28483632  2009
# 10   2280           0  40.0  Afghanistan    29120728  2010
# 11   2508           0  40.0  Afghanistan    29757566  2011
# 12   2736           0  40.0  Afghanistan    30419928  2012
# 13   2964           0  40.0  Afghanistan    31108076  2013
# 14   3192           0  40.0  Afghanistan    31822848  2014
# ...

# %%
all_sort.drop(columns=["index","Unnamed: 0","rank"],inplace=True)

# %%
all_sort.head(40)
# Out:
#         country  population  year
# 0   Afghanistan    22461348  2000
# 1   Afghanistan    22507460  2001
# 2   Afghanistan    23600088  2002
# 3   Afghanistan    25005388  2003
# 4   Afghanistan    25697636  2004
# 5   Afghanistan    26334702  2005
# 6   Afghanistan    27154386  2006
# 7   Afghanistan    27387084  2007
# 8   Afghanistan    27705724  2008
# 9   Afghanistan    28483632  2009
# 10  Afghanistan    29120728  2010
# 11  Afghanistan    29757566  2011
# 12  Afghanistan    30419928  2012
# 13  Afghanistan    31108076  2013
# 14  Afghanistan    31822848  2014
# 15  Afghanistan    32564342  2015
# 16  Afghanistan    33332024  2016
# 17  Afghanistan    34124812  2017
# 18  Afghanistan    34124812  2018
# 19  Afghanistan    35780456  2019
# 20      Albania     3158352  2000
# 21      Albania     3128002  2001
# 22      Albania     3098028  2002
# 23      Albania     3069665  2003
# 24      Albania     3045640  2004
# 25      Albania     3024533  2005
# ...

# %%
all_sort[all_sort.country == "Turkey"]
# Out:
#      country  population  year
# 4140  Turkey    67329296  2000
# 4141  Turkey    68404904  2001
# 4142  Turkey    69479040  2002
# 4143  Turkey    70548632  2003
# 4144  Turkey    71613544  2004
# 4145  Turkey    72673808  2005
# 4146  Turkey    73726128  2006
# 4147  Turkey    74767840  2007
# 4148  Turkey    75793840  2008
# 4149  Turkey    76805520  2009
# 4150  Turkey    77804120  2010
# 4151  Turkey    78785552  2011
# 4152  Turkey    79749464  2012
# 4153  Turkey    80694488  2013
# 4154  Turkey    81619392  2014
# 4155  Turkey    82523056  2015
# 4156  Turkey    83407064  2016
# 4157  Turkey    84273192  2017
# 4158  Turkey    84273192  2018
# 4159  Turkey    85948784  2019

# %%
data_kaggle[data_kaggle.Code=="USA"]
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 5820     United States  USA  1990        1830
# 5821     United States  USA  1991        1615
# 5822     United States  USA  1992        1558
# 5823     United States  USA  1993        1550
# 5824     United States  USA  1994        1530
# 5825     United States  USA  1995        1514
# 5826     United States  USA  1996        1504
# 5827     United States  USA  1997        1514
# 5828     United States  USA  1998        1517
# 5829     United States  USA  1999        1566
# 5830     United States  USA  2000        1458
# 5831     United States  USA  2001        1399
# 5832     United States  USA  2002        1367
# 5833     United States  USA  2003        1344
# 5834     United States  USA  2004        1293
# 5835     United States  USA  2005        1288
# 5836     United States  USA  2006        1273
# 5837     United States  USA  2007        1249
# 5838     United States  USA  2008        1223
# ...

# %%
path = 'C:\\Users\\pabli\\apuntes_de_clase\\Proyecto-ETL\data\\all_data.csv'
data_full = pd.read_csv(path)

# %%
data_full.shape
# Out:
# (3580, 69)

# %%
data_full[data_full.country == "United States"]
# Out:
#       Unnamed: 0        country Code  year  Meningitis  \
# 3400        3400  United States  USA  2000      1458.0
# 3401        3401  United States  USA  2001      1399.0
# 3402        3402  United States  USA  2002      1367.0
# 3403        3403  United States  USA  2003      1344.0
# 3404        3404  United States  USA  2004      1293.0
# 3405        3405  United States  USA  2005      1288.0
# 3406        3406  United States  USA  2006      1273.0
# 3407        3407  United States  USA  2007      1249.0
# 3408        3408  United States  USA  2008      1223.0
# 3409        3409  United States  USA  2009      1186.0
# 3410        3410  United States  USA  2010      1141.0
# 3411        3411  United States  USA  2011      1126.0
# 3412        3412  United States  USA  2012      1108.0
# 3413        3413  United States  USA  2013      1106.0
# 3414        3414  United States  USA  2014      1102.0
# 3415        3415  United States  USA  2015      1115.0
# ...

# %%
data_full.country.value_counts()
# Out:
# Afghanistan      20
# Samoa            20
# Nigeria          20
# Norway           20
# Oman             20
#                  ..
# Guinea           20
# Guinea-Bissau    20
# Guyana           20
# Haiti            20
# Zimbabwe         20
# Name: country, Length: 179, dtype: int64

# %%
data_full
# Out:
#       Unnamed: 0      country Code  year  Meningitis  \
# 0              0  Afghanistan  AFG  2000      3105.0
# 1              1  Afghanistan  AFG  2001      3063.0
# 2              2  Afghanistan  AFG  2002      2990.0
# 3              3  Afghanistan  AFG  2003      3300.0
# 4              4  Afghanistan  AFG  2004      3350.0
# ...          ...          ...  ...   ...         ...
# 3575        3575     Zimbabwe  ZWE  2015      1439.0
# 3576        3576     Zimbabwe  ZWE  2016      1457.0
# 3577        3577     Zimbabwe  ZWE  2017      1460.0
# 3578        3578     Zimbabwe  ZWE  2018      1450.0
# 3579        3579     Zimbabwe  ZWE  2019      1450.0
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                      1291.0                416.0
# 1                                      1300.0                424.0
# 2                                      1311.0                429.0
# ...

# %%
data_full.to_csv(r"../data/extraction_data.csv')
# Out:
#   Cell In [28], line 1
#     data_full.to_csv(r"../data/extraction_data.csv')
#                                                     ^
# SyntaxError: EOL while scanning string literal

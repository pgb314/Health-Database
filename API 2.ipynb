# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import requests
import time
from Functions import *

# %%
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv(r'C:\Users\pabli\Desktop\Health-Database\data\columns2.csv')

# %%
all_ = pd.read_csv(r'C:\Users\pabli\Desktop\Health-Database\data\extraction_data.csv')

# %%
data.rename(columns={"IndCode": "Code"},inplace=True)

# %%
data.drop(columns = "Unnamed: 0", inplace = True)

# %%
all_.rename(columns={"Code": "country_code"},inplace=True)

# %%
lst = []
for i,e in enumerate(data.Code):
    try:
        ind_code = e
        ind_text = data.IndName[i]
        data_raw = get_indicator(ind_code, ind_text)

        data01a = data_raw[['country_code', 'year', ind_text]]
        data01a = remove_duplicates(data01a)
        all_ = all_.merge(data01a, how='left',on = ['year','country_code'])
        
    except:
        lst.append(e)
# Out:
# Data for "Ambient air pollution  attributable DALYs per 100'000 children under 5 years" loaded, set 549 rows 23 columns
# Data for "Household air pollution attributable deaths" loaded, set 7287 rows 23 columns
# Data for "Household air pollution attributable deaths in children under 5 years" loaded, set 540 rows 23 columns
# Data for "Household air pollution attributable DALYs" loaded, set 8141 rows 23 columns
# Data for "Household air pollution attributable DALYs in children under 5 years" loaded, set 540 rows 23 columns
# Data for "Household air pollution attributable DALYs (per 100 000 population)" loaded, set 8141 rows 23 columns
# Data for "Household air pollution attributable DALYs (per 100 000, age-standardized)" loaded, set 8141 rows 23 columns
# Data for "Ambient air pollution attributable deaths in children under 5 years" loaded, set 549 rows 23 columns
# Data for "Ambient air pollution attributable deaths" loaded, set 7341 rows 23 columns
# Data for "Ambient air pollution attributable death rate (per 100 000 population, age-standardized)" loaded, set 7341 rows 23 columns
# Data for "Ambient air pollution attributable DALYs" loaded, set 3492 rows 23 columns
# Data for "DALYs attributable to ambient air pollution (age-standardized)" loaded, set 194 rows 23 columns
# Data for "Ambient air pollution attributable YLLs" loaded, set 7341 rows 23 columns
# Data for "YLLs attributable to ambient air pollution (age-standardized)" loaded, set 549 rows 23 columns
# Data for "Ambient air pollution attributable death rate (per 100 000 population)" loaded, set 7341 rows 23 columns
# Data for "Household air pollution attributable death rate (per 100 000 population)" loaded, set 7287 rows 23 columns
# Data for "Household air pollution attributable death rate (per 100 000 population, age-standardized)" loaded, set 7287 rows 23 columns
# Data for "Ambient air pollution  attributable deaths per 100'000 children under 5 years" loaded, set 549 rows 23 columns
# Data for "Ambient air pollution attributable DALYs" loaded, set 7341 rows 23 columns
# Data for "Ambient air pollution attributable DALYs  in children under 5 years" loaded, set 549 rows 23 columns
# Data for "Ambient air pollution attributable DALYs  (per 100 000 population)" loaded, set 7341 rows 23 columns
# Data for "Ambient air pollution attributable DALYs  (per 100 000 population, age-standardized)" loaded, set 7341 rows 23 columns
# Data for "Functioning national AMR surveillance plan" loaded, set 0 rows 23 columns
# Data for "Establishment of National Coordination Centre (NCC)" loaded, set 0 rows 23 columns
# Data for "Nomination of National Focal Point (NFP)" loaded, set 0 rows 23 columns
# Data for "Establishment of national reference laboratory (NRL)" loaded, set 0 rows 23 columns
# Data for "EQA provided to the national reference laboratory (NRL)" loaded, set 0 rows 23 columns
# Data for "EQA provided for bacterial identification and AST" loaded, set 0 rows 23 columns
# Data for "EQA provided to local laboratories participating in GLASS" loaded, set 0 rows 23 columns
# Data for "GLASS pathogens testing covered by EQA" loaded, set 0 rows 23 columns
# Data for "Types of AST standards followed by countries" loaded, set 0 rows 23 columns
# Data for "Number of national surveillance sites in each country providing data to GLASS: hospital category" loaded, set 0 rows 23 columns
# Data for "Number of National surveillance sites in each country providing data to GLASS: outpatient facility category" loaded, set 0 rows 23 columns
# Data for "Number of local clinical laboratories in each country performing AST to support national AMR surveillance sites" loaded, set 0 rows 23 columns
# Data for "Antenatal care coverage - at least one visit (in the two or three years preceding the survey) (%" loaded, set 11874 rows 23 columns
# Data for "Antenatal care coverage - at least one visit (in the five years preceding the survey) (%)" loaded, set 11874 rows 23 columns
# Data for "Antenatal care coverage - at least four visits (in the two or three years preceding the survey) (%)" loaded, set 11874 rows 23 columns
# Data for "Antenatal care coverage - at least four visits (in the five years preceding the survey) (%)" loaded, set 11874 rows 23 columns
# Data for "Adolescent fertility rate (per 1000 women aged 15-19 years)" loaded, set 11150 rows 23 columns
# Data for "Prevalence of met need of assistive products (%)" loaded, set 704 rows 23 columns
# Data for "Raised blood pressure (SBP>=140 OR DBP>=90) (crude estimate)" loaded, set 9360 rows 23 columns
# Data for "Raised blood pressure (SBP>=140 OR DBP>=90) (age-standardized estimate)" loaded, set 9360 rows 23 columns
# Data for "Mean systolic blood pressure (crude estimate)" loaded, set 3860 rows 23 columns
# Data for "Mean systolic blood pressure (age-standardized estimate)" loaded, set 6240 rows 23 columns
# Data for "Formative research was conducted" loaded, set 1170 rows 23 columns
# Data for "Outcome evaluation was employed to assess effectiveness" loaded, set 1170 rows 23 columns
# Data for "Campaign was part of a comprehensive tobacco control programme" loaded, set 1170 rows 23 columns
# Data for "Campaign was pre-tested" loaded, set 1170 rows 23 columns
# Data for "Campaign utilized media planning" loaded, set 1170 rows 23 columns
# Data for "At least one national mass media campaign ran during the survey period" loaded, set 1170 rows 23 columns
# Data for "Earned media/public relations were used to promote the campaign" loaded, set 1170 rows 23 columns
# Data for "Campaign aired on television and/or radio" loaded, set 1170 rows 23 columns
# Data for "Children aged < 5 years with pneumonia symptoms taken to a health facility (%)" loaded, set 12598 rows 23 columns
# Data for "Congenital syphilis number of reported cases" loaded, set 311 rows 23 columns
# Data for "Cataract surgical coverage of adults aged 50 and over (%)" loaded, set 102 rows 23 columns
# Data for "Effective cataract surgical coverage of adults aged 50 and over (%)" loaded, set 90 rows 23 columns
# Data for "Climate change attributable deaths" loaded, set 0 rows 23 columns
# Data for "Climate change attributable DALYs ('000)" loaded, set 0 rows 23 columns
# Data for "Climate change attributable deaths per 100'000 capita" loaded, set 0 rows 23 columns
# Data for "Climate change attributable DALYs per 100'000 capita" loaded, set 0 rows 23 columns
# Data for "Climate change attributable deaths ('000) in children under 5 years" loaded, set 0 rows 23 columns
# Data for "Climate change  attributable deaths per 100'000 children under 5 years" loaded, set 0 rows 23 columns
# Data for "Climate change attributable DALYs ('000) in children under 5 years" loaded, set 0 rows 23 columns
# Data for "Climate change  attributable DALYs per 100'000 children under 5 years" loaded, set 0 rows 23 columns
# Data for "Composite coverage index (%)" loaded, set 11150 rows 23 columns
# Data for "Composite coverage index (%)" loaded, set 5496 rows 23 columns
# Data for "Poverty headcount ratio at $1.25 a day (PPP) (% of population)" loaded, set 105 rows 23 columns
# Data for "Human development index rank" loaded, set 369 rows 23 columns
# Data for "Gender inequality index rank" loaded, set 340 rows 23 columns
# Data for "Mortality rate for 5-14 year-olds (probability of dying per 1000 children aged 5-14 years)" loaded, set 3900 rows 23 columns
# Data for "Number of reported cases of cholera" loaded, set 883 rows 23 columns
# Data for "Number of reported deaths from cholera" loaded, set 822 rows 23 columns
# Data for "Cholera case fatality rate" loaded, set 833 rows 23 columns
# Data for "Number of under-five deaths" loaded, set 12285 rows 23 columns
# Data for "Number of infant deaths" loaded, set 12285 rows 23 columns
# Data for "Number of neonatal deaths" loaded, set 4095 rows 23 columns
# Data for "Contraceptive prevalence - modern and traditional methods (%)" loaded, set 11874 rows 23 columns
# Data for "Births by caesarean section (in the two or three years preceding the survey) (%)" loaded, set 11874 rows 23 columns
# Data for "Births by caesarean section (in the five years preceding the survey) (%)" loaded, set 11874 rows 23 columns
# Data for "Total density per 100 000 population: Hospitals" loaded, set 137 rows 23 columns
# Data for "Total density per 100 000 population: Health posts" loaded, set 222 rows 23 columns
# Data for "Total density per 100 000 population: Health centres" loaded, set 219 rows 23 columns
# Data for "Total density per 100 000 population: District/rural hospitals" loaded, set 244 rows 23 columns
# Data for "Total density per 100 000 population: Provincial hospitals" loaded, set 251 rows 23 columns
# Data for "Total density per 100 000 population: Specialized hospitals" loaded, set 252 rows 23 columns
# Data for "Availability of national standards or recommended lists of medical devices" loaded, set 318 rows 23 columns
# Data for "Types of lists recommending health technology for high burden diseases" loaded, set 322 rows 23 columns
# Data for "Total density per million population: Magnetic Resonance Imaging" loaded, set 263 rows 23 columns
# Data for "Total density per million population: Computed tomography units" loaded, set 268 rows 23 columns
# Data for "Total density per million population: Positron Emission tomography" loaded, set 230 rows 23 columns
# Data for "Total density per million population: Gamma camera or Nuclear medicine" loaded, set 232 rows 23 columns
# Data for "Total density per million population: Linear Accelerator" loaded, set 331 rows 23 columns
# Data for "Type of nomenclature system" loaded, set 337 rows 23 columns
# Data for "Use of nomenclature system" loaded, set 204 rows 23 columns
# Data for "Health technology (medical device) national policy" loaded, set 341 rows 23 columns
# Data for "Unit in the Ministry of Health responsible for the management of medical devices" loaded, set 340 rows 23 columns
# Data for "Procurement of medical devices carried out at the national level" loaded, set 336 rows 23 columns
# Data for "Availability of national list of approved medical devices for procurement or reimbursement" loaded, set 340 rows 23 columns
# Data for "National guidelines, policies or recommendations on the procurement of medical devices" loaded, set 335 rows 23 columns
# Data for "Availability of technical specifications of medical devices to support procurement or donations" loaded, set 331 rows 23 columns
# Data for "Total density per million population: Telecobalt Unit" loaded, set 327 rows 23 columns
# Data for "Total density per million population: Radiotherapy units" loaded, set 338 rows 23 columns
# Data for "Total density per million females aged from 50 to 69 years old: Mammography units" loaded, set 245 rows 23 columns
# Data for "Enforcing bans on tobacco advertising, promotion and sponsorship" loaded, set 1560 rows 23 columns
# Data for "Compliance of ban on advertising on national TV and radio" loaded, set 776 rows 23 columns
# Data for "Ban on advertising: National TV and radio" loaded, set 1560 rows 23 columns
# Data for "Compliance of ban on promotional discounts" loaded, set 776 rows 23 columns
# Data for "Ban on promotional discounts" loaded, set 1560 rows 23 columns
# Data for "Ban on non-tobacco goods AND services identified with tobacco brand names" loaded, set 1560 rows 23 columns
# Data for "Compliance of ban on non-tobacco goods AND services identified with tobacco brand names" loaded, set 776 rows 23 columns
# Data for "Ban on brand name of non-tobacco products used for tobacco product" loaded, set 1560 rows 23 columns
# Data for "Compliance of ban on brand name of non-tobacco products used for tobacco product" loaded, set 776 rows 23 columns
# Data for "Ban on appearance of tobacco brands in TV and/or films (product placement)" loaded, set 1560 rows 23 columns
# Data for "Compliance of ban on appearance of tobacco brands in TV and/or films (product placement)" loaded, set 776 rows 23 columns
# Data for "Compliance of ban on appearance of tobacco products in TV and/or films" loaded, set 776 rows 23 columns
# Data for "Appearance of tobacco products in TV and/or films" loaded, set 776 rows 23 columns
# Data for "Ban on appearance of tobacco products in TV and/or films" loaded, set 1560 rows 23 columns
# Data for "Requirement to present prescribed anti-tobacco ads before, during or after the broadcasting or showing of any visual entertainment media product that depicts tobacco products, use or images" loaded, set 1560 rows 23 columns
# Data for "Compliance of ban on sponsored events" loaded, set 776 rows 23 columns
# Data for "Sponsored events" loaded, set 776 rows 23 columns
# Data for "Complete ban on sponsorship" loaded, set 1560 rows 23 columns
# Data for "Ban on any form of contribution (financial or other support) to any event, activity or individual" loaded, set 1560 rows 23 columns
# Data for "Banning the publicity of financial or other sponsorship or support by the tobacco industry of events, activities, individuals" loaded, set 1560 rows 23 columns
# Data for "Ban on tobacco companies/tobacco industry publicizing their “Corporate Social Responsibility” activities" loaded, set 776 rows 23 columns
# Data for "Ban on entities other than tobacco companies/tobacco industry publicizing the Corporate Social Responsibility activities of the tobacco companies" loaded, set 776 rows 23 columns
# Data for "Ban on tobacco companies funding or making contributions (including in-kind contributions) to smoking prevention media campaigns, including those directed at youth" loaded, set 1560 rows 23 columns
# Data for "Required anti-tobacco ads for any visual entertainment media product that depicts tobacco products, use or images" loaded, set 776 rows 23 columns
# Data for "Ban on advertising: International TV and radio (broadcast from abroad, including satellite)" loaded, set 1560 rows 23 columns
# Data for "Complete ban on tobacco vending machines" loaded, set 776 rows 23 columns
# Data for "Subnational bans on tobacco advertising, promotion and sponsorship" loaded, set 776 rows 23 columns
# Data for "Subnational advertising, promotion and sponsorship bans - at least one jurisdiction has a comprehensive ban in place" loaded, set 776 rows 23 columns
# Data for "Ban on internet sales of tobacco products" loaded, set 1560 rows 23 columns
# Data for "Ban on display of tobacco products at points of sale" loaded, set 776 rows 23 columns
# Data for "Law requires fines for violations of direct advertising bans" loaded, set 776 rows 23 columns
# Data for "Law requires fines for violations of indirect advertising bans" loaded, set 776 rows 23 columns
# Data for "Compliance of ban on advertising on local magazines and newspapers" loaded, set 776 rows 23 columns
# Data for "Ban on advertising: Local magazines and newspapers" loaded, set 1560 rows 23 columns
# Data for "Ban on advertising: International magazines and newspapers" loaded, set 1560 rows 23 columns
# Data for "Ban on advertising: Billboards and outdoor advertising" loaded, set 1560 rows 23 columns
# Data for "Compliance of ban on advertising on billboards and outdoor advertising" loaded, set 776 rows 23 columns
# Data for "Compliance of ban on advertising at point of sale" loaded, set 776 rows 23 columns
# Data for "Ban on advertising: Point of sale" loaded, set 776 rows 23 columns
# Data for "Ban on display of tobacco products at points of sale" loaded, set 1560 rows 23 columns
# Data for "Ban on advertising: Internet" loaded, set 1560 rows 23 columns
# Data for "Compliance of ban on free distribution of tobacco products in the mail or through other means" loaded, set 776 rows 23 columns
# Data for "Ban on free distribution of tobacco products in the mail or through other means" loaded, set 1560 rows 23 columns
# Data for "Compliance with bans on direct advertising" loaded, set 776 rows 23 columns
# Data for "Compliance with bans on promotion and sponsorship" loaded, set 776 rows 23 columns
# Data for "Electric field (kV/m)" loaded, set 32 rows 23 columns
# Data for "Electric field (kV/m)" loaded, set 62 rows 23 columns
# Data for "Electric field (V/m)" loaded, set 128 rows 23 columns
# Data for "Magnetic flux density (microT)" loaded, set 108 rows 23 columns
# Data for "Power density (W/m^2)" loaded, set 130 rows 23 columns
# Data for "Power frequency (Hz)" loaded, set 61 rows 23 columns
# Data for "Specific absorption rate (SAR) (W/kg)" loaded, set 183 rows 23 columns
# Data for "Existence of standards" loaded, set 246 rows 23 columns
# Data for "Legislative status" loaded, set 224 rows 23 columns
# Data for "Availability of estimates on large  health expenditures as a share of total expenditure or income" loaded, set 430 rows 23 columns
# Data for "Population with household spending on health greater than 10% of total household budget (SDG 3.8.2, estimated data) (millions)" loaded, set 105 rows 23 columns
# Data for "Population with household spending on health greater than 10% of total household budget (SDG 3.8.2, estimated data) (%)" loaded, set 105 rows 23 columns
# Data for "Population with household spending on health greater than 10% of total household budget (SDG 3.8.2, reported data) (%)" loaded, set 1879 rows 23 columns
# Data for "Population with household spending on health greater than 25% of total household budget (SDG 3.8.2, estimated data) (millions)" loaded, set 105 rows 23 columns
# Data for "Population with household spending on health greater than 25% of total household budget (SDG 3.8.2, estimated data) (%)" loaded, set 105 rows 23 columns
# Data for "Population with household spending on health greater than 25% of total household budget (SDG 3.8.2, reported data) (%)" loaded, set 1878 rows 23 columns
# Data for "Total population  pushed below the $1.90 a day  poverty line by household  health expenditures (millions)" loaded, set 105 rows 23 columns
# Data for "Total population  pushed below the $1.90 a day  poverty line by household  health expenditures (%)" loaded, set 105 rows 23 columns
# Data for "Total population  pushed below the $3.10 a day  poverty line by household  health expenditures (millions)" loaded, set 105 rows 23 columns
# Data for "Total population  pushed below the $3.10 a day  poverty line by household  health expenditures (%)" loaded, set 105 rows 23 columns
# Data for "Population  pushed below the $1.90 a day  poverty line by household  health expenditures (%)" loaded, set 1761 rows 23 columns
# Data for "Population  pushed below the $3.10 a day  poverty line by household  health expenditures (%)" loaded, set 1757 rows 23 columns
# Data for "Increase in poverty gap due to household  health expenditures, expressed as a proportion of the $1.90 a-day poverty line (%)" loaded, set 1754 rows 23 columns
# Data for "Increase in poverty gap due to household  health expenditures, expressed as a proportion of the 3.10 a-day poverty line (%)" loaded, set 1750 rows 23 columns
# Data for "Availability of estimates on impoverishment due to out-of-pocket health expenditures" loaded, set 430 rows 23 columns
# Data for "Demand for family planning satisfied - modern and traditional methods (%)" loaded, set 11874 rows 23 columns
# Data for "Demand for family planning satisfied - modern methods (%)" loaded, set 6030 rows 23 columns
# Data for "Age-standardized DALYs (per 100,000)" loaded, set 1376 rows 23 columns
# Data for "National regulator approval of anti-dementia medication" loaded, set 61 rows 23 columns
# Data for "Availability of generic anti-dementia medication" loaded, set 61 rows 23 columns
# Data for "Availability of at least one anti-dementia medication approved for on-label use reimbursement" loaded, set 61 rows 23 columns
# Data for "Availability of atleast one adult hygiene products for people with dementia" loaded, set 61 rows 23 columns
# Data for "Availability of atleast one housing adjustment for people with dementia" loaded, set 61 rows 23 columns
# Data for "Availability of  atleast one assistive technology for people with dementia" loaded, set 61 rows 23 columns
# Data for "Existence of dementia national nongovernmental organization" loaded, set 61 rows 23 columns
# Data for "Dementia nongovernmental organization equipped with office" loaded, set 61 rows 23 columns
# Data for "Dementia nongovernmental organization office branches (Sub-national)" loaded, set 61 rows 23 columns
# Data for "Dementia nongovernmental organization office branches (Local)" loaded, set 61 rows 23 columns
# Data for "Dementia nongovernmental organization office branches (National only)" loaded, set 61 rows 23 columns
# Data for "Dementia nongovernmental organization staff primarily salaried/volunteer" loaded, set 61 rows 23 columns
# Data for "Provision of governmental funding to dementia nongovernmental organization for activities/services" loaded, set 61 rows 23 columns
# Data for "Dementia nongovernmental organization's involvement in policy development" loaded, set 61 rows 23 columns
# Data for "Existence of dementia carer support services" loaded, set 61 rows 23 columns
# Data for "Implementation level [national/subnational] of dementia carer support services" loaded, set 61 rows 23 columns
# Data for "Existence of dedicated resources for dementia carer support services" loaded, set 61 rows 23 columns
# Data for "Existence of implementation plan for dementia carer support services" loaded, set 61 rows 23 columns
# Data for "Existence of psycho-social supports for dementia carers" loaded, set 61 rows 23 columns
# Data for "Existence of respite care for dementia carers" loaded, set 61 rows 23 columns
# Data for "Existence of information on legal rights for dementia carers" loaded, set 61 rows 23 columns
# Data for "Existence of financial benefits/social protection for dementia carers" loaded, set 61 rows 23 columns
# Data for "Accessibility of dementia carer training and education [Capital/capital and main cities/capital, main cities, rural areas]" loaded, set 61 rows 23 columns
# Data for "Majority provider of dementia carer training and education (NGO)" loaded, set 61 rows 23 columns
# Data for "Majority provider of dementia carer training and education (Private sector)" loaded, set 61 rows 23 columns
# Data for "Majority provider of dementia carer training and education (Public sector)" loaded, set 61 rows 23 columns
# Data for "Accessibility of psycho-social supports for dementia carers [Capital/capital and main cities/capital, main cities, rural areas]" loaded, set 61 rows 23 columns
# Data for "Majority provider of psycho-social supports for dementia carers (NGO)" loaded, set 61 rows 23 columns
# Data for "Majority provider of psycho-social supports for dementia carers (Private sector)" loaded, set 61 rows 23 columns
# Data for "Majority provider of psycho-social supports for dementia carers (Public sector)" loaded, set 61 rows 23 columns
# Data for "Accessibility of respite care for dementia carers [Capital/capital and main cities/capital, main cities, rural areas]" loaded, set 61 rows 23 columns
# Data for "Majority provider of respite care for dementia carers (NGO)" loaded, set 61 rows 23 columns
# Data for "Majority provider of respite care for dementia carers (Private sector)" loaded, set 61 rows 23 columns
# Data for "Majority provider of respite care for dementia carers (Public sector)" loaded, set 61 rows 23 columns
# Data for "Accessibility of information on legal rights for dementia carers [Capital/capital and main cities/capital, main cities, rural areas]" loaded, set 61 rows 23 columns
# Data for "Majority provider of information on legal rights for dementia carers (NGO)" loaded, set 61 rows 23 columns
# Data for "Majority provider of information on legal rights for dementia carers (Private sector)" loaded, set 61 rows 23 columns
# Data for "Majority provider of information  on legal rights for dementia carers (Public sector)" loaded, set 61 rows 23 columns
# Data for "Accessibility of financial benefits/social protection for dementia carers [Capital/capital and main cities/capital, main cities, rural areas]" loaded, set 61 rows 23 columns
# Data for "Majority provider of information on financial benefits/social protection for dementia carers (NGO)" loaded, set 61 rows 23 columns
# Data for "Majority provider of information on financial benefits/social protection for dementia carers (Private sector)" loaded, set 61 rows 23 columns
# Data for "Majority provider of information  on financial benefits/social protection for dementia carers (Public sector)" loaded, set 61 rows 23 columns
# Data for "Estimated number of dementia carers receiving training and education" loaded, set 61 rows 23 columns
# Data for "Estimated number of dementia carers receiving psycho-social supports" loaded, set 61 rows 23 columns
# Data for "Estimated number of dementia carers receiving respite care" loaded, set 61 rows 23 columns
# Data for "Estimated number of dementia carers receiving information on legal rights" loaded, set 61 rows 23 columns
# Data for "Estimated number of dementia carers receiving financial benefits/social protection" loaded, set 61 rows 23 columns
# Data for "Existence of at least one functioning dementia awareness campaign" loaded, set 61 rows 23 columns
# Data for "Implementation level [national/subnational] of dementia awareness campaign" loaded, set 61 rows 23 columns
# Data for "Existence of at least one functioning risk reduction campaign" loaded, set 61 rows 23 columns
# Data for "Implementation level [national/subnational] of dementia risk reduction campaign" loaded, set 61 rows 23 columns
# Data for "Availability of dementia-friendly initiatives that improve accessibility" loaded, set 61 rows 23 columns
# Data for "Existence of dementia-friendly initiative to improve accessibility of public spaces" loaded, set 61 rows 23 columns
# Data for "Existence of dementia-friendly initiative to improve accessibility of public transportation" loaded, set 61 rows 23 columns
# Data for "Existence of dementia-friendly initiative for assistance with home modification" loaded, set 61 rows 23 columns
# Data for "Existence of dementia-friendly initiative with assistive technology for loss of capacity" loaded, set 61 rows 23 columns
# Data for "Existence of dementia-friendly initiative supporting community places for older people" loaded, set 61 rows 23 columns
# Data for "Existence of dementia-friendly initiative supporting social opportunities" loaded, set 61 rows 23 columns
# Data for "Inclusion of dementia training and education for non-health workers" loaded, set 61 rows 23 columns
# Data for "Existence of dementia training for volunteers" loaded, set 61 rows 23 columns
# Data for "Existence of dementia training for police and fire services" loaded, set 61 rows 23 columns
# Data for "Existence of dementia training for first responders" loaded, set 61 rows 23 columns
# Data for "Existence of dementia training for legal professionals" loaded, set 61 rows 23 columns
# Data for "Existence of dementia training for community workers" loaded, set 61 rows 23 columns
# Data for "Existence of dementia training for school children" loaded, set 61 rows 23 columns
# Data for "Existence of dementia training for financial service staff" loaded, set 61 rows 23 columns
# Data for "Existence of dementia training for retail and hospitality staff" loaded, set 61 rows 23 columns
# Data for "Routine monitoring of people with dementia" loaded, set 61 rows 23 columns
# Data for "Data sources used to routinely monitor people with dementia (Clinical records)" loaded, set 21 rows 23 columns
# Data for "Data sources used to routinely monitor people with dementia (Household surveys)" loaded, set 21 rows 23 columns
# Data for "Data sources used to routinely monitor people with dementia (Administrative data)" loaded, set 21 rows 23 columns
# Data for "Data sources used to routinely monitor people with dementia (Facility survey or records)" loaded, set 21 rows 23 columns
# Data for "Data sources used to routinely monitor people with dementia (Other)" loaded, set 21 rows 23 columns
# Data for "Electronic availability of data sources used to routinely monitor people with dementia" loaded, set 21 rows 23 columns
# Data for "Data used to routinely monitor people with dementia can be disaggregated" loaded, set 21 rows 23 columns
# Data for "Availability of routine hospital admissions records for people with dementia for monitoring purposes" loaded, set 61 rows 23 columns
# Data for "Availability of routine outpatient visit records for people with dementia for monitoring purposes" loaded, set 61 rows 23 columns
# Data for "Availability of routine outpatient intervention and treatment records for people with dementia for monitoring purposes" loaded, set 61 rows 23 columns
# Data for "Availability of routine pharmaceutical records for people with dementia for monitoring purposes" loaded, set 61 rows 23 columns
# Data for "Availability of routine antipsychotic prescription records for people with dementia for monitoring purposes" loaded, set 61 rows 23 columns
# Data for "Availability and status of dementia reporting in the past two years" loaded, set 61 rows 23 columns
# Data for "Existence of a current dementia research plan/programme" loaded, set 61 rows 23 columns
# Data for "Implementation level [national/subnational] of dementia research plan/programme" loaded, set 61 rows 23 columns
# Data for "Dementia integrated into other national research plan/programme" loaded, set 61 rows 23 columns
# Data for "Identification of other research plans in which dementia is integrated (Mental health)" loaded, set 61 rows 23 columns
# Data for "Identification of other research plans in which dementia is integrated (Ageing)" loaded, set 61 rows 23 columns
# Data for "Identification of other research plans in which dementia is integrated (Neuro or neurodegenerative disease)" loaded, set 61 rows 23 columns
# Data for "Identification of other research plans in which dementia is integrated (NCD)" loaded, set 61 rows 23 columns
# Data for "Implementation level [national/subnational] of research plan in which dementia is integrated" loaded, set 61 rows 23 columns
# Data for "Availability of funding for dementia-specific research plan/programme" loaded, set 61 rows 23 columns
# Data for "Total expenditure on dementia research (local currency, self-report)" loaded, set 61 rows 23 columns
# Data for "Total expenditure on dementia basic research (local currency, self-report)" loaded, set 61 rows 23 columns
# Data for "Total expenditure on dementia clinical/translational research (local currency, self-report)" loaded, set 61 rows 23 columns
# Data for "Total expenditure on dementia implementation research (local currency, self-report)" loaded, set 61 rows 23 columns
# Data for "Number of people with dementia involved in research routinely monitored" loaded, set 61 rows 23 columns
# Data for "Availability of investigational pharmaceutical trials for dementia" loaded, set 61 rows 23 columns
# Data for "Number of investigational pharmaceutical trials for dementia" loaded, set 61 rows 23 columns
# Data for "Inclusion of dementia in ministry portfolio" loaded, set 61 rows 23 columns
# Data for "Inclusion of dementia in a branch of government [health, ageing, social services, mental health, noncommunicable disease]" loaded, set 61 rows 23 columns
# Data for "Existence of dementia representative in ministry" loaded, set 61 rows 23 columns
# Data for "Total number of published dementia research output" loaded, set 21 rows 23 columns
# Data for "Existence of dementia national plan" loaded, set 61 rows 23 columns
# Data for "Availability of funding for dementia national plan" loaded, set 61 rows 23 columns
# Data for "Targets for monitoring implementation of dementia national plan" loaded, set 61 rows 23 columns
# Data for "Dementia integrated into other national plan" loaded, set 61 rows 23 columns
# Data for "Identification of other plans in which dementia is integrated (Ageing)" loaded, set 61 rows 23 columns
# Data for "Identification of other plans in which dementia is integrated (Disability)" loaded, set 61 rows 23 columns
# Data for "Identification of other plans in which dementia is integrated (Mental health)" loaded, set 61 rows 23 columns
# Data for "Identification of other plans in which dementia is integrated (NCD)" loaded, set 61 rows 23 columns
# Data for "Identification of other plans in which dementia is integrated (Other)" loaded, set 61 rows 23 columns
# Data for "Existence of dementia sub-national plan(s)" loaded, set 61 rows 23 columns
# Data for "Percentage of sub-national regions covered by dementia plan" loaded, set 61 rows 23 columns
# Data for "Inclusion of human rights as a guiding principle of the dementia plan" loaded, set 61 rows 23 columns
# Data for "Inclusion of equity as a guiding principle of the dementia plan" loaded, set 61 rows 23 columns
# Data for "Inclusion of empowerment as a guiding principle of the dementia plan" loaded, set 61 rows 23 columns
# Data for "Inclusion of multisectoral collaboration as a guiding principles of the dementia plan" loaded, set 61 rows 23 columns
# Data for "Inclusion of universal health coverage as a guiding principle of the dementia plan" loaded, set 61 rows 23 columns
# Data for "Inclusion of dementia-friendly communities as a specific action of the dementia plan" loaded, set 61 rows 23 columns
# Data for "Inclusion of dementia risk reduction as a specific action of the dementia plan" loaded, set 61 rows 23 columns
# Data for "Inclusion of dementia diagnosis, care and support as a specific action of the dementia plan" loaded, set 61 rows 23 columns
# Data for "Inclusion of dementia workforce training as a specific action of the dementia plan" loaded, set 61 rows 23 columns
# Data for "Inclusion of support for dementia carers and families as a specific action of the dementia plan" loaded, set 61 rows 23 columns
# Data for "Inclusion of improved information system as a specific action of the dementia plan" loaded, set 61 rows 23 columns
# Data for "Inclusion of research and innovation as a specific action of the dementia plan" loaded, set 61 rows 23 columns
# Data for "Estimated population-based prevalence of depression" loaded, set 183 rows 23 columns
# Data for "Existence of dementia legislation" loaded, set 61 rows 23 columns
# Data for "Implementation level [national/subnational] of dementia legislation" loaded, set 61 rows 23 columns
# Data for "Existence of other laws that apply to the rights of people with dementia" loaded, set 61 rows 23 columns
# Data for "Existence of legislation for supported decision making for people with dementia" loaded, set 61 rows 23 columns
# Data for "Existence of legislation to file appeals protecting the rights of people with dementia" loaded, set 61 rows 23 columns
# Data for "Existence of legislation to promote community-based services for people with dementia" loaded, set 61 rows 23 columns
# Data for "Existence of legislation to promote monitoring of human rights conditions of people with dementia in facilities where they reside" loaded, set 61 rows 23 columns
# Data for "Existence of legislation to end coercieve practices for people with dementia" loaded, set 61 rows 23 columns
# Data for "Existence of legislation for advanced care directives for people with dementia" loaded, set 61 rows 23 columns
# Data for "Existence of legislation to end discrimination against people with dementia" loaded, set 61 rows 23 columns
# Data for "Existence of legislation to end discrimination against carers of people with dementia" loaded, set 61 rows 23 columns
# Data for "Existence of dementia standards/ guidelines/ protocols" loaded, set 61 rows 23 columns
# Data for "Implementation level of dementia standards/ guidelines/ protocols (National)" loaded, set 61 rows 23 columns
# Data for "Implementation level of dementia standards/ guidelines/ protocols (Sub-national)" loaded, set 61 rows 23 columns
# Data for "Existence of approved government dementia standards/ guidelines/ protocols" loaded, set 61 rows 23 columns
# Data for "Existence of standards/ guidelines/ protocols for prevention and risk reduction of dementia" loaded, set 61 rows 23 columns
# Data for "Existence of standards/ guidelines/ protocols for diagnosis of dementia" loaded, set 61 rows 23 columns
# Data for "Existence of standards/ guidelines/ protocols for management of dementia" loaded, set 61 rows 23 columns
# Data for "Existence of standards/ guidelines/ protocols for other post-diagnostic supports of people with dementia" loaded, set 61 rows 23 columns
# Data for "Existence of standards/ guidelines/ protocols for treatment and support of carers and families of people with dementia" loaded, set 61 rows 23 columns
# Data for "Existence of standards/ guidelines/ protocols for advance care directives, power of attorney or guardianship for people with dementia" loaded, set 61 rows 23 columns
# Data for "Existence of standards/ guidelines/ protocols for palliative and end-of-life care for people with dementia" loaded, set 61 rows 23 columns
# Data for "Existence of standards/ guidelines/ protocols of care in nursing & residential care facilities for people with dementia" loaded, set 61 rows 23 columns
# Data for "Existence of standards/ guidelines/ protocols of care in hospital for people with dementia" loaded, set 61 rows 23 columns
# Data for "Availability of mechanisms to coordinate dementia care across sectors" loaded, set 61 rows 23 columns
# Data for "Identification of different sectors in dementia care coordination  (Health)" loaded, set 61 rows 23 columns
# Data for "Identification of different sectors in dementia care coordination (Social)" loaded, set 61 rows 23 columns
# Data for "Identification of different sectors in dementia care coordination (Education)" loaded, set 61 rows 23 columns
# Data for "Identification of different sectors in dementia care coordination (Employment)" loaded, set 61 rows 23 columns
# Data for "Identification of different sectors in dementia care coordination (Justice)" loaded, set 61 rows 23 columns
# Data for "Identification of different sectors in dementia care coordination (Housing)" loaded, set 61 rows 23 columns
# Data for "Identification of different sectors in dementia care coordination (Civil society)" loaded, set 61 rows 23 columns
# Data for "Identification of different sectors in dementia care coordination (Private sector)" loaded, set 61 rows 23 columns
# Data for "Identification of different sectors in dementia care coordination (Other)" loaded, set 61 rows 23 columns
# Data for "Implementation level [national/subnational] of dementia care coordination" loaded, set 61 rows 23 columns
# Data for "Presence of formal agreement/joint plan for dementia care coordination" loaded, set 61 rows 23 columns
# Data for "Availability of dementia care coordination standards/ guidelines/ protocols" loaded, set 61 rows 23 columns
# Data for "Number of neurologists (per 100,000)" loaded, set 21 rows 23 columns
# Data for "Number of geriatricians or psychogeriatricians (per 100,000)" loaded, set 21 rows 23 columns
# Data for "Inclusion of basic dementia competencies in training of physicians" loaded, set 60 rows 23 columns
# Data for "Inclusion of basic dementia competencies in training of specialists" loaded, set 60 rows 23 columns
# Data for "Inclusion of basic dementia competencies in training of nurses" loaded, set 61 rows 23 columns
# Data for "Inclusion of basic dementia competencies in training of pharmaceutical personnel" loaded, set 61 rows 23 columns
# Data for "Inclusion of basic dementia competencies in training of social workers" loaded, set 61 rows 23 columns
# Data for "Inclusion of basic dementia competencies in training of personal support workers" loaded, set 61 rows 23 columns
# Data for "Availability of dementia diagnostic rate" loaded, set 61 rows 23 columns
# Data for "Existence of community-based health or social care services for dementia" loaded, set 61 rows 23 columns
# Data for "Availability of diagnostic services in community for dementia" loaded, set 61 rows 23 columns
# Data for "Availability of behaviour and psychological management in community for dementia" loaded, set 61 rows 23 columns
# Data for "Availability of psychosocial and rehabilitation services in community for dementia" loaded, set 61 rows 23 columns
# Data for "Availability of activities of daily living support services in community for dementia" loaded, set 61 rows 23 columns
# Data for "Availability of palliative and end-of-life care services in community for dementia" loaded, set 61 rows 23 columns
# Data for "Availability of social and financial protection for dementia" loaded, set 61 rows 23 columns
# Data for "Accessibility of diagnostic services in community for dementia [Capital/capital and main cities/capital, main cities, rural areas]" loaded, set 61 rows 23 columns
# Data for "Accessibility of behaviour and psychological management in community for dementia [Capital/capital and main cities/capital, main cities, rural areas]" loaded, set 61 rows 23 columns
# Data for "Accessibility of psychosocial and rehabilitation services in community for dementia [Capital/capital and main cities/capital, main cities, rural areas]" loaded, set 61 rows 23 columns
# Data for "Accessibility of activities of daily living support services in community for dementia [Capital/capital and main cities/capital, main cities, rural areas]" loaded, set 61 rows 23 columns
# Data for "Accessibility of palliative and end-of-life care services in community for dementia [Capital/capital and main cities/capital, main cities, rural areas]" loaded, set 61 rows 23 columns
# Data for "Accessibility of social and financial protection for dementia [Capital/capital and main cities/capital, main cities, rural areas]" loaded, set 61 rows 23 columns
# Data for "Majority provider of diagnostic services in community for dementia [public, private]" loaded, set 61 rows 23 columns
# Data for "Majority provider of behaviour and psychological management in community for dementia [public, private]" loaded, set 61 rows 23 columns
# Data for "Majority provider of psychosocial and rehabilitation services in community for dementia [public, private]" loaded, set 61 rows 23 columns
# Data for "Majority provider of activities of daily living support services in community for dementia [public, private]" loaded, set 61 rows 23 columns
# Data for "Majority provider of palliative and end-of-life care services in community for dementia [public, private]" loaded, set 61 rows 23 columns
# Data for "Majority provider of social and financial protection for dementia [public, private]" loaded, set 61 rows 23 columns
# Data for "Estimated number of people receiving behaviour and psychological management services in community for dementia" loaded, set 54 rows 23 columns
# Data for "Estimated number of people receiving psychosocial and rehabilitation services in community for dementia" loaded, set 54 rows 23 columns
# Data for "Estimated number of people receiving activities of daily living support services in community for dementia" loaded, set 52 rows 23 columns
# Data for "Estimated number of people receiving palliative and end-of-life care services in community for dementia" loaded, set 57 rows 23 columns
# Data for "Estimated number of people with dementia receiving social and financial protection for dementia" loaded, set 50 rows 23 columns
# Data for "Dementia care facilities [hospitals]" loaded, set 61 rows 23 columns
# Data for "Care facilities [long-term care]" loaded, set 61 rows 23 columns
# Data for "Care facilities [hospice centres]" loaded, set 61 rows 23 columns
# Data for "Adult day centres" loaded, set 61 rows 23 columns
# Data for "Outpatient health centres" loaded, set 61 rows 23 columns
# Data for "Outpatient social centres" loaded, set 61 rows 23 columns
# Data for "Dementia-specific hospital beds (per 10,000 population)" loaded, set 61 rows 23 columns
# Data for "Geriatric-specific hospital beds (per 10,000 population)" loaded, set 61 rows 23 columns
# Data for "Total dementia hospital admissions (per 100,000)" loaded, set 61 rows 23 columns
# Data for "Estimated percentage of hospitals following national dementia standards" loaded, set 61 rows 23 columns
# Data for "Density of residential long-term care facilities (per 100,000 population)" loaded, set 61 rows 23 columns
# Data for "Residential long-term care beds (per 10 000 population)" loaded, set 61 rows 23 columns
# Data for "Dementia-specific residential long-term care beds (per 10,000 population)" loaded, set 61 rows 23 columns
# Data for "Estimated number of people with dementia living in residential long-term care" loaded, set 61 rows 23 columns
# Data for "Estimated percentage of residential long-term care facilities following national dementia standards" loaded, set 61 rows 23 columns
# Data for "Density of hospice centres (per 100,000 population)" loaded, set 61 rows 23 columns
# Data for "Hospice centre beds (per 10 000 population)" loaded, set 61 rows 23 columns
# Data for "Dementia-specific hospice care beds (per 10,000 population)" loaded, set 61 rows 23 columns
# Data for "Density of adult day centres (per 100,000 population)" loaded, set 61 rows 23 columns
# Data for "Adult day centre places (per 10,000 population)" loaded, set 61 rows 23 columns
# Data for "Dementia-specific adult day centre places (per 10,000 population)" loaded, set 61 rows 23 columns
# Data for "Density of outpatient health centres (per 100,000 population)" loaded, set 61 rows 23 columns
# Data for "Estimated number of people with dementia receiving services at outpatient health centre" loaded, set 61 rows 23 columns
# Data for "Density of outpatient social centres (per 100,000 population)" loaded, set 61 rows 23 columns
# Data for "Estimated number of people with dementia receiving services at outpatient social centre" loaded, set 61 rows 23 columns
# Data for "Disability-adjusted life years (DALYs)" loaded, set 212233 rows 23 columns
# Data for "Disability-adjusted life years (DALYs) (per 100 000 population)" loaded, set 161160 rows 23 columns
# Data for "Years of healthy life lost due to disability (YLDs)" loaded, set 210140 rows 23 columns
# Data for "Years of life lost from mortality (YLLs)" loaded, set 210140 rows 23 columns
# Data for "Years of life lost from mortality (YLLs) (per 100 000 population)" loaded, set 165900 rows 23 columns
# Data for "Current health expenditure (CHE) per capita in PPP int$" loaded, set 3774 rows 23 columns
# Data for "Current health expenditure (CHE) per capita in US$" loaded, set 3774 rows 23 columns
# Data for "Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)" loaded, set 3774 rows 23 columns
# Data for "External health expenditure (EXT) per capita in PPP int$" loaded, set 3774 rows 23 columns
# Data for "External health expenditure (EXT) per capita in US$" loaded, set 3774 rows 23 columns
# Data for "External health expenditure (EXT) as percentage of current health expenditure (CHE) (%)" loaded, set 3774 rows 23 columns
# Data for "Domestic general government health expenditure (GGHE-D) per capita in PPP int$" loaded, set 3774 rows 23 columns
# Data for "Domestic general government health expenditure (GGHE-D) per capita in US$" loaded, set 3774 rows 23 columns
# Data for "Domestic general government health expenditure (GGHE-D) as percentage of current health expenditure (CHE) (%)" loaded, set 3774 rows 23 columns
# Data for "Domestic general government health expenditure (GGHE-D) as percentage of gross domestic product (GDP) (%)" loaded, set 3774 rows 23 columns
# Data for "Domestic general government health expenditure (GGHE-D) as percentage of general government expenditure (GGE) (%)" loaded, set 3774 rows 23 columns
# Data for "Out-of-pocket expenditure (OOP) per capita in PPP int$" loaded, set 3774 rows 23 columns
# Data for "Out-of-pocket expenditure (OOP) per capita in US$" loaded, set 3774 rows 23 columns
# Data for "Out-of-pocket expenditure as percentage of current health expenditure (CHE) (%)" loaded, set 3774 rows 23 columns
# Data for "Domestic private health expenditure (PVT-D) per capita in PPP int$" loaded, set 3774 rows 23 columns
# Data for "Domestic private health expenditure (PVT-D) per capita in US$" loaded, set 3774 rows 23 columns
# Data for "Domestic private health expenditure (PVT-D) as percentage of current health expenditure (CHE) (%)" loaded, set 3774 rows 23 columns
# Data for "National universal health coverage strategy" loaded, set 122 rows 23 columns
# ...
# Data for "Existence of legislation on access to assistive technology" loaded, set 560 rows 23 columns
# Data for "Proportion of isolates with resistance to azithromycin reported to WHO-GASP" loaded, set 425 rows 23 columns
# Data for "Prevalence of daily e-cigarette use among adolescents (%)" loaded, set 19 rows 23 columns
# Data for "Total number of surveillance sites reporting to GLASS" loaded, set 0 rows 23 columns
# Data for "Ambient air pollution attributable deaths in children under 15 years" loaded, set 549 rows 23 columns
# Data for "Ban on tobacco companies/the tobacco industry publicizing their CSR activities" loaded, set 1560 rows 23 columns
# Data for "Subnational smoking bans - at least one jurisdiction has a comprehensive ban in place" loaded, set 195 rows 23 columns
# Data for "Increase in poverty gap due to household health expenditures, expressed as a proportion of a relative poverty line (60% of median daily per capita consumption or income) (%)" loaded, set 1717 rows 23 columns
# Data for "Prevalence of anaemia in children aged 6–59 months (%)" loaded, set 20160 rows 23 columns
# Data for "Existence of evidence-based national guidelines/protocols/standards for the management of physical inactivity" loaded, set 194 rows 23 columns
# Data for "Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, crude" loaded, set 12120 rows 23 columns
# Data for "Existence of national policies on trans-fatty acid elimination" loaded, set 388 rows 23 columns
# Data for "Ban on entities other than tobacco companies/the tobacco industry publicizing the CSR activities of the tobacco companies/industry" loaded, set 1560 rows 23 columns
# Data for "Cheapest brand of cigarettes - price in US$ at official exchange rates" loaded, set 173 rows 23 columns
# Data for "Mean Non-HDL cholesterol, crude" loaded, set 10887 rows 23 columns
# Data for "Coverage of people in need of assistive technology by legislation" loaded, set 434 rows 23 columns
# Data for "Compliance with ban on sponsorship (contributions and/or publicity of contributions) (score)" loaded, set 195 rows 23 columns
# Data for "Compliance with ban on advertising on national television and radio (score)" loaded, set 195 rows 23 columns
# Data for "Cytisine - cost covered" loaded, set 585 rows 23 columns
# Data for "ICD-11 implementation progress level" loaded, set 98 rows 23 columns
# Data for "Reference level for workplaces (Bq/m3)" loaded, set 59 rows 23 columns
# Data for "Compliance with smoke-free public transport law (score)" loaded, set 195 rows 23 columns
# Data for "Nursing personnel (%)" loaded, set 982 rows 23 columns
# Data for "Mean total cholesterol,  age-standardized" loaded, set 10887 rows 23 columns
# Data for "Number of deaths among children ages 10 to 14 years" loaded, set 4095 rows 23 columns
# Data for "Has conducted a recent, national adult risk factor survey covering harmful alcohol use" loaded, set 194 rows 23 columns
# Data for "Year the law was enacted (latest revision)" loaded, set 107 rows 23 columns
# Data for "Number of malaria positive cases by rapid diagnostic test (RDT)" loaded, set 733 rows 23 columns
# Data for "Most sold brand of cigarettes - price in US$ at official exchange rates" loaded, set 1297 rows 23 columns
# Data for "Total population pushed  further below the $1.90 a day poverty line by household health expenditures (millions)" loaded, set 105 rows 23 columns
# Data for "Proportion of population with primary reliance on polluting fuels and technologies for cooking (%)" loaded, set 12033 rows 23 columns
# Data for "Implementation of a nutrition public awareness program" loaded, set 194 rows 23 columns
# Data for "Tax stamps, fiscal marks, banderole or other types of marking are applied on cigarettes" loaded, set 178 rows 23 columns
# Data for "Existence of a national target on tobacco" loaded, set 194 rows 23 columns
# Data for "Households pushed below or further below a relative poverty line (reflecting basic needs: food, housing, utilities) by out-of-pocket payments (%)" loaded, set 223 rows 23 columns
# Data for "Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude" loaded, set 12120 rows 23 columns
# Data for "Compliance with ban on appearance of tobacco brands in TV and/or films (score)" loaded, set 195 rows 23 columns
# Data for "General availability of Fixed dose combination avail (lisinopril + amlodipine) in the public health sector" loaded, set 194 rows 23 columns
# Data for "Number of malaria cases treated with any first  line tx courses (including artemisinin-based combination therapies (ACTs))" loaded, set 238 rows 23 columns
# Data for "Mean hemoglobin level of women of reproductive age (aged 15-49 years)" loaded, set 3900 rows 23 columns
# Data for "Has conducted a recent, national adult risk factor survey covering raised blood glucose/diabetes" loaded, set 194 rows 23 columns
# Data for "Existence of policy promoting physical activity: active ageing" loaded, set 194 rows 23 columns
# Data for "Number of deaths among children ages 5 to 9 years" loaded, set 4095 rows 23 columns
# Data for "Name of latest adult prevalence survey (nonsmoked)" loaded, set 142 rows 23 columns
# Data for "Existence of tax incentives to promote physical activity" loaded, set 194 rows 23 columns
# Data for "SDG 6.3.1 Proportion of safely treated domestic wastewater flows (%)" loaded, set 133 rows 23 columns
# Data for "Availability of government/registered services for assistive technology" loaded, set 490 rows 23 columns
# Data for "Number of confirmed yaws cases reported" loaded, set 440 rows 23 columns
# Data for "Total consumption of antibacterials expressed as DDD per 1000 inhabitants per day" loaded, set 87 rows 23 columns
# Data for "Full immunization coverage among one-year-olds (%)" loaded, set 12598 rows 23 columns
# Data for "Population pushed further below the $1.90 a day poverty line by household health expenditures (%)" loaded, set 1570 rows 23 columns
# Data for "Population with primary reliance on clean fuels and technologies for cooking (in millions)" loaded, set 12033 rows 23 columns
# Data for "General availability of radiotherapy in the public sector" loaded, set 194 rows 23 columns
# Data for "General availability of dilated fundus examination at the primary health care level" loaded, set 194 rows 23 columns
# Data for "Medical doctors (%)" loaded, set 1868 rows 23 columns
# Data for "Estimated malaria mortality rate (per 100 000 population)" loaded, set 2266 rows 23 columns
# Data for "Prevalence of current tobacco use among adolescents (%)" loaded, set 405 rows 23 columns
# Data for "Affordability – category of change 2010-2020 (Yes (less affordable), No (more affordable), No change)." loaded, set 174 rows 23 columns
# Data for "Age range of latest youth prevalence survey (nonsmoked)" loaded, set 165 rows 23 columns
# Data for "Existence of a national target on salt" loaded, set 194 rows 23 columns
# Data for "Obesity prevalence in non-pregnant women aged 15-49 years, BMI >= 30 (%)" loaded, set 11874 rows 23 columns
# Data for "Severe wasting prevalence in children aged < 5 years (%)" loaded, set 12598 rows 23 columns
# Data for "Existence of a national target on blood pressure / hypertension" loaded, set 194 rows 23 columns
# Data for "Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)" loaded, set 4095 rows 23 columns
# Data for "Availability of public funding for assistive technology" loaded, set 560 rows 23 columns
# Data for "Funding for assistive products (%)" loaded, set 308 rows 23 columns
# Data for "Year of most recent survey of adults" loaded, set 190 rows 23 columns
# Data for "Number of isolates tested for ciprofloxacin" loaded, set 543 rows 23 columns
# Data for "Prevalence of current tobacco smoking among adolescents (%)" loaded, set 292 rows 23 columns
# Data for "General availability of Fixed dose combination avail (telmisartan + amlodipine) in the public health sector" loaded, set 194 rows 23 columns
# Data for "Proportion of population with primary reliance on clean fuels and technologies for cooking (%)" loaded, set 12033 rows 23 columns
# Data for "General availability of Fixed dose combination avail (lisinopril + hydrochlorothiazide) in the public health sector" loaded, set 194 rows 23 columns
# Data for "Tax stamps, fiscal marks, banderole or other types of marking are applied on other tobacco products" loaded, set 169 rows 23 columns
# Data for "Pregnant women attending antenatal care  at least once and receiving at least 3 doses of Intermittent Preventive Treatment of Malaria for Pregnant Women (IPTp3) (%)" loaded, set 363 rows 23 columns
# Data for "Measles immunization coverage among one-year-olds (%)" loaded, set 12598 rows 23 columns
# Data for "Household air pollution attributable DALYs in children under 15 years" loaded, set 540 rows 23 columns
# Data for "Reported number of tests performed where results were received by a person (testing volume), reporting period" loaded, set 194 rows 23 columns
# Data for "Number of presumed malaria cases" loaded, set 1015 rows 23 columns
# Data for "Total population pushed below a relative poverty line by household health expenditures (60% of median daily per capita consumption or income) (%)" loaded, set 105 rows 23 columns
# Data for "Existence of operational policy/strategy/action plan to reduce overweight/obesity" loaded, set 194 rows 23 columns
# Data for "Title of most recent adolescent survey" loaded, set 192 rows 23 columns
# Data for "Pattern of antibiotic consumption at national level (relative consumption by AWaRe classification)" loaded, set 348 rows 23 columns
# Data for "Existence of evidence-based national guidelines/protocols/standards for the management of overweight/obesity" loaded, set 194 rows 23 columns
# Data for "General availability of combination budesonide formoterol inhaler in the public health sector" loaded, set 194 rows 23 columns
# Data for "Mean Non-HDL cholesterol, age-standardized" loaded, set 10887 rows 23 columns
# Data for "Number of suspected yaws cases reported" loaded, set 1218 rows 23 columns
# Data for "Existence of a national target on diabetes" loaded, set 194 rows 23 columns
# Data for "Has conducted a recent, national adult risk factor survey covering unhealthy diet" loaded, set 194 rows 23 columns
# Data for "Demand for family planning satisfied - use of modern methods (%)" loaded, set 11874 rows 23 columns
# Data for "Household air pollution attributable deaths in children under 15 years" loaded, set 540 rows 23 columns
# Data for "Number of isolates tested for azithromycin" loaded, set 425 rows 23 columns
# Data for "Prevalence of daily cigarette smoking among adults (%)" loaded, set 585 rows 23 columns
# Data for "Has conducted a recent, national adult risk factor survey covering salt/sodium intake" loaded, set 194 rows 23 columns
# Data for "Existence of regulations/standards/guidelines/protocols on assistive technology" loaded, set 559 rows 23 columns
# Data for "Estimate of current tobacco use prevalence (%) (age-standardized rate)" loaded, set 4596 rows 23 columns
# Data for "Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)" loaded, set 20162 rows 23 columns
# Data for "Total population pushed  further  below a relative poverty line by household health expenditures (60% of median daily per capita consumption or income) (%)" loaded, set 105 rows 23 columns
# Data for "Existence of national guidelines for physical activity" loaded, set 194 rows 23 columns
# Data for "Ban on advertising at point of sale" loaded, set 1560 rows 23 columns
# Data for "Households with out-of-pocket payments greater than 40% of capacity to pay for health care (food, housing and utilities approach - developed by WHO/Europe) (%)" loaded, set 223 rows 23 columns
# Data for "Prevalence of cervical cancer screening  among women aged 30-49 years (%)" loaded, set 780 rows 23 columns
# Data for "Prevalence of current e-cigarette use among adolescents (%)" loaded, set 258 rows 23 columns
# Data for "Prevalence of daily tobacco smoking among adults (%)" loaded, set 585 rows 23 columns
# Data for "Existence of evidence-based national guidelines/protocols/standards for the management of diabetes" loaded, set 194 rows 23 columns
# Data for "Number of people protected from malaria by indoor residual spraying (IRS)" loaded, set 273 rows 23 columns
# Data for "Ban on sale of duty-free or excise-free cigarettes" loaded, set 178 rows 23 columns
# Data for "Representativeness of most recent adolescent survey" loaded, set 192 rows 23 columns
# Data for "Prevalence of anaemia in pregnant women (aged 15-49) (%)" loaded, set 20162 rows 23 columns
# Data for "A minimum price policy is implemented" loaded, set 178 rows 23 columns
# Data for "Average of 13 International Health Regulations core capacity scores, SPAR version, 1st edition" loaded, set 582 rows 23 columns
# Data for "Compliance with smoke-free universities law (score)" loaded, set 195 rows 23 columns
# Data for "Polio immunization coverage among one-year-olds (%)" loaded, set 12598 rows 23 columns
# Data for "Mean hemoglobin level of non-pregnant women (aged 15-49 years)" loaded, set 3900 rows 23 columns
# Data for "Law requires fines for violations of advertising bans" loaded, set 1560 rows 23 columns
# Data for "Proportion of population with primary reliance on fuels and technologies for cooking, by fuel type (%)" loaded, set 60084 rows 23 columns
# Data for "Compliance with ban on use of brand name of non-tobacco product for tobacco product (score)" loaded, set 195 rows 23 columns
# Data for "General availability of foot vibration perception by tuning fork at the primary health care level" loaded, set 194 rows 23 columns
# Data for "Law requires fines for violations of promotion and sponsorship bans" loaded, set 1560 rows 23 columns
# Data for "Food Safety (SPAR)" loaded, set 529 rows 23 columns
# Data for "DTP3 immunization coverage among one-year-olds (%)" loaded, set 12598 rows 23 columns
# Data for "Existence of price subsidies for healthy foods" loaded, set 194 rows 23 columns
# Data for "New leprosy child case detection rate (less than 15 years of age) per 1 000 000 child population" loaded, set 1940 rows 23 columns
# Data for "Number of isolates tested for extended-spectrum cephalosporins" loaded, set 527 rows 23 columns
# Data for "Number of isolates tested for ceftriaxone" loaded, set 489 rows 23 columns
# Data for "Prevalence of use of assistive products (%)" loaded, set 1914 rows 23 columns
# Data for "Prevalence of daily tobacco use among adults (%)" loaded, set 585 rows 23 columns
# Data for "Age range of most recent survey of adults" loaded, set 190 rows 23 columns
# Data for "Total number of  malaria cases (presumed + confirmed cases)" loaded, set 1087 rows 23 columns
# Data for "Persistence to last grade of primary (% of cohort)" loaded, set 2409 rows 23 columns
# Data for "Existence of national radon action plan - Years covered" loaded, set 59 rows 23 columns
# Data for "Estimate of current tobacco smoking prevalence (%) (age-standardized rate)" loaded, set 4428 rows 23 columns
# Data for "General availability of alteplase for acute stroke management in the public health system" loaded, set 194 rows 23 columns
# Data for "Year of latest adult prevalence survey (nonsmoked)" loaded, set 142 rows 23 columns
# Data for "Existence of national guidelines for physical activity for adults" loaded, set 194 rows 23 columns
# Data for "Prevalence of daily e-cigarette use among adults (%)" loaded, set 585 rows 23 columns
# Data for "Overall compliance with regulations on smoke-free environments (score)" loaded, set 195 rows 23 columns
# Data for "Number of isolates tested for cefixime" loaded, set 322 rows 23 columns
# Data for "Best-practice policy implemented for industrially produced trans-fatty acids (TFA) (Y/N)" loaded, set 3686 rows 23 columns
# Data for "General availability of urine strips for glucose and ketone measurement at the primary health care level" loaded, set 194 rows 23 columns

# %%
lst
# Out:
# ['Camp_airtime',
#  'GHE_YLDRATE',
#  'M_def_1_prev_adult',
#  'M_def_1_prev_youth',
#  'M_def_1_text_adult',
#  'M_def_1_text_youth',
#  'M_def_2_prev_adult',
#  'M_def_2_prev_youth',
#  'M_def_2_text_adult',
#  'M_def_2_text_youth',
#  'M_smkless_age_range_adult',
#  'M_smkless_age_range_youth',
#  'M_smkless_def_text_adult',
#  'M_smkless_def_text_youth',
#  'M_smkless_prev_adult',
#  'M_smkless_prev_youth',
#  'M_smkless_survey_title_adult',
#  'M_smkless_survey_title_youth',
#  'M_smkless_svy_national_adult',
#  'M_smkless_svy_national_youth',
#  'M_survey_title_adult',
#  'M_survey_title_youth',
#  'M_svy_age_adult',
#  'M_svy_age_youth',
#  'M_svy_national_adult',
#  'M_svy_national_youth',
#  'R_admin_duty_free_allowance',
#  'R_admin_duty_free_limited',
#  'R_admin_tax_stamps',
#  'SA_0000001468',
#  'SA_0000001472',
#  'VIOLENCE_CHILD_EMOTIONAL',
#  'VIOLENCE_CHILD_NEGLECT',
#  'VIOLENCE_CHILD_PHYSICAL',
#  'VIOLENCE_CHILD_SEXUAL']

# %%
all_.to_csv(r'C:\Users\pabli\Desktop\Health-Database\data\full_data2.csv')

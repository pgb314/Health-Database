# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\pabli\Desktop\Health-Database\data\full_data.csv')

# %%
data
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0      country country_code  year  \
# 0                0             0           0  Afghanistan          AFG  2000
# 1                1             1           1  Afghanistan          AFG  2001
# 2                2             2           2  Afghanistan          AFG  2002
# 3                3             3           3  Afghanistan          AFG  2003
# 4                4             4           4  Afghanistan          AFG  2004
# ...            ...           ...         ...          ...          ...   ...
# 3575          3575          3575        3575     Zimbabwe          ZWE  2015
# 3576          3576          3576        3576     Zimbabwe          ZWE  2016
# 3577          3577          3577        3577     Zimbabwe          ZWE  2017
# 3578          3578          3578        3578     Zimbabwe          ZWE  2018
# 3579          3579          3579        3579     Zimbabwe          ZWE  2019
#
# ...

# %%
data.drop(columns= ['Unnamed: 0.2','Unnamed: 0.1','Unnamed: 0'],inplace=True)

# %%
data
# Out:
#           country country_code  year  Meningitis  \
# 0     Afghanistan          AFG  2000      3105.0
# 1     Afghanistan          AFG  2001      3063.0
# 2     Afghanistan          AFG  2002      2990.0
# 3     Afghanistan          AFG  2003      3300.0
# 4     Afghanistan          AFG  2004      3350.0
# ...           ...          ...   ...         ...
# 3575     Zimbabwe          ZWE  2015      1439.0
# 3576     Zimbabwe          ZWE  2016      1457.0
# 3577     Zimbabwe          ZWE  2017      1460.0
# 3578     Zimbabwe          ZWE  2018      1450.0
# 3579     Zimbabwe          ZWE  2019      1450.0
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                      1291.0                416.0
# 1                                      1300.0                424.0
# 2                                      1311.0                429.0
# 3                                      1326.0                434.0
# ...

# %%
data[data["Prevalence of daily tobacco smoking among adolescents (%)"].notna()== True]
# Out:
# Empty DataFrame
# ...

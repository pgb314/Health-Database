# %%
import pandas as pd

# %%
df= pd.read_csv("Total NCD Deaths (in thousands).csv")

# %%
df
# Out:
#       Unnamed: 0  Drug Use Disorders  per_capita-Interpersonal Violence  \
# 0              0           -0.116208                           0.502553
# 1              1           -0.112187                           0.497541
# 2              2           -0.108453                           0.471754
# 3              3           -0.105581                           0.451805
# 4              4           -0.103858                           0.449804
# ...          ...                 ...                                ...
# 3073        3073           -0.144354                           0.082638
# 3074        3074           -0.142631                           0.089316
# 3075        3075           -0.141195                           0.084170
# 3076        3076           -0.139472                           0.103851
# 3077        3077           -0.137748                           0.090990
#
#       per_capita-Cirrhosis and Other Chronic Liver Diseases  \
# 0                                             -0.538463
# 1                                             -0.568923
# 2                                             -0.582446
# 3                                             -0.611802
# 4                                             -0.652056
# ...                                                 ...
# 3073                                          -0.536253
# 3074                                          -0.558440
# 3075                                          -0.557470
# 3076                                          -0.544203
# 3077                                          -0.573490
#
#       Total NCD Deaths (in thousands)  \
# 0                            44342.73
# 1                            44521.91
# 2                            47583.46
# 3                            95631.12
# 4                            97079.55
# ...                               ...
# 3073                         26388.98
# 3074                         46639.99
# 3075                         25688.86
# 3076                         20001.77
# 3077                         20456.06
#
#       Crude suicide rates (per 100 000 population)
# 0                                        -0.462878
# 1                                        -0.496176
# 2                                        -0.459549
# 3                                        -0.530305
# 4                                        -0.538630
# ...                                            ...
# 3073                                      1.075725
# 3074                                      0.053255
# 3075                                     -0.109927
# 3076                                      0.745707
# 3077                                     -0.176521
#
# [3078 rows x 6 columns]

# %%
import os
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression as LinReg
from sklearn.linear_model import Lasso        # regularizacion L1
from sklearn.linear_model import Ridge        # regularizacion L2
from sklearn.linear_model import ElasticNet as Elastic

from sklearn.linear_model import LogisticRegression as LogReg

from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor as RFR  
from sklearn.tree import ExtraTreeRegressor as ETR
from sklearn.ensemble import GradientBoostingRegressor as GBR
from xgboost import XGBRegressor as XGBR
from catboost import CatBoostRegressor as CTR
from lightgbm import LGBMRegressor as LGBMR


# assign directory


directory = r'C:\Users\pabli\Desktop\Health-Database\data\thresh4_models'
mod = {"Adolescent birth rate (per 1000 women aged 15-19 years)":RFR(),
 "Age-standardized suicide rates (per 100 000 population)":Lasso(),
 "Estimates of rates of homicides per 100 000 population":RFR(),
 "Prevalence of controlled hypertension among adults aged 30-79 years with hypertension, age-standardized":RFR(),
 "Total NCD Deaths (in thousands)":Elastic()}


for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    if os.path.isfile(f):
        df = pd.read_csv(f)
        df1 = pd.read_csv(r"C:\Users\pabli\Desktop\Health-Database\data\clean_full_data.csv")
        lst = df1[filename.split(".c")[0]]
        print(lst[0])
        file = filename.split(".c")[0]
        df[file]=lst
        print(file)
        print(df[file][0])
        X = df.drop(columns=file)
        y = df[file]
        X_train, X_test, y_train, y_test = tts(X, y, train_size=0.8, test_size=0.2, random_state=42)
        mo = mod[file]
        mo.fit(X_train, y_train)
        pickle.dump(mo, open(f'model_{file}.pkl', 'wb'))

# %%
df = pd.read_csv(f"C:\\Users\\pabli\\Desktop\\Health-Database\\data\\thresh4_models\\Total NCD Deaths (in thousands).csv")

# %%
df
# Out:
#       Unnamed: 0  Drug Use Disorders  per_capita-Interpersonal Violence  \
# 0              0           -0.116208                           0.502553
# 1              1           -0.112187                           0.497541
# 2              2           -0.108453                           0.471754
# 3              3           -0.105581                           0.451805
# 4              4           -0.103858                           0.449804
# ...          ...                 ...                                ...
# 3073        3073           -0.144354                           0.082638
# 3074        3074           -0.142631                           0.089316
# 3075        3075           -0.141195                           0.084170
# 3076        3076           -0.139472                           0.103851
# 3077        3077           -0.137748                           0.090990
#
#       per_capita-Cirrhosis and Other Chronic Liver Diseases  \
# 0                                             -0.538463
# 1                                             -0.568923
# 2                                             -0.582446
# 3                                             -0.611802
# 4                                             -0.652056
# ...                                                 ...
# 3073                                          -0.536253
# 3074                                          -0.558440
# 3075                                          -0.557470
# 3076                                          -0.544203
# 3077                                          -0.573490
#
#       Total NCD Deaths (in thousands)  \
# 0                            44342.73
# 1                            44521.91
# 2                            47583.46
# 3                            95631.12
# 4                            97079.55
# ...                               ...
# 3073                         26388.98
# 3074                         46639.99
# 3075                         25688.86
# 3076                         20001.77
# 3077                         20456.06
#
#       Crude suicide rates (per 100 000 population)
# 0                                        -0.462878
# 1                                        -0.496176
# 2                                        -0.459549
# 3                                        -0.530305
# 4                                        -0.538630
# ...                                            ...
# 3073                                      1.075725
# 3074                                      0.053255
# 3075                                     -0.109927
# 3076                                      0.745707
# 3077                                     -0.176521
#
# [3078 rows x 6 columns]

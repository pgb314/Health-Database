# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\pabli\Desktop\Health-Database\data\clean_full_data.csv')

# %%
data = data.copy()

# %%
data.columns[:4]
# Out:
# Index(['Unnamed: 0', 'country', 'country_code', 'year'], dtype='object')

# %%
data
# Out:
#       Meningitis  Alzheimer's Disease and Other Dementias  \
# 0         2990.0                                   1311.0
# 1         3300.0                                   1326.0
# 2         3350.0                                   1344.0
# 3         3238.0                                   1362.0
# 4         3098.0                                   1381.0
# ...          ...                                      ...
# 3073      1439.0                                    754.0
# 3074      1457.0                                    767.0
# 3075      1460.0                                    781.0
# 3076      1450.0                                    795.0
# 3077      1450.0                                    812.0
#
#       Parkinson's Disease  Nutritional Deficiencies  Malaria  Drowning  \
# 0                   429.0                    2795.0   2883.0    1980.0
# 1                   434.0                    3039.0   2188.0    2282.0
# 2                   439.0                    3033.0    773.0    2386.0
# 3                   442.0                    2879.0    545.0    2315.0
# 4                   446.0                    2727.0    414.0    2235.0
# ...                   ...                       ...      ...       ...
# 3073                215.0                    3019.0   2518.0     770.0
# 3074                219.0                    3056.0   2050.0     801.0
# 3075                223.0                    2990.0   2116.0     818.0
# 3076                227.0                    2918.0   2088.0     825.0
# 3077                232.0                    2884.0   2068.0     827.0
#
#       Interpersonal Violence  Maternal Disorders  HIV/AIDS  \
# 0                     3277.0              4498.0     111.0
# 1                     3458.0              4702.0     118.0
# 2                     3479.0              4799.0     125.0
# 3                     3506.0              4936.0     132.0
# 4                     3609.0              4884.0     140.0
# ...                      ...                 ...       ...
# 3073                  1302.0              1355.0   29162.0
# 3074                  1342.0              1338.0   27141.0
# 3075                  1363.0              1312.0   24846.0
# 3076                  1396.0              1294.0   22106.0
# 3077                  1434.0              1294.0   20722.0
#
#       Drug Use Disorders  Tuberculosis  Cardiovascular Diseases  \
# 0                  202.0        5660.0                  54213.0
# 1                  216.0        5676.0                  54274.0
# 2                  229.0        5607.0                  54438.0
# 3                  239.0        5403.0                  54196.0
# 4                  245.0        5203.0                  54080.0
# ...                  ...           ...                      ...
# 3073               104.0       11214.0                  16649.0
# 3074               110.0       10998.0                  16937.0
# 3075               115.0       10762.0                  17187.0
# 3076               121.0       10545.0                  17460.0
# 3077               127.0       10465.0                  17810.0
#
#       Lower Respiratory Infections  Neonatal Disorders  Alcohol Use Disorders  \
# 0                          30346.0             23976.0                  101.0
# 1                          32361.0             24628.0                  104.0
# 2                          32222.0             24780.0                  107.0
# 3                          30898.0             24725.0                  109.0
# 4                          29406.0             24229.0                  110.0
# ...                            ...                 ...                    ...
# 3073                       12974.0              9278.0                   48.0
# 3074                       13024.0              9065.0                   49.0
# 3075                       12961.0              8901.0                   50.0
# 3076                       12860.0              8697.0                   51.0
# 3077                       12897.0              8609.0                   53.0
#
#       Self-harm  Exposure to Forces of Nature  Diarrheal Diseases  \
# 0        1190.0                        1286.0             11393.0
# 1        1235.0                         137.0             12348.0
# 2        1283.0                          18.0             12258.0
# 3        1300.0                         561.0             11532.0
# 4        1303.0                         382.0             10356.0
# ...         ...                           ...                 ...
# 3073     2235.0                          16.0              5102.0
# 3074     2296.0                          31.0              5002.0
# 3075     2338.0                         251.0              4948.0
# 3076     2372.0                           0.0              4745.0
# 3077     2403.0                         660.0              4635.0
#
#       Environmental Heat and Cold Exposure  Neoplasms  Conflict and Terrorism  \
# 0                                     53.0    14437.0                   977.0
# 1                                     55.0    14951.0                   864.0
# 2                                     57.0    15360.0                  1049.0
# 3                                     78.0    15556.0                  2114.0
# 4                                     57.0    15724.0                  5677.0
# ...                                    ...        ...                     ...
# 3073                                  37.0    11161.0                    13.0
# 3074                                  37.0    11465.0                     6.0
# 3075                                  37.0    11744.0                     5.0
# 3076                                  37.0    12038.0                     9.0
# 3077                                  37.0    12353.0                    11.0
#
#       Diabetes Mellitus  Chronic Kidney Disease  Poisonings  \
# 0                2745.0                  4239.0       490.0
# 1                2865.0                  4336.0       531.0
# 2                2986.0                  4413.0       547.0
# 3                3070.0                  4431.0       540.0
# 4                3130.0                  4461.0       527.0
# ...                 ...                     ...         ...
# 3073             3176.0                  2108.0       381.0
# 3074             3259.0                  2160.0       393.0
# 3075             3313.0                  2196.0       398.0
# 3076             3381.0                  2240.0       400.0
# 3077             3460.0                  2292.0       405.0
#
#       Protein-Energy Malnutrition  Road Injuries  \
# 0                          2746.0         6696.0
# 1                          2984.0         7243.0
# 2                          2978.0         7522.0
# 3                          2824.0         7577.0
# 4                          2675.0         7484.0
# ...                           ...            ...
# 3073                       2990.0         2373.0
# 3074                       3027.0         2436.0
# 3075                       2962.0         2473.0
# 3076                       2890.0         2509.0
# 3077                       2855.0         2554.0
#
#       Chronic Respiratory Diseases  \
# 0                           7455.0
# 1                           7471.0
# 2                           7477.0
# 3                           7391.0
# 4                           7310.0
# ...                            ...
# 3073                        2751.0
# 3074                        2788.0
# 3075                        2818.0
# 3076                        2849.0
# 3077                        2891.0
#
#       Cirrhosis and Other Chronic Liver Diseases  Digestive Diseases  \
# 0                                         3238.0              6246.0
# 1                                         3342.0              6443.0
# 2                                         3394.0              6541.0
# 3                                         3388.0              6528.0
# 4                                         3366.0              6494.0
# ...                                          ...                 ...
# 3073                                      1956.0              4202.0
# 3074                                      1962.0              4264.0
# 3075                                      2007.0              4342.0
# 3076                                      2030.0              4377.0
# 3077                                      2065.0              4437.0
#
#       Fire, Heat, and Hot Substances  Acute Hepatitis  population  \
# 0                              455.0           4251.0  23600088.0
# 1                              499.0           4373.0  25005388.0
# 2                              516.0           4345.0  25697636.0
# 3                              507.0           4194.0  26334702.0
# 4                              496.0           3870.0  27154386.0
# ...                              ...              ...         ...
# 3073                           632.0            146.0  14229541.0
# 3074                           648.0            146.0  14546961.0
# 3075                           654.0            144.0  14868131.0
# 3076                           657.0            139.0  14868131.0
# 3077                           662.0            136.0  15512471.0
#
#       per_capita-Meningitis  \
# 0                  0.000127
# 1                  0.000132
# 2                  0.000130
# 3                  0.000123
# 4                  0.000114
# ...                     ...
# 3073               0.000101
# 3074               0.000100
# 3075               0.000098
# 3076               0.000098
# 3077               0.000093
#
#       per_capita-Alzheimer's Disease and Other Dementias  \
# 0                                              0.000056
# 1                                              0.000053
# 2                                              0.000052
# 3                                              0.000052
# 4                                              0.000051
# ...                                                 ...
# 3073                                           0.000053
# 3074                                           0.000053
# 3075                                           0.000053
# 3076                                           0.000053
# 3077                                           0.000052
#
#       per_capita-Parkinson's Disease  per_capita-Nutritional Deficiencies  \
# 0                           0.000018                             0.000118
# 1                           0.000017                             0.000122
# 2                           0.000017                             0.000118
# 3                           0.000017                             0.000109
# 4                           0.000016                             0.000100
# ...                              ...                                  ...
# 3073                        0.000015                             0.000212
# 3074                        0.000015                             0.000210
# 3075                        0.000015                             0.000201
# 3076                        0.000015                             0.000196
# 3077                        0.000015                             0.000186
#
#       per_capita-Malaria  per_capita-Drowning  \
# 0               0.000122             0.000084
# 1               0.000088             0.000091
# 2               0.000030             0.000093
# 3               0.000021             0.000088
# 4               0.000015             0.000082
# ...                  ...                  ...
# 3073            0.000177             0.000054
# 3074            0.000141             0.000055
# 3075            0.000142             0.000055
# 3076            0.000140             0.000055
# 3077            0.000133             0.000053
#
#       per_capita-Interpersonal Violence  per_capita-Maternal Disorders  \
# 0                              0.000139                       0.000191
# 1                              0.000138                       0.000188
# 2                              0.000135                       0.000187
# 3                              0.000133                       0.000187
# 4                              0.000133                       0.000180
# ...                                 ...                            ...
# 3073                           0.000091                       0.000095
# 3074                           0.000092                       0.000092
# 3075                           0.000092                       0.000088
# 3076                           0.000094                       0.000087
# 3077                           0.000092                       0.000083
#
#       per_capita-HIV/AIDS  per_capita-Drug Use Disorders  \
# 0                0.000005                       0.000009
# 1                0.000005                       0.000009
# 2                0.000005                       0.000009
# 3                0.000005                       0.000009
# 4                0.000005                       0.000009
# ...                   ...                            ...
# 3073             0.002049                       0.000007
# 3074             0.001866                       0.000008
# 3075             0.001671                       0.000008
# 3076             0.001487                       0.000008
# 3077             0.001336                       0.000008
#
#       per_capita-Tuberculosis  per_capita-Cardiovascular Diseases  \
# 0                    0.000240                            0.002297
# 1                    0.000227                            0.002170
# 2                    0.000218                            0.002118
# 3                    0.000205                            0.002058
# 4                    0.000192                            0.001992
# ...                       ...                                 ...
# 3073                 0.000788                            0.001170
# 3074                 0.000756                            0.001164
# 3075                 0.000724                            0.001156
# 3076                 0.000709                            0.001174
# 3077                 0.000675                            0.001148
#
#       per_capita-Lower Respiratory Infections  per_capita-Neonatal Disorders  \
# 0                                    0.001286                       0.001016
# 1                                    0.001294                       0.000985
# 2                                    0.001254                       0.000964
# 3                                    0.001173                       0.000939
# 4                                    0.001083                       0.000892
# ...                                       ...                            ...
# 3073                                 0.000912                       0.000652
# 3074                                 0.000895                       0.000623
# 3075                                 0.000872                       0.000599
# 3076                                 0.000865                       0.000585
# 3077                                 0.000831                       0.000555
#
#       per_capita-Alcohol Use Disorders  per_capita-Self-harm  \
# 0                             0.000004              0.000050
# 1                             0.000004              0.000049
# 2                             0.000004              0.000050
# 3                             0.000004              0.000049
# 4                             0.000004              0.000048
# ...                                ...                   ...
# 3073                          0.000003              0.000157
# 3074                          0.000003              0.000158
# 3075                          0.000003              0.000157
# 3076                          0.000003              0.000160
# 3077                          0.000003              0.000155
#
#       per_capita-Exposure to Forces of Nature  per_capita-Diarrheal Diseases  \
# 0                                5.449132e-05                       0.000483
# 1                                5.478819e-06                       0.000494
# 2                                7.004535e-07                       0.000477
# 3                                2.130269e-05                       0.000438
# 4                                1.406771e-05                       0.000381
# ...                                       ...                            ...
# 3073                             1.124421e-06                       0.000359
# 3074                             2.131029e-06                       0.000344
# 3075                             1.688175e-05                       0.000333
# 3076                             0.000000e+00                       0.000319
# 3077                             4.254641e-05                       0.000299
#
#       per_capita-Environmental Heat and Cold Exposure  per_capita-Neoplasms  \
# 0                                            0.000002              0.000612
# 1                                            0.000002              0.000598
# 2                                            0.000002              0.000598
# 3                                            0.000003              0.000591
# 4                                            0.000002              0.000579
# ...                                               ...                   ...
# 3073                                         0.000003              0.000784
# 3074                                         0.000003              0.000788
# 3075                                         0.000002              0.000790
# 3076                                         0.000002              0.000810
# 3077                                         0.000002              0.000796
#
#       per_capita-Conflict and Terrorism  per_capita-Diabetes Mellitus  \
# 0                          4.139815e-05                      0.000116
# 1                          3.455255e-05                      0.000115
# 2                          4.082088e-05                      0.000116
# 3                          8.027431e-05                      0.000117
# 4                          2.090638e-04                      0.000115
# ...                                 ...                           ...
# 3073                       9.135924e-07                      0.000223
# 3074                       4.124573e-07                      0.000224
# 3075                       3.362897e-07                      0.000223
# 3076                       6.053215e-07                      0.000227
# 3077                       7.091069e-07                      0.000223
#
#       per_capita-Chronic Kidney Disease  per_capita-Poisonings  \
# 0                              0.000180               0.000021
# 1                              0.000173               0.000021
# 2                              0.000172               0.000021
# 3                              0.000168               0.000021
# 4                              0.000164               0.000019
# ...                                 ...                    ...
# 3073                           0.000148               0.000027
# 3074                           0.000148               0.000027
# 3075                           0.000148               0.000027
# 3076                           0.000151               0.000027
# 3077                           0.000148               0.000026
#
#       per_capita-Protein-Energy Malnutrition  per_capita-Road Injuries  \
# 0                                   0.000116                  0.000284
# 1                                   0.000119                  0.000290
# 2                                   0.000116                  0.000293
# 3                                   0.000107                  0.000288
# 4                                   0.000099                  0.000276
# ...                                      ...                       ...
# 3073                                0.000210                  0.000167
# 3074                                0.000208                  0.000167
# 3075                                0.000199                  0.000166
# 3076                                0.000194                  0.000169
# 3077                                0.000184                  0.000165
#
#       per_capita-Chronic Respiratory Diseases  \
# 0                                    0.000316
# 1                                    0.000299
# 2                                    0.000291
# 3                                    0.000281
# 4                                    0.000269
# ...                                       ...
# 3073                                 0.000193
# 3074                                 0.000192
# 3075                                 0.000190
# 3076                                 0.000192
# 3077                                 0.000186
#
#       per_capita-Cirrhosis and Other Chronic Liver Diseases  \
# 0                                              0.000137
# 1                                              0.000134
# 2                                              0.000132
# 3                                              0.000129
# 4                                              0.000124
# ...                                                 ...
# 3073                                           0.000137
# 3074                                           0.000135
# 3075                                           0.000135
# 3076                                           0.000137
# 3077                                           0.000133
#
#       per_capita-Digestive Diseases  \
# 0                          0.000265
# 1                          0.000258
# 2                          0.000255
# 3                          0.000248
# 4                          0.000239
# ...                             ...
# 3073                       0.000295
# 3074                       0.000293
# 3075                       0.000292
# 3076                       0.000294
# 3077                       0.000286
#
#       per_capita-Fire, Heat, and Hot Substances  per_capita-Acute Hepatitis  \
# 0                                      0.000019                    0.000180
# 1                                      0.000020                    0.000175
# 2                                      0.000020                    0.000169
# 3                                      0.000019                    0.000159
# 4                                      0.000018                    0.000143
# ...                                         ...                         ...
# 3073                                   0.000044                    0.000010
# 3074                                   0.000045                    0.000010
# 3075                                   0.000044                    0.000010
# 3076                                   0.000044                    0.000009
# 3077                                   0.000043                    0.000009
#
#                gdp   gdp/percap  \
# 0     5.146000e+09   218.050034
# 1     6.167000e+09   246.626847
# 2     6.925000e+09   269.480041
# 3     8.556000e+09   324.894506
# 4     1.029700e+10   379.202093
# ...            ...          ...
# 3073  1.996900e+10  1403.348147
# 3074  2.055500e+10  1413.009906
# 3075  2.138500e+10  1438.311244
# 3076  3.694500e+10  2484.844934
# 3077  2.299500e+10  1482.355712
#
#       Raised blood pressure (SBP>=140 OR DBP>=90) (age-standardized estimate)  \
# 0                                                29.500
# 1                                                29.700
# 2                                                29.800
# 3                                                29.900
# 4                                                30.000
# ...                                                 ...
# 3073                                             28.200
# 3074                                             28.875
# 3075                                             28.875
# 3076                                             28.875
# 3077                                             28.875
#
#       Mean systolic blood pressure (age-standardized estimate)  \
# 0                                              123.4000
# 1                                              123.5000
# 2                                              123.7000
# 3                                              123.8000
# 4                                              124.0000
# ...                                                 ...
# 3073                                           128.7000
# 3074                                           128.9875
# 3075                                           128.9875
# 3076                                           128.9875
# 3077                                           128.9875
#
#       Mortality rate for 5-14 year-olds (probability of dying per 1000 children aged 5-14 years)  \
# 0                                               9.59386
# 1                                               9.41968
# 2                                               9.42410
# 3                                               9.55693
# 4                                               9.78268
# ...                                                 ...
# 3073                                           13.28315
# 3074                                           12.88704
# 3075                                           12.52253
# 3076                                           12.19367
# 3077                                           11.85089
#
#       Number of under-five deaths  Number of infant deaths  \
# 0                         66148.0                  48423.0
# 1                         65461.0                  47951.0
# 2                         64442.0                  47308.0
# 3                         63207.0                  46519.0
# 4                         61810.0                  45608.0
# ...                           ...                      ...
# 3073                      15686.0                  10986.0
# 3074                      14884.0                  10487.0
# 3075                      14289.0                  10085.0
# 3076                      13528.0                   9624.0
# 3077                      13172.0                   9303.0
#
#       Number of neonatal deaths  \
# 0                       62635.0
# 1                       62483.0
# 2                       62215.0
# 3                       61677.0
# 4                       60907.0
# ...                         ...
# 3073                    12974.0
# 3074                    12588.0
# 3075                    12170.0
# 3076                    11792.0
# 3077                    11436.0
#
#       Current health expenditure (CHE) per capita in PPP int$  \
# 0                                                 81.27
# 1                                                 82.46
# 2                                                 89.47
# 3                                                100.71
# 4                                                113.75
# ...                                                 ...
# 3073                                             199.68
# 3074                                             215.40
# 3075                                             226.21
# 3076                                             269.20
# 3077                                             208.41
#
#       Current health expenditure (CHE) per capita in US$  \
# 0                                                 15.80
# 1                                                 17.04
# 2                                                 20.41
# 3                                                 23.89
# 4                                                 27.84
# ...                                                 ...
# 3073                                             107.69
# 3074                                             112.41
# 3075                                             115.65
# 3076                                             141.37
# 3077                                             103.03
#
#       Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)  \
# 0                                                  9.44
# 1                                                  8.94
# 2                                                  9.81
# 3                                                  9.95
# 4                                                 10.62
# ...                                                 ...
# 3073                                               7.45
# 3074                                               7.68
# 3075                                               7.47
# 3076                                               8.68
# 3077                                               7.70
#
#       Domestic general government health expenditure (GGHE-D) per capita in PPP int$  \
# 0                                                  0.72
# 1                                                  6.00
# 2                                                  4.95
# 3                                                  5.36
# 4                                                  5.33
# ...                                                 ...
# 3073                                              41.57
# 3074                                              50.21
# 3075                                              54.33
# 3076                                              86.31
# 3077                                              36.75
#
#       Domestic general government health expenditure (GGHE-D) per capita in US$  \
# 0                                                  0.14
# 1                                                  1.24
# 2                                                  1.13
# 3                                                  1.27
# 4                                                  1.30
# ...                                                 ...
# 3073                                              22.42
# 3074                                              26.20
# 3075                                              27.78
# 3076                                              45.32
# 3077                                              18.17
#
#       Domestic general government health expenditure (GGHE-D) as percentage of current health expenditure (CHE) (%)  \
# 0                                                  0.89
# 1                                                  7.28
# 2                                                  5.54
# 3                                                  5.32
# 4                                                  4.69
# ...                                                 ...
# 3073                                              20.82
# 3074                                              23.31
# 3075                                              24.02
# 3076                                              32.06
# 3077                                              17.63
#
#       Domestic general government health expenditure (GGHE-D) as percentage of gross domestic product (GDP) (%)  \
# 0                                                  0.08
# 1                                                  0.65
# 2                                                  0.54
# 3                                                  0.53
# 4                                                  0.50
# ...                                                 ...
# 3073                                               1.55
# 3074                                               1.79
# 3075                                               1.79
# 3076                                               2.78
# 3077                                               1.36
#
#       Domestic general government health expenditure (GGHE-D) as percentage of general government expenditure (GGE) (%)  \
# 0                                                  1.21
# 1                                                  5.46
# 2                                                  3.60
# 3                                                  3.37
# 4                                                  2.72
# ...                                                 ...
# 3073                                               7.56
# 3074                                               7.56
# 3075                                               6.44
# 3076                                               8.73
# 3077                                               8.73
#
#       Out-of-pocket expenditure (OOP) per capita in PPP int$  \
# 0                                                 69.39
# 1                                                 70.97
# 2                                                 75.63
# 3                                                 79.53
# 4                                                 87.39
# ...                                                 ...
# 3073                                              51.49
# 3074                                              50.21
# 3075                                              51.59
# 3076                                              53.02
# 3077                                              50.80
#
#       Out-of-pocket expenditure (OOP) per capita in US$  \
# 0                                                 13.49
# 1                                                 14.66
# 2                                                 17.25
# 3                                                 18.87
# 4                                                 21.39
# ...                                                 ...
# 3073                                              27.77
# 3074                                              26.20
# 3075                                              26.37
# 3076                                              27.85
# 3077                                              25.11
#
#       Out-of-pocket expenditure as percentage of current health expenditure (CHE) (%)  \
# 0                                                 85.38
# 1                                                 86.07
# 2                                                 84.53
# 3                                                 78.97
# 4                                                 76.82
# ...                                                 ...
# 3073                                              25.79
# 3074                                              23.31
# 3075                                              22.81
# 3076                                              19.70
# 3077                                              24.38
#
#       Domestic private health expenditure (PVT-D) per capita in PPP int$  \
# 0                                                 69.39
# 1                                                 70.97
# 2                                                 75.63
# 3                                                 79.53
# 4                                                 87.39
# ...                                                 ...
# 3073                                             109.67
# 3074                                             105.08
# 3075                                             102.42
# 3076                                             115.13
# 3077                                             110.07
#
#       Domestic private health expenditure (PVT-D) per capita in US$  \
# 0                                                 13.49
# 1                                                 14.66
# 2                                                 17.25
# 3                                                 18.87
# 4                                                 21.39
# ...                                                 ...
# 3073                                              59.15
# 3074                                              54.84
# 3075                                              52.36
# 3076                                              60.46
# 3077                                              54.41
#
#       Domestic private health expenditure (PVT-D) as percentage of current health expenditure (CHE) (%)  \
# 0                                                 85.38
# 1                                                 86.07
# 2                                                 84.53
# 3                                                 78.97
# 4                                                 76.82
# ...                                                 ...
# 3073                                              54.93
# 3074                                              48.78
# 3075                                              45.28
# 3076                                              42.77
# 3077                                              52.81
#
#       Medical doctors (per 10,000)  \
# 0                         2.357733
# 1                         2.357733
# 2                         2.357733
# 3                         2.357733
# 4                         1.596000
# ...                            ...
# 3073                      1.815000
# 3074                      1.788000
# 3075                      1.859000
# 3076                      2.096000
# 3077                      1.275333
#
#       Nursing and midwifery personnel (per 10,000)  \
# 0                                           3.5630
# 1                                           3.5630
# 2                                           3.5630
# 3                                           5.8200
# 4                                           4.4000
# ...                                            ...
# 3073                                       13.8250
# 3074                                       14.0000
# 3075                                       25.9720
# 3076                                       19.3460
# 3077                                       14.5366
#
#       Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)  \
# 0                                              90.06387
# 1                                              87.29221
# 2                                              84.55224
# 3                                              81.71863
# 4                                              78.91795
# ...                                                 ...
# 3073                                           46.55127
# 3074                                           45.12611
# 3075                                           44.18795
# 3076                                           42.90252
# 3077                                           42.14792
#
#       Adolescent birth rate (per 1000 women aged 15-19 years)  \
# 0                                             12.300000
# 1                                              8.100000
# 2                                            135.700000
# 3                                              8.200000
# 4                                              4.300000
# ...                                                 ...
# 3073                                           1.633333
# 3074                                           1.200000
# 3075                                           1.100000
# 3076                                           1.633333
# 3077                                           1.633333
#
#       Under-five mortality rate (probability of dying by age 5 per 1000 live births)  \
# 0                                             125.00544
# 1                                             120.83735
# 2                                             116.57782
# 3                                             112.25100
# 4                                             107.98572
# ...                                                 ...
# 3073                                           66.31459
# 3074                                           63.56478
# 3075                                           61.91988
# 3076                                           59.56721
# 3077                                           58.92604
#
#       Deaths due to tuberculosis among HIV-negative people (per 100 000 population)  \
# 0                                                  57.0
# 1                                                  58.0
# 2                                                  51.0
# 3                                                  47.0
# 4                                                  43.0
# ...                                                 ...
# 3073                                                7.9
# 3074                                                8.6
# 3075                                                8.3
# 3076                                                7.7
# 3077                                               11.0
#
#       Incidence of tuberculosis (per 100 000 population per year)  \
# 0                                                 189.0
# 1                                                 189.0
# ...
# ...                                                 ...
# 3073                                               29.1
# 3074                                               28.9
# 3075                                               28.8
# 3076                                               28.8
# 3077                                               28.9
#
#       Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, age-standardized  \
# 0                                                  21.8
# 1                                                  22.6
# 2                                                  23.5
# 3                                                  24.3
# 4                                                  25.2
# ...                                                 ...
# 3073                                               24.1
# 3074                                               24.9
# 3075                                               25.8
# 3076                                               26.6
# 3077                                               27.5
#
#       Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)  \
# 0                                                1650.0
# 1                                                1740.0
# 2                                                1830.0
# 3                                                1920.0
# 4                                                1990.0
# ...                                                 ...
# 3073                                             1050.0
# 3074                                             1050.0
# 3075                                             1060.0
# 3076                                             1080.0
# 3077                                             1100.0
#
#       Number of children aged 6–59 months with anaemia (thousands)  \
# 0                                                2170.0
# 1                                                2190.0
# 2                                                2210.0
# 3                                                2230.0
# 4                                                2260.0
# ...                                                 ...
# 3073                                              941.0
# 3074                                              923.0
# 3075                                              892.0
# 3076                                              846.0
# 3077                                              808.0
#
#       Number of pregnant women (aged 15-49 years) with anaemia (thousands)  \
# 0                                                 297.0
# 1                                                 299.0
# 2                                                 301.0
# 3                                                 302.0
# 4                                                 302.0
# ...                                                 ...
# 3073                                               95.2
# 3074                                               93.0
# 3075                                               90.6
# 3076                                               88.6
# 3077                                               86.9
#
#       Prevalence of anaemia in children aged 6–59 months (%)  \
# 0                                                  48.3
# 1                                                  47.1
# 2                                                  46.2
# 3                                                  45.5
# 4                                                  44.9
# ...                                                 ...
# 3073                                               41.7
# 3074                                               40.5
# 3075                                               39.6
# 3076                                               38.5
# 3077                                               37.8
#
#       Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, crude  \
# 0                                                  20.5
# 1                                                  21.2
# 2                                                  22.0
# 3                                                  22.8
# 4                                                  23.6
# ...                                                 ...
# 3073                                               20.3
# 3074                                               21.0
# 3075                                               21.8
# 3076                                               22.6
# 3077                                               23.5
#
#       Mean total cholesterol,  age-standardized  \
# 0                                      4.300000
# 1                                      4.300000
# 2                                      4.300000
# 3                                      4.200000
# 4                                      4.200000
# ...                                         ...
# 3073                                   4.000000
# 3074                                   4.000000
# 3075                                   4.000000
# 3076                                   4.000000
# 3077                                   4.044444
#
#       Number of deaths among children ages 10 to 14 years  \
# 0                                                2744.0
# 1                                                2789.0
# 2                                                2851.0
# 3                                                2926.0
# 4                                                3037.0
# ...                                                 ...
# 3073                                             2896.0
# 3074                                             3040.0
# 3075                                             3172.0
# 3076                                             3290.0
# 3077                                             3389.0
#
#       Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude  \
# 0                                                  28.2
# 1                                                  28.9
# 2                                                  29.6
# 3                                                  30.3
# 4                                                  31.1
# ...                                                 ...
# 3073                                               30.2
# 3074                                               31.0
# 3075                                               31.9
# 3076                                               32.9
# 3077                                               33.9
#
#       Mean hemoglobin level of women of reproductive age (aged 15-49 years)  \
# 0                                                 123.0
# 1                                                 123.0
# 2                                                 123.0
# 3                                                 123.0
# 4                                                 123.0
# ...                                                 ...
# 3073                                              126.0
# 3074                                              126.0
# 3075                                              126.0
# 3076                                              126.0
# 3077                                              126.0
#
#       Number of deaths among children ages 5 to 9 years  \
# 0                                                4420.0
# 1                                                4532.0
# 2                                                4676.0
# 3                                                4821.0
# 4                                                5047.0
# ...                                                 ...
# 3073                                             2229.0
# 3074                                             2094.0
# 3075                                             1997.0
# 3076                                             1921.0
# 3077                                             1858.0
#
#       Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)  \
# 0                                               4.67688
# 1                                               4.55469
# 2                                               4.47444
# 3                                               4.43099
# 4                                               4.44194
# ...                                                 ...
# 3073                                            8.60679
# 3074                                            8.84993
# 3075                                            8.99209
# 3076                                            9.06009
# 3077                                            9.05888
#
#       Mean Non-HDL cholesterol, age-standardized  \
# 0                                       3.100000
# 1                                       3.100000
# 2                                       3.100000
# 3                                       3.100000
# 4                                       3.100000
# ...                                          ...
# 3073                                    2.900000
# 3074                                    2.900000
# 3075                                    2.800000
# 3076                                    2.800000
# 3077                                    2.877778
#
#       Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)  \
# 0                                                1360.0
# 1                                                1440.0
# 2                                                1530.0
# 3                                                1620.0
# 4                                                1690.0
# ...                                                 ...
# 3073                                              950.0
# 3074                                              959.0
# 3075                                              971.0
# 3076                                              989.0
# 3077                                             1010.0
#
#       Prevalence of anaemia in pregnant women (aged 15-49) (%)  \
# 0                                                  43.4
# 1                                                  42.9
# 2                                                  42.4
# 3                                                  41.9
# 4                                                  41.4
# ...                                                 ...
# 3073                                               32.4
# 3074                                               32.2
# 3075                                               32.0
# 3076                                               31.8
# 3077                                               31.7
#
#       Mean hemoglobin level of non-pregnant women (aged 15-49 years)  \
# 0                                                 125.0
# 1                                                 124.0
# 2                                                 124.0
# 3                                                 124.0
# 4                                                 124.0
# ...                                                 ...
# 3073                                              127.0
# 3074                                              127.0
# 3075                                              127.0
# 3076                                              127.0
# 3077                                              127.0
#
#       average_age  num_nan
# 0        16.77425       19
# 1        16.77425       19
# 2        16.77425       18
# 3        16.49000       15
# 4        16.77425        9
# ...           ...      ...
# 3073     20.70300       10
# 3074     19.04000       15
# 3075     19.04000       19
# 3076     19.04000       24
# 3077     19.04000       33
#
# [3078 rows x 153 columns]

# %%
data.drop(columns = data.columns[:4], inplace = True)

# %%
lis = ["Hospital beds (per 10 000 population)","Mean total cholesterol, age-standardized","Stillbirth rate (per 1000 total births)","Mean BMI (kg/m²) (age-standardized estimate)"]

# %%
target_alz=data1.drop("per_capita-Alzheimer's Disease and Other Dementias", axis=1).apply(lambda x: x.corr(data1["per_capita-Alzheimer's Disease and Other Dementias"]))

# %%
target_alz
# Out:
# per_capita-Meningitis                                                      -0.390116
# per_capita-Parkinson's Disease                                              0.932980
# per_capita-Nutritional Deficiencies                                        -0.374382
# per_capita-Malaria                                                         -0.309720
# per_capita-Drowning                                                        -0.303619
#                                                                               ...
# Mean Non-HDL cholesterol, age-standardized                                  0.460414
# Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)   -0.083260
# Prevalence of anaemia in pregnant women (aged 15-49) (%)                   -0.667108
# Mean hemoglobin level of non-pregnant women (aged 15-49 years)              0.586157
# num_nan                                                                     0.025158
# Length: 108, dtype: float64

# %%
for i,e in enumerate(data.columns[4:]):
    print(e)
# Out:
# Meningitis
# Alzheimer's Disease and Other Dementias
# Parkinson's Disease
# Nutritional Deficiencies
# Malaria
# Drowning
# Interpersonal Violence
# Maternal Disorders
# HIV/AIDS
# Drug Use Disorders
# Tuberculosis
# Cardiovascular Diseases
# Lower Respiratory Infections
# Neonatal Disorders
# Alcohol Use Disorders
# Self-harm
# Exposure to Forces of Nature
# Diarrheal Diseases
# Environmental Heat and Cold Exposure
# Neoplasms
# Conflict and Terrorism
# Diabetes Mellitus
# Chronic Kidney Disease
# Poisonings
# Protein-Energy Malnutrition
# Road Injuries
# Chronic Respiratory Diseases
# Cirrhosis and Other Chronic Liver Diseases
# Digestive Diseases
# Fire, Heat, and Hot Substances
# Acute Hepatitis
# population
# per_capita-Meningitis
# per_capita-Alzheimer's Disease and Other Dementias
# per_capita-Parkinson's Disease
# per_capita-Nutritional Deficiencies
# per_capita-Malaria
# per_capita-Drowning
# per_capita-Interpersonal Violence
# per_capita-Maternal Disorders
# per_capita-HIV/AIDS
# per_capita-Drug Use Disorders
# per_capita-Tuberculosis
# per_capita-Cardiovascular Diseases
# per_capita-Lower Respiratory Infections
# per_capita-Neonatal Disorders
# per_capita-Alcohol Use Disorders
# per_capita-Self-harm
# per_capita-Exposure to Forces of Nature
# per_capita-Diarrheal Diseases
# per_capita-Environmental Heat and Cold Exposure
# per_capita-Neoplasms
# per_capita-Conflict and Terrorism
# per_capita-Diabetes Mellitus
# per_capita-Chronic Kidney Disease
# per_capita-Poisonings
# per_capita-Protein-Energy Malnutrition
# per_capita-Road Injuries
# per_capita-Chronic Respiratory Diseases
# per_capita-Cirrhosis and Other Chronic Liver Diseases
# per_capita-Digestive Diseases
# per_capita-Fire, Heat, and Hot Substances
# per_capita-Acute Hepatitis
# gdp
# gdp/percap
# Raised blood pressure (SBP>=140 OR DBP>=90) (age-standardized estimate)
# Mean systolic blood pressure (age-standardized estimate)
# Mortality rate for 5-14 year-olds (probability of dying per 1000 children aged 5-14 years)
# Number of under-five deaths
# Number of infant deaths
# Number of neonatal deaths
# Current health expenditure (CHE) per capita in PPP int$
# Current health expenditure (CHE) per capita in US$
# Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)
# Domestic general government health expenditure (GGHE-D) per capita in PPP int$
# Domestic general government health expenditure (GGHE-D) per capita in US$
# Domestic general government health expenditure (GGHE-D) as percentage of current health expenditure (CHE) (%)
# Domestic general government health expenditure (GGHE-D) as percentage of gross domestic product (GDP) (%)
# Domestic general government health expenditure (GGHE-D) as percentage of general government expenditure (GGE) (%)
# Out-of-pocket expenditure (OOP) per capita in PPP int$
# Out-of-pocket expenditure (OOP) per capita in US$
# Out-of-pocket expenditure as percentage of current health expenditure (CHE) (%)
# Domestic private health expenditure (PVT-D) per capita in PPP int$
# Domestic private health expenditure (PVT-D) per capita in US$
# Domestic private health expenditure (PVT-D) as percentage of current health expenditure (CHE) (%)
# Medical doctors (per 10,000)
# Nursing and midwifery personnel (per 10,000)
# Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)
# Adolescent birth rate (per 1000 women aged 15-19 years)
# Under-five mortality rate (probability of dying by age 5 per 1000 live births)
# Deaths due to tuberculosis among HIV-negative people (per 100 000 population)
# Incidence of tuberculosis (per 100 000 population per year)
# Maternal mortality ratio (per 100 000 live births)
# Age-standardized suicide rates (per 100 000 population)
# Number of deaths
# Deaths per 1 000 live births
# Prevalence of underweight among adults, BMI < 18 (age-standardized estimate) (%)
# Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%)
# Prevalence of obesity among adults, BMI &GreaterEqual; 30 (age-standardized estimate) (%)
# Mean BMI (kg/m²) (age-standardized estimate)
# Total NCD Deaths (in thousands)
# Mean fasting blood glucose (mmol/l) (age-standardized estimate)
# Raised fasting blood glucose (>=7.0 mmol/L) (age-standardized estimate)
# Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease
# Estimated number of road traffic deaths
# Estimated road traffic death rate (per 100 000 population)
# Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)_x
# Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)_y
# Mortality rate attributed to unintentional poisoning (per 100 000 population)
# Crude suicide rates (per 100 000 population)
# Number of incident tuberculosis cases
# Number of deaths due to tuberculosis, excluding HIV
# Estimates of number of homicides
# Estimates of rates of homicides per 100 000 population
# Neonatal mortality rate (per 1000 live births)
# Stillbirth rate (per 1000 total births)
# Age-standardized NCD mortality rate  (per 100 000 population)
# Yellow fever - number of reported cases
# Mumps - number of reported cases
# Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)
# Polio (Pol3) immunization coverage among 1-year-olds (%)
# Hospital beds (per 10 000 population)
# Measles-containing-vaccine first-dose (MCV1) immunization coverage among 1-year-olds (%)
# Mortality rate among children ages 5 to 9 years (per 1000 children aged 5)
# Mean hemoglobin level of children aged 6-59 months
# Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, age-standardized
# Mean hemoglobin level of pregnant women (aged 15-49 years)
# Mean HDL cholesterol, age-standardized
# Prevalence of hypertension among adults aged 30-79 years, age-standardized
# Prevalence of hypertension among adults aged 30-79 years, crude
# Prevalence of controlled hypertension among adults aged 30-79 years with hypertension, age-standardized
# Prevalence of anaemia in non-pregnant women (aged 15-49) (%)
# Mean total cholesterol,  crude
# Prevalence of controlled hypertension among adults aged 30-79 years with hypertension, crude
# Prevalence of anaemia in women of reproductive age (aged 15-49) (%)
# Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, age-standardized
# Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)
# Number of children aged 6–59 months with anaemia (thousands)
# Number of pregnant women (aged 15-49 years) with anaemia (thousands)
# Prevalence of anaemia in children aged 6–59 months (%)
# Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, crude
# Mean total cholesterol,  age-standardized
# Number of deaths among children ages 10 to 14 years
# Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude
# Mean hemoglobin level of women of reproductive age (aged 15-49 years)
# Number of deaths among children ages 5 to 9 years
# Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)
# Mean Non-HDL cholesterol, age-standardized
# Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)
# Prevalence of anaemia in pregnant women (aged 15-49) (%)
# Mean hemoglobin level of non-pregnant women (aged 15-49 years)
# average_age
# num_nan

# %%
dicti = {}
for i,e in enumerate(data.columns):
    lst1= []
    target=data.drop(e, axis=1).apply(lambda x: x.corr(data[e]))
    
    for f,g in enumerate(target.sort_values(ascending=False)):
        if g >= 0.5 or g <= -0.5 :
            lst1.append(target.sort_values(ascending=False).index[f])
    lst2 = []
    for h in lst1:
        target1=data.drop(h, axis=1).apply(lambda x: x.corr(data[h]))
        target1 = target1.sort_values(ascending=False)
        lst2.append(target1[:7].index)
    try:
        
        for i in lst2[0]:
            if i in lst1:
                lst1.remove(i)
    except:
        print(e)
    dicti[e]=lst1
# Out:
# per_capita-Road Injuries
# per_capita-Chronic Respiratory Diseases
# Adolescent birth rate (per 1000 women aged 15-19 years)
# Estimated road traffic death rate (per 100 000 population)
# Yellow fever - number of reported cases
# num_nan

# %%
dicti
# Out:
# {'Meningitis': ['Number of under-five deaths',
#   'Diarrheal Diseases',
#   'Number of children aged 6–59 months with anaemia (thousands)',
#   'Lower Respiratory Infections',
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of deaths',
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Tuberculosis',
#   'Nutritional Deficiencies',
#   'Malaria',
#   'Protein-Energy Malnutrition',
#   'Acute Hepatitis',
#   'Number of incident tuberculosis cases',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Fire, Heat, and Hot Substances',
#   'Digestive Diseases',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Self-harm',
#   'Diabetes Mellitus',
#   'population',
#   'Chronic Kidney Disease',
#   'Drowning',
#   'HIV/AIDS'],
#  "Alzheimer's Disease and Other Dementias": ["Parkinson's Disease",
#   'gdp',
#   'Chronic Respiratory Diseases',
#   'Poisonings',
#   'Digestive Diseases',
#   'Diabetes Mellitus',
#   'Self-harm',
#   'Estimated number of road traffic deaths',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Drowning',
#   'Mumps - number of reported cases',
#   'Drug Use Disorders',
#   'Alcohol Use Disorders',
#   'Fire, Heat, and Hot Substances',
#   'Lower Respiratory Infections'],
#  "Parkinson's Disease": ['Neoplasms',
#   'Chronic Kidney Disease',
#   'Chronic Respiratory Diseases',
#   'Digestive Diseases',
#   'Self-harm',
#   'Diabetes Mellitus',
#   'Estimated number of road traffic deaths',
#   'Drowning',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'gdp',
#   'Fire, Heat, and Hot Substances',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Lower Respiratory Infections',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Mumps - number of reported cases',
#   'Number of deaths',
#   'Alcohol Use Disorders',
#   'Drug Use Disorders',
#   'Number of incident tuberculosis cases',
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of children aged 6–59 months with anaemia (thousands)'],
#  'Nutritional Deficiencies': ['Protein-Energy Malnutrition',
#   'Tuberculosis',
#   'Number of children aged 6–59 months with anaemia (thousands)',
#   'Neonatal Disorders',
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Acute Hepatitis',
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Diarrheal Diseases',
#   'Number of incident tuberculosis cases',
#   'Lower Respiratory Infections',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Number of deaths',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Meningitis',
#   'Digestive Diseases',
#   'Fire, Heat, and Hot Substances',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Self-harm',
#   'Diabetes Mellitus',
#   'Drowning',
#   'population',
#   'Chronic Kidney Disease',
#   'Chronic Respiratory Diseases',
#   'Estimated number of road traffic deaths',
#   'Road Injuries'],
#  'Malaria': ['Meningitis'],
#  'Drowning': ['Chronic Respiratory Diseases',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Chronic Kidney Disease',
#   'Total NCD Deaths (in thousands)',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Fire, Heat, and Hot Substances',
#   'Number of deaths',
#   'Neoplasms',
#   "Parkinson's Disease",
#   'Lower Respiratory Infections',
#   'Diabetes Mellitus',
#   'Poisonings',
#   'Number of incident tuberculosis cases',
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of children aged 6–59 months with anaemia (thousands)',
#   'Number of deaths among children ages 10 to 14 years',
#   'Number of neonatal deaths',
#   'Tuberculosis',
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Acute Hepatitis',
#   'Number of infant deaths',
#   "Alzheimer's Disease and Other Dementias",
#   'Neonatal Disorders',
#   'Nutritional Deficiencies',
#   'Number of under-five deaths',
#   'Number of deaths among children ages 5 to 9 years',
#   'Maternal Disorders',
#   'Protein-Energy Malnutrition',
#   'Diarrheal Diseases',
#   'Alcohol Use Disorders',
#   'Environmental Heat and Cold Exposure',
#   'Meningitis',
#   'Interpersonal Violence',
#   'Mumps - number of reported cases'],
#  'Interpersonal Violence': ['Estimates of number of homicides',
#   'Alcohol Use Disorders',
#   'Self-harm',
#   'Environmental Heat and Cold Exposure',
#   'population',
#   'Road Injuries',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Drowning',
#   'Number of incident tuberculosis cases',
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of deaths among children ages 10 to 14 years',
#   'Cardiovascular Diseases',
#   'Neonatal Disorders'],
#  'Maternal Disorders': ['Number of neonatal deaths',
#   'Diarrheal Diseases',
#   'Number of deaths among children ages 5 to 9 years',
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Tuberculosis',
#   'Acute Hepatitis',
#   'Nutritional Deficiencies',
#   'Number of incident tuberculosis cases',
#   'Lower Respiratory Infections',
#   'Meningitis',
#   'Protein-Energy Malnutrition',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of deaths',
#   'Fire, Heat, and Hot Substances',
#   'Digestive Diseases',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Self-harm',
#   'Diabetes Mellitus',
#   'population',
#   'Drowning',
#   'Chronic Kidney Disease',
#   'Chronic Respiratory Diseases',
#   'Estimated number of road traffic deaths',
#   'Road Injuries'],
#  'HIV/AIDS': ['Incidence of tuberculosis (per 100 000 population per year)',
#   'Number of deaths among children ages 5 to 9 years',
#   'Meningitis'],
#  'Drug Use Disorders': ['gdp',
#   'per_capita-Drug Use Disorders',
#   'Alcohol Use Disorders',
#   'Cardiovascular Diseases'],
#  'Tuberculosis': ['Number of deaths due to tuberculosis, excluding HIV',
#   'Maternal Disorders',
#   'Number of neonatal deaths',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Neonatal Disorders',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of infant deaths',
#   'Lower Respiratory Infections',
#   'Nutritional Deficiencies',
#   'Number of under-five deaths',
#   'Number of deaths among children ages 5 to 9 years',
#   'Fire, Heat, and Hot Substances',
#   'Digestive Diseases',
#   'Protein-Energy Malnutrition',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Number of deaths',
#   'Self-harm',
#   'Meningitis',
#   'Diabetes Mellitus',
#   'population',
#   'Drowning',
#   'Chronic Kidney Disease',
#   'Chronic Respiratory Diseases',
#   'Road Injuries',
#   'Estimated number of road traffic deaths',
#   'Total NCD Deaths (in thousands)',
#   'Cardiovascular Diseases',
#   'Environmental Heat and Cold Exposure'],
#  'Cardiovascular Diseases': ['Neoplasms',
#   'Chronic Respiratory Diseases',
#   'Drowning',
#   'Chronic Kidney Disease',
#   'Self-harm',
#   'Estimated number of road traffic deaths',
#   'Digestive Diseases',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Diabetes Mellitus',
#   'Fire, Heat, and Hot Substances',
#   'Alcohol Use Disorders',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Number of deaths',
#   'Lower Respiratory Infections',
#   'Mumps - number of reported cases',
#   'Number of incident tuberculosis cases',
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Environmental Heat and Cold Exposure',
#   'Number of children aged 6–59 months with anaemia (thousands)',
#   'Number of deaths among children ages 10 to 14 years',
#   'gdp',
#   'Tuberculosis',
#   'Drug Use Disorders',
#   'Number of neonatal deaths',
#   'Interpersonal Violence'],
#  'Lower Respiratory Infections': ['Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of infant deaths',
#   'Number of under-five deaths',
#   'Neonatal Disorders',
#   'Digestive Diseases',
#   'Number of deaths among children ages 5 to 9 years',
#   'Diarrheal Diseases',
#   'Maternal Disorders',
#   'Fire, Heat, and Hot Substances',
#   'Number of deaths',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Acute Hepatitis',
#   'Self-harm',
#   'Meningitis',
#   'Nutritional Deficiencies',
#   'population',
#   'Diabetes Mellitus',
#   'Chronic Kidney Disease',
#   'Drowning',
#   'Protein-Energy Malnutrition',
#   'Chronic Respiratory Diseases',
#   'Road Injuries',
#   'Estimated number of road traffic deaths',
#   'Total NCD Deaths (in thousands)',
#   'Cardiovascular Diseases',
#   "Parkinson's Disease",
#   'Interpersonal Violence',
#   'Neoplasms',
#   'Environmental Heat and Cold Exposure',
#   "Alzheimer's Disease and Other Dementias",
#   'Estimates of number of homicides',
#   'Poisonings'],
#  'Neonatal Disorders': ['Number of neonatal deaths',
#   'Diarrheal Diseases',
#   'Tuberculosis',
#   'Acute Hepatitis',
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Number of deaths among children ages 5 to 9 years',
#   'Number of incident tuberculosis cases',
#   'Lower Respiratory Infections',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Meningitis',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Nutritional Deficiencies',
#   'Number of deaths',
#   'Protein-Energy Malnutrition',
#   'Fire, Heat, and Hot Substances',
#   'Digestive Diseases',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Self-harm',
#   'Diabetes Mellitus',
#   'population',
#   'Chronic Kidney Disease',
#   'Drowning',
#   'Chronic Respiratory Diseases',
#   'Estimated number of road traffic deaths',
#   'Road Injuries',
#   'Total NCD Deaths (in thousands)',
#   'Interpersonal Violence'],
#  'Alcohol Use Disorders': ['Environmental Heat and Cold Exposure',
#   'Poisonings',
#   'Total NCD Deaths (in thousands)',
#   "Parkinson's Disease",
#   'population',
#   'Road Injuries',
#   'Neoplasms',
#   'Drowning',
#   'Chronic Kidney Disease',
#   "Alzheimer's Disease and Other Dementias",
#   'Diabetes Mellitus',
#   'Chronic Respiratory Diseases',
#   'Estimated number of road traffic deaths',
#   'Drug Use Disorders'],
#  'Self-harm': ['Digestive Diseases',
#   'Fire, Heat, and Hot Substances',
#   'Drowning',
#   'Chronic Respiratory Diseases',
#   'Road Injuries',
#   'Cardiovascular Diseases',
#   'Lower Respiratory Infections',
#   'Estimated number of road traffic deaths',
#   'Number of incident tuberculosis cases',
#   'Total NCD Deaths (in thousands)',
#   "Parkinson's Disease",
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of children aged 6–59 months with anaemia (thousands)',
#   'Number of deaths among children ages 10 to 14 years',
#   'Number of deaths',
#   'Tuberculosis',
#   'Neoplasms',
#   'Acute Hepatitis',
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Number of neonatal deaths',
#   'Neonatal Disorders',
#   'Number of infant deaths',
#   'Poisonings',
#   'Diarrheal Diseases',
#   'Alcohol Use Disorders',
#   "Alzheimer's Disease and Other Dementias",
#   'Maternal Disorders',
#   'Number of under-five deaths',
#   'Nutritional Deficiencies',
#   'Environmental Heat and Cold Exposure',
#   'Number of deaths among children ages 5 to 9 years',
#   'Protein-Energy Malnutrition',
#   'Interpersonal Violence',
#   'Meningitis'],
#  'Exposure to Forces of Nature': ['per_capita-Exposure to Forces of Nature'],
#  'Diarrheal Diseases': ['Number of children aged 6–59 months with anaemia (thousands)',
#   'Maternal Disorders',
#   'Acute Hepatitis',
#   'Number of infant deaths',
#   'Number of deaths among children ages 5 to 9 years',
#   'Number of under-five deaths',
#   'Number of incident tuberculosis cases',
#   'Lower Respiratory Infections',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Meningitis',
#   'Nutritional Deficiencies',
#   'Fire, Heat, and Hot Substances',
#   'Protein-Energy Malnutrition',
#   'Number of deaths',
#   'Digestive Diseases',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Self-harm',
#   'Diabetes Mellitus',
#   'Chronic Kidney Disease',
#   'population',
#   'Drowning',
#   'Chronic Respiratory Diseases',
#   'Estimated number of road traffic deaths',
#   'Road Injuries'],
#  'Environmental Heat and Cold Exposure': ['Alcohol Use Disorders',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Drowning',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Lower Respiratory Infections',
#   'population',
#   'Total NCD Deaths (in thousands)',
#   'Number of incident tuberculosis cases',
#   'Tuberculosis',
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of children aged 6–59 months with anaemia (thousands)',
#   'Road Injuries'],
#  'Neoplasms': ["Parkinson's Disease",
#   'Poisonings',
#   'Chronic Respiratory Diseases',
#   'Estimated number of road traffic deaths',
#   'Drowning',
#   'Self-harm',
#   'Digestive Diseases',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Diabetes Mellitus',
#   'Mumps - number of reported cases',
#   'gdp',
#   'Fire, Heat, and Hot Substances',
#   'Number of deaths',
#   'Alcohol Use Disorders',
#   'Lower Respiratory Infections',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Drug Use Disorders'],
#  'Conflict and Terrorism': ['per_capita-Conflict and Terrorism'],
#  'Diabetes Mellitus': ['Chronic Kidney Disease',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Road Injuries',
#   'Number of incident tuberculosis cases',
#   'Lower Respiratory Infections',
#   'Fire, Heat, and Hot Substances',
#   'Cardiovascular Diseases',
#   'Total NCD Deaths (in thousands)',
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Drowning',
#   'Estimated number of road traffic deaths',
#   'Number of children aged 6–59 months with anaemia (thousands)',
#   'Tuberculosis',
#   'Number of deaths among children ages 10 to 14 years',
#   'Number of deaths',
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Neoplasms',
#   'Neonatal Disorders',
#   'Acute Hepatitis',
#   'Number of neonatal deaths',
#   "Alzheimer's Disease and Other Dementias",
#   'Nutritional Deficiencies',
#   'Diarrheal Diseases',
#   'Number of infant deaths',
#   'Maternal Disorders',
#   'Number of under-five deaths',
#   'Protein-Energy Malnutrition',
#   'Number of deaths among children ages 5 to 9 years',
#   'Interpersonal Violence',
#   'Poisonings',
#   'Estimates of number of homicides',
#   'Meningitis',
#   'Alcohol Use Disorders'],
#  'Chronic Kidney Disease': ['Diabetes Mellitus',
#   "Parkinson's Disease",
#   'Self-harm',
#   'Road Injuries',
#   'Cardiovascular Diseases',
#   'Total NCD Deaths (in thousands)',
#   'Drowning',
#   'Neoplasms',
#   'Estimated number of road traffic deaths',
#   'Lower Respiratory Infections',
#   'Fire, Heat, and Hot Substances',
#   "Alzheimer's Disease and Other Dementias",
#   'Number of incident tuberculosis cases',
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of deaths',
#   'Number of children aged 6–59 months with anaemia (thousands)',
#   'Number of deaths among children ages 10 to 14 years',
#   'Tuberculosis',
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Number of neonatal deaths',
#   'Neonatal Disorders',
#   'Poisonings',
#   'Acute Hepatitis',
#   'Number of infant deaths',
#   'Nutritional Deficiencies',
#   'Diarrheal Diseases',
#   'Number of under-five deaths',
#   'Maternal Disorders',
#   'Protein-Energy Malnutrition',
#   'Number of deaths among children ages 5 to 9 years',
#   'gdp',
#   'Alcohol Use Disorders',
#   'Interpersonal Violence',
#   'Drug Use Disorders',
#   'Meningitis',
#   'Estimates of number of homicides'],
#  'Poisonings': ['Cardiovascular Diseases',
#   'Estimated number of road traffic deaths',
#   'Drowning',
#   "Alzheimer's Disease and Other Dementias",
#   'Self-harm',
#   'Mumps - number of reported cases',
#   'Chronic Kidney Disease',
#   'Digestive Diseases',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Alcohol Use Disorders',
#   'Number of deaths',
#   'Fire, Heat, and Hot Substances',
#   'Diabetes Mellitus',
#   'Environmental Heat and Cold Exposure',
#   'Lower Respiratory Infections'],
#  'Protein-Energy Malnutrition': ['Nutritional Deficiencies',
#   'Number of under-five deaths',
#   'Number of children aged 6–59 months with anaemia (thousands)',
#   'Neonatal Disorders',
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Acute Hepatitis',
#   'Diarrheal Diseases',
#   'Lower Respiratory Infections',
#   'Number of incident tuberculosis cases',
#   'Number of deaths',
#   'Meningitis',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Digestive Diseases',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Fire, Heat, and Hot Substances',
#   'Diabetes Mellitus',
#   'Self-harm',
#   'Drowning',
#   'population',
#   'Chronic Kidney Disease',
#   'Chronic Respiratory Diseases',
#   'Road Injuries',
#   'Estimated number of road traffic deaths'],
#  'Road Injuries': ['population',
#   'Cardiovascular Diseases',
#   'Estimated number of road traffic deaths',
#   'Neoplasms',
#   "Parkinson's Disease",
#   'Total NCD Deaths (in thousands)',
#   'Poisonings',
#   'Diabetes Mellitus',
#   'Fire, Heat, and Hot Substances',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Number of deaths',
#   "Alzheimer's Disease and Other Dementias",
#   'Lower Respiratory Infections',
#   'Number of incident tuberculosis cases',
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of children aged 6–59 months with anaemia (thousands)',
#   'Number of deaths among children ages 10 to 14 years',
#   'Tuberculosis',
#   'Number of neonatal deaths',
#   'Mumps - number of reported cases',
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Alcohol Use Disorders',
#   'Number of infant deaths',
#   'Acute Hepatitis',
#   'Neonatal Disorders',
#   'Number of under-five deaths',
#   'Nutritional Deficiencies',
#   'Number of deaths among children ages 5 to 9 years',
#   'Interpersonal Violence',
#   'Protein-Energy Malnutrition',
#   'Maternal Disorders',
#   'Diarrheal Diseases',
#   'Environmental Heat and Cold Exposure'],
#  'Chronic Respiratory Diseases': ['population',
#   'Cardiovascular Diseases',
#   'Estimated number of road traffic deaths',
#   "Parkinson's Disease",
#   'Neoplasms',
#   'Total NCD Deaths (in thousands)',
#   'Diabetes Mellitus',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Fire, Heat, and Hot Substances',
#   'Poisonings',
#   'Number of deaths',
#   'Lower Respiratory Infections',
#   'Number of incident tuberculosis cases',
#   "Alzheimer's Disease and Other Dementias",
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of children aged 6–59 months with anaemia (thousands)',
#   'Number of deaths among children ages 10 to 14 years',
#   'Tuberculosis',
#   'Number of neonatal deaths',
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Acute Hepatitis',
#   'Neonatal Disorders',
#   'Number of infant deaths',
#   'Number of under-five deaths',
#   'Nutritional Deficiencies',
#   'Diarrheal Diseases',
#   'Maternal Disorders',
#   'Number of deaths among children ages 5 to 9 years',
#   'Alcohol Use Disorders',
#   'Mumps - number of reported cases',
#   'Protein-Energy Malnutrition'],
#  'Cirrhosis and Other Chronic Liver Diseases': ['Digestive Diseases',
#   'Fire, Heat, and Hot Substances',
#   'Chronic Respiratory Diseases',
#   'Lower Respiratory Infections',
#   'Road Injuries',
#   'Drowning',
#   'Number of incident tuberculosis cases',
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Cardiovascular Diseases',
#   'Number of children aged 6–59 months with anaemia (thousands)',
#   'Estimated number of road traffic deaths',
#   'Total NCD Deaths (in thousands)',
#   'Number of deaths',
#   'Number of deaths among children ages 10 to 14 years',
#   'Tuberculosis',
#   "Parkinson's Disease",
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Number of neonatal deaths',
#   'Acute Hepatitis',
#   'Neonatal Disorders',
#   'Number of infant deaths',
#   'Neoplasms',
#   'Diarrheal Diseases',
#   'Maternal Disorders',
#   'Nutritional Deficiencies',
#   'Number of under-five deaths',
#   'Number of deaths among children ages 5 to 9 years',
#   'Protein-Energy Malnutrition',
#   "Alzheimer's Disease and Other Dementias",
#   'Poisonings',
#   'Meningitis',
#   'Alcohol Use Disorders',
#   'Environmental Heat and Cold Exposure',
#   'Interpersonal Violence',
#   'Estimates of number of homicides'],
#  'Digestive Diseases': ['Cirrhosis and Other Chronic Liver Diseases',
#   'Fire, Heat, and Hot Substances',
#   'Chronic Respiratory Diseases',
#   'Lower Respiratory Infections',
#   'Drowning',
#   'Road Injuries',
#   'Number of incident tuberculosis cases',
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Cardiovascular Diseases',
#   'Number of children aged 6–59 months with anaemia (thousands)',
#   'Total NCD Deaths (in thousands)',
#   'Estimated number of road traffic deaths',
#   "Parkinson's Disease",
#   'Number of deaths among children ages 10 to 14 years',
#   'Number of deaths',
#   'Tuberculosis',
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Number of neonatal deaths',
#   'Acute Hepatitis',
#   'Neonatal Disorders',
#   'Number of infant deaths',
#   'Neoplasms',
#   'Diarrheal Diseases',
#   'Nutritional Deficiencies',
#   'Maternal Disorders',
#   'Number of under-five deaths',
#   'Number of deaths among children ages 5 to 9 years',
#   "Alzheimer's Disease and Other Dementias",
#   'Protein-Energy Malnutrition',
#   'Poisonings',
#   'Alcohol Use Disorders',
#   'Meningitis',
#   'Environmental Heat and Cold Exposure',
#   'Interpersonal Violence',
#   'Estimates of number of homicides'],
#  'Fire, Heat, and Hot Substances': ['Self-harm',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Lower Respiratory Infections',
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of incident tuberculosis cases',
#   'Number of children aged 6–59 months with anaemia (thousands)',
#   'Number of deaths among children ages 10 to 14 years',
#   'Tuberculosis',
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Diabetes Mellitus',
#   'Number of neonatal deaths',
#   'Acute Hepatitis',
#   'Chronic Kidney Disease',
#   'Neonatal Disorders',
#   'Diarrheal Diseases',
#   'Environmental Heat and Cold Exposure',
#   'Number of infant deaths',
#   'Road Injuries',
#   'Number of deaths',
#   'Maternal Disorders',
#   'Cardiovascular Diseases',
#   'Number of under-five deaths',
#   'Estimated number of road traffic deaths',
#   'Alcohol Use Disorders',
#   'Number of deaths among children ages 5 to 9 years',
#   'Total NCD Deaths (in thousands)',
#   'Nutritional Deficiencies',
#   "Parkinson's Disease",
#   'Meningitis',
#   'Protein-Energy Malnutrition',
#   'Interpersonal Violence',
#   'Neoplasms',
#   'Poisonings',
#   "Alzheimer's Disease and Other Dementias",
#   'Estimates of number of homicides'],
#  'Acute Hepatitis': ['Tuberculosis',
#   'Number of neonatal deaths',
#   'Maternal Disorders',
#   'Neonatal Disorders',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of infant deaths',
#   'Lower Respiratory Infections',
#   'Number of under-five deaths',
#   'Nutritional Deficiencies',
#   'Number of deaths among children ages 5 to 9 years',
#   'Fire, Heat, and Hot Substances',
#   'Protein-Energy Malnutrition',
#   'Digestive Diseases',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Self-harm',
#   'Number of deaths',
#   'Meningitis',
#   'Diabetes Mellitus',
#   'Drowning',
#   'population',
#   'Chronic Kidney Disease',
#   'Chronic Respiratory Diseases',
#   'Road Injuries',
#   'Estimated number of road traffic deaths',
#   'Total NCD Deaths (in thousands)'],
#  'population': ['Chronic Respiratory Diseases',
#   'Chronic Kidney Disease',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Diabetes Mellitus',
#   "Parkinson's Disease",
#   'Total NCD Deaths (in thousands)',
#   'Neoplasms',
#   'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)',
#   'Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Fire, Heat, and Hot Substances',
#   'Lower Respiratory Infections',
#   'Number of deaths',
#   'Number of incident tuberculosis cases',
#   'Poisonings',
#   'Number of pregnant women (aged 15-49 years) with anaemia (thousands)',
#   "Alzheimer's Disease and Other Dementias",
#   'Number of children aged 6–59 months with anaemia (thousands)',
#   'Number of deaths among children ages 10 to 14 years',
#   'Tuberculosis',
#   'Number of neonatal deaths',
#   'Number of deaths due to tuberculosis, excluding HIV',
#   'Neonatal Disorders',
#   'Number of infant deaths',
#   'Acute Hepatitis',
#   'Number of under-five deaths',
#   'Nutritional Deficiencies',
#   'Number of deaths among children ages 5 to 9 years',
#   'Maternal Disorders',
#   'Diarrheal Diseases',
#   'Protein-Energy Malnutrition',
#   'Alcohol Use Disorders',
#   'Meningitis',
#   'Interpersonal Violence',
#   'Mumps - number of reported cases',
#   'Environmental Heat and Cold Exposure'],
#  'per_capita-Meningitis': ['per_capita-Diarrheal Diseases',
#   'per_capita-Neonatal Disorders',
#   'per_capita-Malaria',
#   'Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)',
#   'Prevalence of anaemia in children aged 6–59 months (%)',
#   'per_capita-Nutritional Deficiencies',
#   'per_capita-Protein-Energy Malnutrition',
#   'Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)',
#   'Neonatal mortality rate (per 1000 live births)',
#   'Stillbirth rate (per 1000 total births)',
#   'Prevalence of anaemia in pregnant women (aged 15-49) (%)',
#   'Prevalence of anaemia in women of reproductive age (aged 15-49) (%)',
#   'Prevalence of anaemia in non-pregnant women (aged 15-49) (%)',
#   'per_capita-Tuberculosis',
#   'per_capita-Acute Hepatitis',
#   'Prevalence of underweight among adults, BMI < 18 (age-standardized estimate) (%)',
#   'Domestic general government health expenditure (GGHE-D) as percentage of current health expenditure (CHE) (%)',
#   'Medical doctors (per 10,000)',
#   'Prevalence of obesity among adults, BMI &GreaterEqual; 30 (age-standardized estimate) (%)',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, crude',
#   'average_age',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude',
#   'Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%)',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Mean BMI (kg/m²) (age-standardized estimate)',
#   'Polio (Pol3) immunization coverage among 1-year-olds (%)',
#   'Mean hemoglobin level of non-pregnant women (aged 15-49 years)',
#   'Measles-containing-vaccine first-dose (MCV1) immunization coverage among 1-year-olds (%)',
#   'Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)',
#   'Mean total cholesterol,  crude',
#   'Mean total cholesterol,  age-standardized',
#   'Mean hemoglobin level of women of reproductive age (aged 15-49 years)',
#   'Mean Non-HDL cholesterol, age-standardized',
#   'Mean hemoglobin level of pregnant women (aged 15-49 years)',
#   'Mean hemoglobin level of children aged 6-59 months'],
#  "per_capita-Alzheimer's Disease and Other Dementias": ["per_capita-Parkinson's Disease",
#   'Domestic general government health expenditure (GGHE-D) per capita in PPP int$',
#   'Current health expenditure (CHE) per capita in PPP int$',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude',
#   'Current health expenditure (CHE) per capita in US$',
#   'Domestic general government health expenditure (GGHE-D) per capita in US$',
#   'Out-of-pocket expenditure (OOP) per capita in US$',
#   'Nursing and midwifery personnel (per 10,000)',
#   'Mean total cholesterol,  crude',
#   'Out-of-pocket expenditure (OOP) per capita in PPP int$',
#   'Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)_x',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Mean total cholesterol,  age-standardized',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Hospital beds (per 10 000 population)',
#   'Prevalence of controlled hypertension among adults aged 30-79 years with hypertension, crude',
#   'Mean hemoglobin level of children aged 6-59 months',
#   'gdp/percap',
#   'Mean hemoglobin level of women of reproductive age (aged 15-49 years)',
#   'Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)',
#   'Mean hemoglobin level of pregnant women (aged 15-49 years)',
#   'Mean hemoglobin level of non-pregnant women (aged 15-49 years)',
#   'Prevalence of hypertension among adults aged 30-79 years, crude',
#   'Domestic general government health expenditure (GGHE-D) as percentage of general government expenditure (GGE) (%)',
#   'Domestic private health expenditure (PVT-D) per capita in PPP int$',
#   'Prevalence of controlled hypertension among adults aged 30-79 years with hypertension, age-standardized',
#   'Domestic private health expenditure (PVT-D) per capita in US$',
#   'Domestic general government health expenditure (GGHE-D) as percentage of current health expenditure (CHE) (%)',
#   'Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)_y',
#   'Prevalence of obesity among adults, BMI &GreaterEqual; 30 (age-standardized estimate) (%)',
#   'Mean BMI (kg/m²) (age-standardized estimate)',
#   'Age-standardized NCD mortality rate  (per 100 000 population)',
#   'Under-five mortality rate (probability of dying by age 5 per 1000 live births)',
#   'per_capita-Neonatal Disorders',
#   'Prevalence of underweight among adults, BMI < 18 (age-standardized estimate) (%)',
#   'Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)',
#   'Neonatal mortality rate (per 1000 live births)',
#   'Prevalence of anaemia in children aged 6–59 months (%)',
#   'Prevalence of anaemia in non-pregnant women (aged 15-49) (%)',
#   'Stillbirth rate (per 1000 total births)',
#   'Prevalence of anaemia in women of reproductive age (aged 15-49) (%)',
#   'Prevalence of anaemia in pregnant women (aged 15-49) (%)'],
#  "per_capita-Parkinson's Disease": ['per_capita-Neoplasms',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, crude',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude',
#   'Domestic general government health expenditure (GGHE-D) per capita in PPP int$',
#   'Current health expenditure (CHE) per capita in PPP int$',
#   'Nursing and midwifery personnel (per 10,000)',
#   'Out-of-pocket expenditure (OOP) per capita in US$',
#   'Current health expenditure (CHE) per capita in US$',
#   'Domestic general government health expenditure (GGHE-D) per capita in US$',
#   'Out-of-pocket expenditure (OOP) per capita in PPP int$',
#   'Mean total cholesterol,  age-standardized',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)_x',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Prevalence of controlled hypertension among adults aged 30-79 years with hypertension, crude',
#   'Mean hemoglobin level of children aged 6-59 months',
#   'Mean hemoglobin level of women of reproductive age (aged 15-49 years)',
#   'Mean hemoglobin level of non-pregnant women (aged 15-49 years)',
#   'Hospital beds (per 10 000 population)',
#   'Mean hemoglobin level of pregnant women (aged 15-49 years)',
#   'Prevalence of hypertension among adults aged 30-79 years, crude',
#   'Prevalence of obesity among adults, BMI &GreaterEqual; 30 (age-standardized estimate) (%)',
#   'per_capita-Cardiovascular Diseases',
#   'gdp/percap',
#   'Prevalence of controlled hypertension among adults aged 30-79 years with hypertension, age-standardized',
#   'Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)',
#   'Mean BMI (kg/m²) (age-standardized estimate)',
#   'Domestic general government health expenditure (GGHE-D) as percentage of current health expenditure (CHE) (%)',
#   'Domestic private health expenditure (PVT-D) per capita in PPP int$',
#   'Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)_y',
#   'Domestic private health expenditure (PVT-D) per capita in US$',
#   'Domestic general government health expenditure (GGHE-D) as percentage of general government expenditure (GGE) (%)',
#   'Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%)',
#   'Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)',
#   'per_capita-Tuberculosis',
#   'per_capita-Maternal Disorders',
#   'Mortality rate for 5-14 year-olds (probability of dying per 1000 children aged 5-14 years)',
#   'Under-five mortality rate (probability of dying by age 5 per 1000 live births)',
#   'per_capita-Neonatal Disorders',
#   'Prevalence of underweight among adults, BMI < 18 (age-standardized estimate) (%)',
#   'Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)',
#   'Prevalence of anaemia in children aged 6–59 months (%)',
#   'Neonatal mortality rate (per 1000 live births)',
#   'Prevalence of anaemia in non-pregnant women (aged 15-49) (%)',
#   'Prevalence of anaemia in pregnant women (aged 15-49) (%)',
#   'Stillbirth rate (per 1000 total births)',
#   'Prevalence of anaemia in women of reproductive age (aged 15-49) (%)'],
#  'per_capita-Nutritional Deficiencies': ['per_capita-Protein-Energy Malnutrition',
#   'per_capita-Diarrheal Diseases',
#   'Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)',
#   'per_capita-Lower Respiratory Infections',
#   'Maternal mortality ratio (per 100 000 live births)',
#   'per_capita-Tuberculosis',
#   'Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)',
#   'Prevalence of anaemia in children aged 6–59 months (%)',
#   'Neonatal mortality rate (per 1000 live births)',
#   'per_capita-Malaria',
#   'Stillbirth rate (per 1000 total births)',
#   'Prevalence of anaemia in pregnant women (aged 15-49) (%)',
#   'Prevalence of underweight among adults, BMI < 18 (age-standardized estimate) (%)',
#   'per_capita-Acute Hepatitis',
#   'Prevalence of anaemia in women of reproductive age (aged 15-49) (%)',
#   'Prevalence of anaemia in non-pregnant women (aged 15-49) (%)',
#   'Mean hemoglobin level of women of reproductive age (aged 15-49 years)',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude',
#   'Prevalence of obesity among adults, BMI &GreaterEqual; 30 (age-standardized estimate) (%)',
#   'Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)',
#   'Measles-containing-vaccine first-dose (MCV1) immunization coverage among 1-year-olds (%)',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'average_age',
#   'Mean hemoglobin level of pregnant women (aged 15-49 years)',
#   'Polio (Pol3) immunization coverage among 1-year-olds (%)',
#   'Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%)',
#   'Mean BMI (kg/m²) (age-standardized estimate)',
#   'Mean total cholesterol,  crude',
#   'Mean total cholesterol,  age-standardized',
#   'Mean Non-HDL cholesterol, age-standardized',
#   'Mean hemoglobin level of children aged 6-59 months'],
#  'per_capita-Malaria': ['per_capita-Meningitis',
#   'Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)',
#   'Prevalence of anaemia in children aged 6–59 months (%)',
#   'Maternal mortality ratio (per 100 000 live births)',
#   'per_capita-Maternal Disorders',
#   'Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)',
#   'per_capita-Protein-Energy Malnutrition',
#   'per_capita-Nutritional Deficiencies',
#   'Prevalence of anaemia in pregnant women (aged 15-49) (%)',
#   'Prevalence of anaemia in women of reproductive age (aged 15-49) (%)',
#   'Prevalence of anaemia in non-pregnant women (aged 15-49) (%)',
#   'Neonatal mortality rate (per 1000 live births)',
#   'Stillbirth rate (per 1000 total births)',
#   'Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)',
#   'Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%)',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude',
#   'Polio (Pol3) immunization coverage among 1-year-olds (%)',
#   'Measles-containing-vaccine first-dose (MCV1) immunization coverage among 1-year-olds (%)',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Mean total cholesterol,  crude',
#   'Mean total cholesterol,  age-standardized',
#   'Mean hemoglobin level of non-pregnant women (aged 15-49 years)',
#   'Mean Non-HDL cholesterol, age-standardized',
#   'Mean hemoglobin level of women of reproductive age (aged 15-49 years)',
#   'Mean hemoglobin level of pregnant women (aged 15-49 years)',
#   'Mean hemoglobin level of children aged 6-59 months'],
#  'per_capita-Drowning': ['per_capita-Fire, Heat, and Hot Substances'],
#  'per_capita-Interpersonal Violence': ['Estimates of rates of homicides per 100 000 population'],
#  'per_capita-Maternal Disorders': ['Maternal mortality ratio (per 100 000 live births)',
#   'Prevalence of anaemia in children aged 6–59 months (%)',
#   'Mortality rate among children ages 5 to 9 years (per 1000 children aged 5)',
#   'per_capita-Meningitis',
#   'Stillbirth rate (per 1000 total births)',
#   'per_capita-Lower Respiratory Infections',
#   'Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)',
#   'per_capita-Nutritional Deficiencies',
#   'per_capita-Protein-Energy Malnutrition',
#   'Prevalence of anaemia in pregnant women (aged 15-49) (%)',
#   'Prevalence of anaemia in women of reproductive age (aged 15-49) (%)',
#   'Prevalence of anaemia in non-pregnant women (aged 15-49) (%)',
#   'per_capita-Malaria',
#   'per_capita-Acute Hepatitis',
#   'per_capita-Tuberculosis',
#   'Prevalence of underweight among adults, BMI < 18 (age-standardized estimate) (%)',
#   'Deaths due to tuberculosis among HIV-negative people (per 100 000 population)',
#   'Deaths per 1 000 live births',
#   'per_capita-Neoplasms',
#   "per_capita-Parkinson's Disease",
#   'Hospital beds (per 10 000 population)',
#   'Domestic general government health expenditure (GGHE-D) as percentage of gross domestic product (GDP) (%)',
#   'Nursing and midwifery personnel (per 10,000)',
#   'Domestic general government health expenditure (GGHE-D) as percentage of current health expenditure (CHE) (%)',
#   'Prevalence of obesity among adults, BMI &GreaterEqual; 30 (age-standardized estimate) (%)',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, crude',
#   'Medical doctors (per 10,000)',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude',
#   'Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%)',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'average_age',
#   'Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)',
#   'Polio (Pol3) immunization coverage among 1-year-olds (%)',
#   'Mean BMI (kg/m²) (age-standardized estimate)',
#   'Mean hemoglobin level of non-pregnant women (aged 15-49 years)',
#   'Measles-containing-vaccine first-dose (MCV1) immunization coverage among 1-year-olds (%)',
#   'Mean Non-HDL cholesterol, age-standardized',
#   'Mean total cholesterol,  crude',
#   'Mean total cholesterol,  age-standardized',
#   'Mean hemoglobin level of women of reproductive age (aged 15-49 years)',
#   'Mean hemoglobin level of pregnant women (aged 15-49 years)',
#   'Mean hemoglobin level of children aged 6-59 months'],
#  'per_capita-HIV/AIDS': ['Incidence of tuberculosis (per 100 000 population per year)'],
#  'per_capita-Drug Use Disorders': ['Current health expenditure (CHE) per capita in PPP int$',
#   'Nursing and midwifery personnel (per 10,000)',
#   'Drug Use Disorders',
#   'Domestic private health expenditure (PVT-D) per capita in US$'],
#  'per_capita-Tuberculosis': ['Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)',
#   'Incidence of tuberculosis (per 100 000 population per year)',
#   'Prevalence of underweight among adults, BMI < 18 (age-standardized estimate) (%)',
#   'Mortality rate for 5-14 year-olds (probability of dying per 1000 children aged 5-14 years)',
#   'Maternal mortality ratio (per 100 000 live births)',
#   'per_capita-Lower Respiratory Infections',
#   'per_capita-Diarrheal Diseases',
#   'Deaths due to tuberculosis among HIV-negative people (per 100 000 population)',
#   'Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)',
#   'per_capita-HIV/AIDS',
#   'per_capita-Nutritional Deficiencies',
#   'per_capita-Protein-Energy Malnutrition',
#   'per_capita-Meningitis',
#   'Prevalence of anaemia in pregnant women (aged 15-49) (%)',
#   'Prevalence of anaemia in women of reproductive age (aged 15-49) (%)',
#   'Prevalence of anaemia in non-pregnant women (aged 15-49) (%)',
#   'Mortality rate attributed to unintentional poisoning (per 100 000 population)',
#   'per_capita-Acute Hepatitis',
#   'Out-of-pocket expenditure (OOP) per capita in PPP int$',
#   "per_capita-Parkinson's Disease",
#   'Polio (Pol3) immunization coverage among 1-year-olds (%)',
#   'Measles-containing-vaccine first-dose (MCV1) immunization coverage among 1-year-olds (%)',
#   'Mean hemoglobin level of non-pregnant women (aged 15-49 years)',
#   'Mean hemoglobin level of women of reproductive age (aged 15-49 years)',
#   'Medical doctors (per 10,000)',
#   'Mean hemoglobin level of pregnant women (aged 15-49 years)',
#   'average_age',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, crude',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Prevalence of obesity among adults, BMI &GreaterEqual; 30 (age-standardized estimate) (%)',
#   'Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%)',
#   'Mean total cholesterol,  crude',
#   'Mean total cholesterol,  age-standardized',
#   'Mean hemoglobin level of children aged 6-59 months',
#   'Mean Non-HDL cholesterol, age-standardized',
#   'Mean BMI (kg/m²) (age-standardized estimate)'],
#  'per_capita-Cardiovascular Diseases': ['Hospital beds (per 10 000 population)',
#   'per_capita-Alcohol Use Disorders',
#   'per_capita-Self-harm',
#   'per_capita-Environmental Heat and Cold Exposure',
#   "per_capita-Parkinson's Disease",
#   'Mean total cholesterol,  crude',
#   'Prevalence of hypertension among adults aged 30-79 years, age-standardized',
#   'Mean total cholesterol,  age-standardized',
#   'per_capita-Digestive Diseases'],
#  'per_capita-Lower Respiratory Infections': ['Under-five mortality rate (probability of dying by age 5 per 1000 live births)',
#   'per_capita-Meningitis',
#   'per_capita-Diarrheal Diseases',
#   'per_capita-Maternal Disorders',
#   'per_capita-Nutritional Deficiencies',
#   'per_capita-Protein-Energy Malnutrition',
#   'per_capita-Tuberculosis',
#   'Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)',
#   'per_capita-Malaria',
#   'Stillbirth rate (per 1000 total births)',
#   'Prevalence of anaemia in pregnant women (aged 15-49) (%)',
#   'per_capita-Acute Hepatitis',
#   'Prevalence of anaemia in women of reproductive age (aged 15-49) (%)',
#   'Prevalence of anaemia in non-pregnant women (aged 15-49) (%)',
#   'Deaths due to tuberculosis among HIV-negative people (per 100 000 population)',
#   'Prevalence of underweight among adults, BMI < 18 (age-standardized estimate) (%)',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, crude',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude',
#   'average_age',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Mean hemoglobin level of non-pregnant women (aged 15-49 years)',
#   'Prevalence of obesity among adults, BMI &GreaterEqual; 30 (age-standardized estimate) (%)',
#   'Mean hemoglobin level of women of reproductive age (aged 15-49 years)',
#   'Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%)',
#   'Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)',
#   'Mean total cholesterol,  crude',
#   'Polio (Pol3) immunization coverage among 1-year-olds (%)',
#   'Measles-containing-vaccine first-dose (MCV1) immunization coverage among 1-year-olds (%)',
#   'Mean BMI (kg/m²) (age-standardized estimate)',
#   'Mean total cholesterol,  age-standardized',
#   'Mean hemoglobin level of pregnant women (aged 15-49 years)',
#   'Mean Non-HDL cholesterol, age-standardized',
#   'Mean hemoglobin level of children aged 6-59 months'],
#  'per_capita-Neonatal Disorders': ['Under-five mortality rate (probability of dying by age 5 per 1000 live births)',
#   'Stillbirth rate (per 1000 total births)',
#   'per_capita-Maternal Disorders',
#   'per_capita-Meningitis',
#   'per_capita-Diarrheal Diseases',
#   'Prevalence of anaemia in pregnant women (aged 15-49) (%)',
#   'per_capita-Lower Respiratory Infections',
#   'Prevalence of anaemia in women of reproductive age (aged 15-49) (%)',
#   'per_capita-Nutritional Deficiencies',
#   'Prevalence of anaemia in non-pregnant women (aged 15-49) (%)',
#   'per_capita-Protein-Energy Malnutrition',
#   'Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)',
# ...
#   'Prevalence of anaemia in women of reproductive age (aged 15-49) (%)',
#   'Prevalence of anaemia in non-pregnant women (aged 15-49) (%)',
#   'Prevalence of underweight among adults, BMI < 18 (age-standardized estimate) (%)',
#   'Deaths due to tuberculosis among HIV-negative people (per 100 000 population)',
#   'per_capita-Acute Hepatitis',
#   "per_capita-Parkinson's Disease",
#   'Domestic general government health expenditure (GGHE-D) as percentage of current health expenditure (CHE) (%)',
#   'Prevalence of obesity among adults, BMI &GreaterEqual; 30 (age-standardized estimate) (%)',
#   'Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)',
#   'Medical doctors (per 10,000)',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, crude',
#   'Polio (Pol3) immunization coverage among 1-year-olds (%)',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%)',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude',
#   'Measles-containing-vaccine first-dose (MCV1) immunization coverage among 1-year-olds (%)',
#   'Mean hemoglobin level of non-pregnant women (aged 15-49 years)',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'average_age',
#   'Mean hemoglobin level of women of reproductive age (aged 15-49 years)',
#   'Mean BMI (kg/m²) (age-standardized estimate)',
#   'Mean hemoglobin level of pregnant women (aged 15-49 years)',
#   'Mean Non-HDL cholesterol, age-standardized',
#   'Mean total cholesterol,  crude',
#   'Mean total cholesterol,  age-standardized',
#   'Mean hemoglobin level of children aged 6-59 months'],
#  'Mean Non-HDL cholesterol, age-standardized': ['Mean total cholesterol,  age-standardized',
#   'Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%)',
#   'Prevalence of obesity among adults, BMI &GreaterEqual; 30 (age-standardized estimate) (%)',
#   'Mean hemoglobin level of pregnant women (aged 15-49 years)',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Mean hemoglobin level of women of reproductive age (aged 15-49 years)',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, crude',
#   'Domestic general government health expenditure (GGHE-D) as percentage of current health expenditure (CHE) (%)',
#   'Mean hemoglobin level of non-pregnant women (aged 15-49 years)',
#   'per_capita-Neoplasms',
#   'per_capita-Acute Hepatitis',
#   'Deaths due to tuberculosis among HIV-negative people (per 100 000 population)',
#   'per_capita-Malaria',
#   'per_capita-Protein-Energy Malnutrition',
#   'per_capita-Nutritional Deficiencies',
#   'Prevalence of anaemia in non-pregnant women (aged 15-49) (%)',
#   'Prevalence of anaemia in women of reproductive age (aged 15-49) (%)',
#   'Prevalence of anaemia in pregnant women (aged 15-49) (%)',
#   'Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)',
#   'per_capita-Lower Respiratory Infections',
#   'per_capita-Meningitis',
#   'Prevalence of underweight among adults, BMI < 18 (age-standardized estimate) (%)',
#   'per_capita-Diarrheal Diseases',
#   'per_capita-Maternal Disorders',
#   'Mortality rate for 5-14 year-olds (probability of dying per 1000 children aged 5-14 years)',
#   'Mortality rate among children ages 5 to 9 years (per 1000 children aged 5)',
#   'Maternal mortality ratio (per 100 000 live births)',
#   'per_capita-Tuberculosis',
#   'Stillbirth rate (per 1000 total births)',
#   'per_capita-Neonatal Disorders',
#   'Neonatal mortality rate (per 1000 live births)',
#   'Prevalence of anaemia in children aged 6–59 months (%)',
#   'Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)',
#   'Under-five mortality rate (probability of dying by age 5 per 1000 live births)'],
#  'Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)': ['Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)',
#   'Digestive Diseases',
#   'Cirrhosis and Other Chronic Liver Diseases',
#   'Number of deaths among children ages 10 to 14 years',
#   'Fire, Heat, and Hot Substances',
#   'Acute Hepatitis',
#   'Self-harm',
#   'Number of neonatal deaths',
#   'Diarrheal Diseases',
#   'Neonatal Disorders',
#   'Diabetes Mellitus',
#   'population',
#   'Maternal Disorders',
#   'Number of infant deaths',
#   'Chronic Kidney Disease',
#   'Chronic Respiratory Diseases',
#   'Drowning',
#   'Number of deaths',
#   'Number of under-five deaths',
#   'Number of deaths among children ages 5 to 9 years',
#   'Road Injuries',
#   'Nutritional Deficiencies',
#   'Estimated number of road traffic deaths',
#   'Protein-Energy Malnutrition',
#   'Meningitis',
#   'Total NCD Deaths (in thousands)',
#   'Cardiovascular Diseases',
#   "Parkinson's Disease",
#   'Neoplasms',
#   'Environmental Heat and Cold Exposure',
#   'Interpersonal Violence'],
#  'Prevalence of anaemia in pregnant women (aged 15-49) (%)': ['Prevalence of anaemia in women of reproductive age (aged 15-49) (%)',
#   'Stillbirth rate (per 1000 total births)',
#   'per_capita-Maternal Disorders',
#   'Prevalence of underweight among adults, BMI < 18 (age-standardized estimate) (%)',
#   'Mortality rate among children ages 5 to 9 years (per 1000 children aged 5)',
#   'Mortality rate for 5-14 year-olds (probability of dying per 1000 children aged 5-14 years)',
#   'Maternal mortality ratio (per 100 000 live births)',
#   'per_capita-Meningitis',
#   'per_capita-Diarrheal Diseases',
#   'Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)',
#   'per_capita-Malaria',
#   'per_capita-Lower Respiratory Infections',
#   'Deaths due to tuberculosis among HIV-negative people (per 100 000 population)',
#   'per_capita-Tuberculosis',
#   'per_capita-Acute Hepatitis',
#   'per_capita-Nutritional Deficiencies',
#   'per_capita-Protein-Energy Malnutrition',
#   'Mean systolic blood pressure (age-standardized estimate)',
#   'Domestic private health expenditure (PVT-D) per capita in PPP int$',
#   'Domestic general government health expenditure (GGHE-D) per capita in US$',
#   'gdp/percap',
#   'Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)',
#   'Current health expenditure (CHE) per capita in US$',
#   'Polio (Pol3) immunization coverage among 1-year-olds (%)',
#   'Measles-containing-vaccine first-dose (MCV1) immunization coverage among 1-year-olds (%)',
#   'Domestic general government health expenditure (GGHE-D) as percentage of general government expenditure (GGE) (%)',
#   'Out-of-pocket expenditure (OOP) per capita in US$',
#   'Mean HDL cholesterol, age-standardized',
#   'Prevalence of controlled hypertension among adults aged 30-79 years with hypertension, age-standardized',
#   'Prevalence of controlled hypertension among adults aged 30-79 years with hypertension, crude',
#   'Domestic general government health expenditure (GGHE-D) per capita in PPP int$',
#   'Domestic general government health expenditure (GGHE-D) as percentage of current health expenditure (CHE) (%)',
#   'Nursing and midwifery personnel (per 10,000)',
#   'Current health expenditure (CHE) per capita in PPP int$',
#   'Mean Non-HDL cholesterol, age-standardized',
#   "per_capita-Alzheimer's Disease and Other Dementias",
#   'Out-of-pocket expenditure (OOP) per capita in PPP int$',
#   'per_capita-Neoplasms',
#   "per_capita-Parkinson's Disease",
#   'Prevalence of obesity among adults, BMI &GreaterEqual; 30 (age-standardized estimate) (%)',
#   'Domestic general government health expenditure (GGHE-D) as percentage of gross domestic product (GDP) (%)',
#   'Medical doctors (per 10,000)',
#   'Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%)',
#   'Mean BMI (kg/m²) (age-standardized estimate)',
#   'Mean total cholesterol,  age-standardized',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Mean total cholesterol,  crude',
#   'average_age',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, crude',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude',
#   'Mean hemoglobin level of children aged 6-59 months',
#   'Mean hemoglobin level of non-pregnant women (aged 15-49 years)',
#   'Mean hemoglobin level of women of reproductive age (aged 15-49 years)',
#   'Mean hemoglobin level of pregnant women (aged 15-49 years)'],
#  'Mean hemoglobin level of non-pregnant women (aged 15-49 years)': ['Mean hemoglobin level of women of reproductive age (aged 15-49 years)',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'average_age',
#   'Mean total cholesterol,  age-standardized',
#   'Mean BMI (kg/m²) (age-standardized estimate)',
#   'Domestic general government health expenditure (GGHE-D) as percentage of gross domestic product (GDP) (%)',
#   'Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%)',
#   "per_capita-Parkinson's Disease",
#   'per_capita-Neoplasms',
#   'Medical doctors (per 10,000)',
#   'Prevalence of obesity among adults, BMI &GreaterEqual; 30 (age-standardized estimate) (%)',
#   "per_capita-Alzheimer's Disease and Other Dementias",
#   'Mean Non-HDL cholesterol, age-standardized',
#   'Domestic general government health expenditure (GGHE-D) as percentage of general government expenditure (GGE) (%)',
#   'Nursing and midwifery personnel (per 10,000)',
#   'Prevalence of controlled hypertension among adults aged 30-79 years with hypertension, crude',
#   'Domestic general government health expenditure (GGHE-D) as percentage of current health expenditure (CHE) (%)',
#   'Out-of-pocket expenditure (OOP) per capita in PPP int$',
#   'Measles-containing-vaccine first-dose (MCV1) immunization coverage among 1-year-olds (%)',
#   'Polio (Pol3) immunization coverage among 1-year-olds (%)',
#   'Current health expenditure (CHE) per capita in PPP int$',
#   'Prevalence of controlled hypertension among adults aged 30-79 years with hypertension, age-standardized',
#   'Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)',
#   'Domestic general government health expenditure (GGHE-D) per capita in PPP int$',
#   'Out-of-pocket expenditure (OOP) per capita in US$',
#   'Mean HDL cholesterol, age-standardized',
#   'Mean systolic blood pressure (age-standardized estimate)',
#   'per_capita-Tuberculosis',
#   'Deaths due to tuberculosis among HIV-negative people (per 100 000 population)',
#   'per_capita-Lower Respiratory Infections',
#   'per_capita-Acute Hepatitis',
#   'per_capita-Malaria',
#   'Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)',
#   'per_capita-Diarrheal Diseases',
#   'per_capita-Meningitis',
#   'Maternal mortality ratio (per 100 000 live births)',
#   'Prevalence of underweight among adults, BMI < 18 (age-standardized estimate) (%)',
#   'Mortality rate for 5-14 year-olds (probability of dying per 1000 children aged 5-14 years)',
#   'Mortality rate among children ages 5 to 9 years (per 1000 children aged 5)',
#   'per_capita-Maternal Disorders',
#   'Stillbirth rate (per 1000 total births)',
#   'Under-five mortality rate (probability of dying by age 5 per 1000 live births)',
#   'per_capita-Neonatal Disorders',
#   'Neonatal mortality rate (per 1000 live births)',
#   'Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)',
#   'Prevalence of anaemia in children aged 6–59 months (%)',
#   'Prevalence of anaemia in pregnant women (aged 15-49) (%)',
#   'Prevalence of anaemia in women of reproductive age (aged 15-49) (%)',
#   'Prevalence of anaemia in non-pregnant women (aged 15-49) (%)'],
#  'average_age': ['per_capita-Neoplasms',
#   'Mean total cholesterol,  age-standardized',
#   'Mean hemoglobin level of children aged 6-59 months',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, crude',
#   'Nursing and midwifery personnel (per 10,000)',
#   'Hospital beds (per 10 000 population)',
#   'Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Out-of-pocket expenditure (OOP) per capita in PPP int$',
#   'Current health expenditure (CHE) per capita in PPP int$',
#   'Domestic general government health expenditure (GGHE-D) per capita in PPP int$',
#   'Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, age-standardized',
#   'Mean hemoglobin level of pregnant women (aged 15-49 years)',
#   'Mean hemoglobin level of women of reproductive age (aged 15-49 years)',
#   'Out-of-pocket expenditure (OOP) per capita in US$',
#   'Mean Non-HDL cholesterol, age-standardized',
#   'Mean hemoglobin level of non-pregnant women (aged 15-49 years)',
#   'per_capita-Cardiovascular Diseases',
#   'Prevalence of hypertension among adults aged 30-79 years, crude',
#   'Mean BMI (kg/m²) (age-standardized estimate)',
#   'Current health expenditure (CHE) per capita in US$',
#   'Domestic general government health expenditure (GGHE-D) as percentage of current health expenditure (CHE) (%)',
#   'Prevalence of obesity among adults, BMI &GreaterEqual; 30 (age-standardized estimate) (%)',
#   'Domestic general government health expenditure (GGHE-D) per capita in US$',
#   'gdp/percap',
#   'Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%)',
#   'Prevalence of controlled hypertension among adults aged 30-79 years with hypertension, crude',
#   'Domestic private health expenditure (PVT-D) per capita in PPP int$',
#   'Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)_x',
#   'Prevalence of controlled hypertension among adults aged 30-79 years with hypertension, age-standardized',
#   'Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)_y',
#   'Domestic private health expenditure (PVT-D) per capita in US$',
#   'per_capita-Protein-Energy Malnutrition',
#   'per_capita-Nutritional Deficiencies',
#   'per_capita-Acute Hepatitis',
#   'per_capita-Lower Respiratory Infections',
#   'per_capita-Meningitis',
#   'per_capita-Diarrheal Diseases',
#   'per_capita-Tuberculosis',
#   'Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)',
#   'Mortality rate among children ages 5 to 9 years (per 1000 children aged 5)',
#   'Maternal mortality ratio (per 100 000 live births)',
#   'Mortality rate for 5-14 year-olds (probability of dying per 1000 children aged 5-14 years)',
#   'Prevalence of underweight among adults, BMI < 18 (age-standardized estimate) (%)',
#   'per_capita-Maternal Disorders',
#   'Prevalence of anaemia in non-pregnant women (aged 15-49) (%)',
#   'Under-five mortality rate (probability of dying by age 5 per 1000 live births)',
#   'Prevalence of anaemia in women of reproductive age (aged 15-49) (%)',
#   'per_capita-Neonatal Disorders',
#   'Prevalence of anaemia in pregnant women (aged 15-49) (%)',
#   'Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)',
#   'Neonatal mortality rate (per 1000 live births)',
#   'Stillbirth rate (per 1000 total births)',
#   'Prevalence of anaemia in children aged 6–59 months (%)'],
#  'num_nan': []}

# %%
data.drop('Meningitis', axis=1).apply(lambda x: x.corr(data['Meningitis'])).sort_values(ascending=False)
# Out:
# Number of under-five deaths                                                                     0.958376
# Number of deaths among children ages 5 to 9 years                                               0.949801
# Number of infant deaths                                                                         0.938146
# Maternal Disorders                                                                              0.891197
# Neonatal Disorders                                                                              0.891078
#                                                                                                   ...
# Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%)   -0.348375
# Mean hemoglobin level of children aged 6-59 months                                             -0.349713
# Measles-containing-vaccine first-dose (MCV1) immunization coverage among 1-year-olds (%)       -0.364201
# Polio (Pol3) immunization coverage among 1-year-olds (%)                                       -0.375111
# Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)     -0.387886
# Length: 152, dtype: float64

# %%
newcol = data.columns[36:]

# %%
data1 = data.copy()

# %%
data1 = data1[newcol]

# %%
pd.set_option('display.max_columns', None)

# %%
data1
# Out:
#       per_capita-Meningitis  \
# 0                  0.000127
# 1                  0.000132
# 2                  0.000130
# 3                  0.000123
# 4                  0.000114
# ...                     ...
# 2883               0.000110
# 2884               0.000103
# 2885               0.000101
# 2886               0.000100
# 2887               0.000098
#
#       per_capita-Alzheimer's Disease and Other Dementias  \
# 0                                              0.000056
# 1                                              0.000053
# 2                                              0.000052
# 3                                              0.000052
# 4                                              0.000051
# ...                                                 ...
# 2883                                           0.000055
# 2884                                           0.000054
# 2885                                           0.000053
# 2886                                           0.000053
# 2887                                           0.000053
#
#       per_capita-Parkinson's Disease  per_capita-Nutritional Deficiencies  \
# 0                           0.000018                             0.000118
# 1                           0.000017                             0.000122
# 2                           0.000017                             0.000118
# 3                           0.000017                             0.000109
# 4                           0.000016                             0.000100
# ...                              ...                                  ...
# 2883                        0.000016                             0.000229
# 2884                        0.000015                             0.000216
# 2885                        0.000015                             0.000212
# 2886                        0.000015                             0.000210
# 2887                        0.000015                             0.000201
#
#       per_capita-Malaria  per_capita-Drowning  \
# 0               0.000122             0.000084
# 1               0.000088             0.000091
# 2               0.000030             0.000093
# 3               0.000021             0.000088
# 4               0.000015             0.000082
# ...                  ...                  ...
# 2883            0.000269             0.000056
# 2884            0.000268             0.000053
# 2885            0.000177             0.000054
# 2886            0.000141             0.000055
# 2887            0.000142             0.000055
#
#       per_capita-Interpersonal Violence  per_capita-Maternal Disorders  \
# 0                              0.000139                       0.000191
# 1                              0.000138                       0.000188
# 2                              0.000135                       0.000187
# 3                              0.000133                       0.000187
# 4                              0.000133                       0.000180
# ...                                 ...                            ...
# 2883                           0.000094                       0.000105
# 2884                           0.000091                       0.000099
# 2885                           0.000091                       0.000095
# 2886                           0.000092                       0.000092
# 2887                           0.000092                       0.000088
#
#       per_capita-HIV/AIDS  per_capita-Drug Use Disorders  \
# 0                0.000005                       0.000009
# 1                0.000005                       0.000009
# 2                0.000005                       0.000009
# 3                0.000005                       0.000009
# 4                0.000005                       0.000009
# ...                   ...                            ...
# 2883             0.002552                       0.000007
# 2884             0.002253                       0.000007
# 2885             0.002049                       0.000007
# 2886             0.001866                       0.000008
# 2887             0.001671                       0.000008
#
#       per_capita-Tuberculosis  per_capita-Cardiovascular Diseases  \
# 0                    0.000240                            0.002297
# 1                    0.000227                            0.002170
# 2                    0.000218                            0.002118
# 3                    0.000205                            0.002058
# 4                    0.000192                            0.001992
# ...                       ...                                 ...
# 2883                 0.000899                            0.001221
# 2884                 0.000831                            0.001188
# 2885                 0.000788                            0.001170
# 2886                 0.000756                            0.001164
# 2887                 0.000724                            0.001156
#
#       per_capita-Lower Respiratory Infections  per_capita-Neonatal Disorders  \
# 0                                    0.001286                       0.001016
# 1                                    0.001294                       0.000985
# 2                                    0.001254                       0.000964
# 3                                    0.001173                       0.000939
# 4                                    0.001083                       0.000892
# ...                                       ...                            ...
# 2883                                 0.000984                       0.000721
# 2884                                 0.000936                       0.000682
# 2885                                 0.000912                       0.000652
# 2886                                 0.000895                       0.000623
# 2887                                 0.000872                       0.000599
#
#       per_capita-Alcohol Use Disorders  per_capita-Self-harm  \
# 0                             0.000004              0.000050
# 1                             0.000004              0.000049
# 2                             0.000004              0.000050
# 3                             0.000004              0.000049
# 4                             0.000004              0.000048
# ...                                ...                   ...
# 2883                          0.000003              0.000160
# 2884                          0.000003              0.000157
# 2885                          0.000003              0.000157
# 2886                          0.000003              0.000158
# 2887                          0.000003              0.000157
#
#       per_capita-Exposure to Forces of Nature  per_capita-Diarrheal Diseases  \
# 0                                5.449132e-05                       0.000483
# 1                                5.478819e-06                       0.000494
# 2                                7.004535e-07                       0.000477
# 3                                2.130269e-05                       0.000438
# 4                                1.406771e-05                       0.000381
# ...                                       ...                            ...
# 2883                             9.481975e-06                       0.000419
# 2884                             5.809005e-07                       0.000381
# 2885                             1.124421e-06                       0.000359
# 2886                             2.131029e-06                       0.000344
# 2887                             1.688175e-05                       0.000333
#
#       per_capita-Environmental Heat and Cold Exposure  per_capita-Neoplasms  \
# 0                                            0.000002              0.000612
# 1                                            0.000002              0.000598
# 2                                            0.000002              0.000598
# 3                                            0.000003              0.000591
# 4                                            0.000002              0.000579
# ...                                               ...                   ...
# 2883                                         0.000003              0.000802
# 2884                                         0.000003              0.000788
# 2885                                         0.000003              0.000784
# 2886                                         0.000003              0.000788
# 2887                                         0.000002              0.000790
#
#       per_capita-Conflict and Terrorism  per_capita-Diabetes Mellitus  \
# 0                          4.139815e-05                      0.000116
# 1                          3.455255e-05                      0.000115
# 2                          4.082088e-05                      0.000116
# 3                          8.027431e-05                      0.000117
# 4                          2.090638e-04                      0.000115
# ...                                 ...                           ...
# 2883                       6.068464e-07                      0.000228
# 2884                       3.630628e-07                      0.000225
# 2885                       9.135924e-07                      0.000223
# 2886                       4.124573e-07                      0.000224
# 2887                       3.362897e-07                      0.000223
#
#       per_capita-Chronic Kidney Disease  per_capita-Poisonings  \
# 0                              0.000180               0.000021
# 1                              0.000173               0.000021
# 2                              0.000172               0.000021
# 3                              0.000168               0.000021
# 4                              0.000164               0.000019
# ...                                 ...                    ...
# 2883                           0.000153               0.000027
# 2884                           0.000149               0.000027
# 2885                           0.000148               0.000027
# 2886                           0.000148               0.000027
# 2887                           0.000148               0.000027
#
#       per_capita-Protein-Energy Malnutrition  per_capita-Road Injuries  \
# 0                                   0.000116                  0.000284
# 1                                   0.000119                  0.000290
# 2                                   0.000116                  0.000293
# 3                                   0.000107                  0.000288
# 4                                   0.000099                  0.000276
# ...                                      ...                       ...
# 2883                                0.000227                  0.000174
# 2884                                0.000214                  0.000167
# 2885                                0.000210                  0.000167
# 2886                                0.000208                  0.000167
# 2887                                0.000199                  0.000166
#
#       per_capita-Chronic Respiratory Diseases  \
# 0                                    0.000316
# 1                                    0.000299
# 2                                    0.000291
# 3                                    0.000281
# 4                                    0.000269
# ...                                       ...
# 2883                                 0.000204
# 2884                                 0.000197
# 2885                                 0.000193
# 2886                                 0.000192
# 2887                                 0.000190
#
#       per_capita-Cirrhosis and Other Chronic Liver Diseases  \
# 0                                              0.000137
# 1                                              0.000134
# 2                                              0.000132
# 3                                              0.000129
# 4                                              0.000124
# ...                                                 ...
# 2883                                           0.000149
# 2884                                           0.000142
# 2885                                           0.000137
# 2886                                           0.000135
# 2887                                           0.000135
#
#       per_capita-Digestive Diseases  \
# 0                          0.000265
# 1                          0.000258
# 2                          0.000255
# 3                          0.000248
# 4                          0.000239
# ...                             ...
# 2883                       0.000312
# 2884                       0.000300
# 2885                       0.000295
# 2886                       0.000293
# 2887                       0.000292
#
#       per_capita-Fire, Heat, and Hot Substances  per_capita-Acute Hepatitis  \
# 0                                      0.000019                    0.000180
# 1                                      0.000020                    0.000175
# 2                                      0.000020                    0.000169
# 3                                      0.000019                    0.000159
# 4                                      0.000018                    0.000143
# ...                                         ...                         ...
# 2883                                   0.000046                    0.000011
# 2884                                   0.000045                    0.000011
# 2885                                   0.000044                    0.000010
# 2886                                   0.000045                    0.000010
# 2887                                   0.000044                    0.000010
#
#                gdp   gdp/percap  \
# 0     5.146000e+09   218.050034
# 1     6.167000e+09   246.626847
# 2     6.925000e+09   269.480041
# 3     8.556000e+09   324.894506
# 4     1.029700e+10   379.202093
# ...            ...          ...
# 2883  1.909300e+10  1448.314742
# 2884  1.949900e+10  1415.872424
# 2885  1.996900e+10  1403.348147
# 2886  2.055500e+10  1413.009906
# 2887  2.138500e+10  1438.311244
#
#       Mortality rate for 5-14 year-olds (probability of dying per 1000 children aged 5-14 years)  \
# 0                                               9.59386
# 1                                               9.41968
# 2                                               9.42410
# 3                                               9.55693
# 4                                               9.78268
# ...                                                 ...
# 2883                                           14.12878
# 2884                                           13.67498
# 2885                                           13.28315
# 2886                                           12.88704
# 2887                                           12.52253
#
#       Number of under-five deaths  Number of infant deaths  \
# 0                         66148.0                  48423.0
# 1                         65461.0                  47951.0
# 2                         64442.0                  47308.0
# 3                         63207.0                  46519.0
# 4                         61810.0                  45608.0
# ...                           ...                      ...
# 2883                      16941.0                  11837.0
# 2884                      16109.0                  11308.0
# 2885                      15686.0                  10986.0
# 2886                      14884.0                  10487.0
# 2887                      14289.0                  10085.0
#
#       Number of neonatal deaths  \
# 0                       62635.0
# 1                       62483.0
# 2                       62215.0
# 3                       61677.0
# 4                       60907.0
# ...                         ...
# 2883                    13695.0
# 2884                    13345.0
# 2885                    12974.0
# 2886                    12588.0
# 2887                    12170.0
#
#       Current health expenditure (CHE) per capita in PPP int$  \
# 0                                                 81.27
# 1                                                 82.46
# 2                                                 89.47
# 3                                                100.71
# 4                                                113.75
# ...                                                 ...
# 2883                                             182.07
# 2884                                             212.49
# 2885                                             199.68
# 2886                                             215.40
# 2887                                             226.21
#
#       Current health expenditure (CHE) per capita in US$  \
# 0                                                 15.80
# 1                                                 17.04
# 2                                                 20.41
# 3                                                 23.89
# 4                                                 27.84
# ...                                                 ...
# 2883                                             101.67
# 2884                                             116.71
# 2885                                             107.69
# 2886                                             112.41
# 2887                                             115.65
#
#       Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)  \
# 0                                                  9.44
# 1                                                  8.94
# 2                                                  9.81
# 3                                                  9.95
# 4                                                 10.62
# ...                                                 ...
# 2883                                               7.11
# 2884                                               8.13
# 2885                                               7.45
# 2886                                               7.68
# 2887                                               7.47
#
#       Domestic general government health expenditure (GGHE-D) per capita in PPP int$  \
# 0                                                  0.72
# 1                                                  6.00
# 2                                                  4.95
# 3                                                  5.36
# 4                                                  5.33
# ...                                                 ...
# 2883                                              51.68
# 2884                                              71.36
# 2885                                              41.57
# 2886                                              50.21
# 2887                                              54.33
#
#       Domestic general government health expenditure (GGHE-D) per capita in US$  \
# 0                                                  0.14
# 1                                                  1.24
# 2                                                  1.13
# 3                                                  1.27
# 4                                                  1.30
# ...                                                 ...
# 2883                                              28.86
# 2884                                              39.20
# 2885                                              22.42
# 2886                                              26.20
# 2887                                              27.78
#
#       Domestic general government health expenditure (GGHE-D) as percentage of current health expenditure (CHE) (%)  \
# 0                                                  0.89
# 1                                                  7.28
# 2                                                  5.54
# 3                                                  5.32
# 4                                                  4.69
# ...                                                 ...
# 2883                                              28.38
# 2884                                              33.58
# 2885                                              20.82
# 2886                                              23.31
# 2887                                              24.02
#
#       Domestic general government health expenditure (GGHE-D) as percentage of gross domestic product (GDP) (%)  \
# 0                                                  0.08
# 1                                                  0.65
# 2                                                  0.54
# 3                                                  0.53
# 4                                                  0.50
# ...                                                 ...
# 2883                                               2.02
# 2884                                               2.73
# 2885                                               1.55
# 2886                                               1.79
# 2887                                               1.79
#
#       Domestic general government health expenditure (GGHE-D) as percentage of general government expenditure (GGE) (%)  \
# 0                                                  1.21
# 1                                                  5.46
# 2                                                  3.60
# 3                                                  3.37
# 4                                                  2.72
# ...                                                 ...
# 2883                                               9.65
# 2884                                              13.36
# 2885                                               7.56
# 2886                                               7.56
# 2887                                               6.44
#
#       Out-of-pocket expenditure (OOP) per capita in PPP int$  \
# 0                                                 69.39
# 1                                                 70.97
# 2                                                 75.63
# 3                                                 79.53
# 4                                                 87.39
# ...                                                 ...
# 2883                                              54.18
# 2884                                              52.76
# 2885                                              51.49
# 2886                                              50.21
# 2887                                              51.59
#
#       Out-of-pocket expenditure (OOP) per capita in US$  \
# 0                                                 13.49
# 1                                                 14.66
# 2                                                 17.25
# 3                                                 18.87
# 4                                                 21.39
# ...                                                 ...
# 2883                                              30.25
# 2884                                              28.98
# 2885                                              27.77
# 2886                                              26.20
# 2887                                              26.37
#
#       Out-of-pocket expenditure as percentage of current health expenditure (CHE) (%)  \
# 0                                                 85.38
# 1                                                 86.07
# 2                                                 84.53
# 3                                                 78.97
# 4                                                 76.82
# ...                                                 ...
# 2883                                              29.76
# 2884                                              24.83
# 2885                                              25.79
# 2886                                              23.31
# 2887                                              22.81
#
#       Domestic private health expenditure (PVT-D) per capita in PPP int$  \
# 0                                                 69.39
# 1                                                 70.97
# 2                                                 75.63
# 3                                                 79.53
# 4                                                 87.39
# ...                                                 ...
# 2883                                              93.75
# 2884                                              98.15
# 2885                                             109.67
# 2886                                             105.08
# 2887                                             102.42
#
#       Domestic private health expenditure (PVT-D) per capita in US$  \
# 0                                                 13.49
# 1                                                 14.66
# 2                                                 17.25
# 3                                                 18.87
# 4                                                 21.39
# ...                                                 ...
# 2883                                              52.35
# 2884                                              53.91
# 2885                                              59.15
# 2886                                              54.84
# 2887                                              52.36
#
#       Domestic private health expenditure (PVT-D) as percentage of current health expenditure (CHE) (%)  \
# 0                                                 85.38
# 1                                                 86.07
# 2                                                 84.53
# 3                                                 78.97
# 4                                                 76.82
# ...                                                 ...
# 2883                                              51.49
# 2884                                              46.19
# 2885                                              54.93
# 2886                                              48.78
# 2887                                              45.28
#
#       Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)  \
# 0                                              90.06387
# 1                                              87.29221
# 2                                              84.55224
# 3                                              81.71863
# 4                                              78.91795
# ...                                                 ...
# 2883                                           49.41840
# 2884                                           47.44573
# 2885                                           46.55127
# 2886                                           45.12611
# 2887                                           44.18795
#
#       Under-five mortality rate (probability of dying by age 5 per 1000 live births)  \
# 0                                             125.00544
# 1                                             120.83735
# 2                                             116.57782
# 3                                             112.25100
# 4                                             107.98572
# ...                                                 ...
# 2883                                           71.38609
# 2884                                           67.79174
# 2885                                           66.31459
# 2886                                           63.56478
# 2887                                           61.91988
#
#       Deaths due to tuberculosis among HIV-negative people (per 100 000 population)  \
# 0                                                  57.0
# 1                                                  58.0
# 2                                                  51.0
# 3                                                  47.0
# 4                                                  43.0
# ...                                                 ...
# 2883                                                9.3
# 2884                                               10.0
# 2885                                                7.9
# 2886                                                8.6
# 2887                                                8.3
#
#       Incidence of tuberculosis (per 100 000 population per year)  \
# 0                                                 189.0
# 1                                                 189.0
# 2                                                 189.0
# 3                                                 189.0
# 4                                                 189.0
# ...                                                 ...
# 2883                                              304.0
# 2884                                              278.0
# 2885                                              242.0
# 2886                                              233.0
# 2887                                              221.0
#
#       Age-standardized suicide rates (per 100 000 population)  \
# 0                                                7.6900
# 1                                                7.7800
# 2                                                7.7700
# 3                                                7.7800
# 4                                                7.7500
# ...                                                 ...
# 2883                                            46.3784
# 2884                                            45.2645
# 2885                                            30.7352
# 2886                                            44.4823
# 2887                                            41.3055
#
#       Number of deaths  Deaths per 1 000 live births  \
# 0             5276.260                       5.03069
# 1             5423.343                       5.05688
# 2             5551.158                       5.07586
# 3             5601.079                       5.03886
# 4             5558.577                       4.93930
# ...                ...                           ...
# 2883          2324.449                       4.37248
# 2884          2189.076                       4.09614
# 2885          2081.309                       3.88761
# 2886          2042.850                       3.81916
# 2887          1850.952                       3.46815
#
#       Total NCD Deaths (in thousands)  \
# 0                            44342.73
# 1                            44521.91
# 2                            47583.46
# 3                            95631.12
# 4                            97079.55
# ...                               ...
# 2883                         26806.92
# 2884                         19505.89
# 2885                         26388.98
# 2886                         46639.99
# 2887                         25688.86
#
#       Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease  \
# 0                                              42.05954
# 1                                              40.13374
# 2                                              42.45138
# 3                                              40.04629
# 4                                              39.78164
# ...                                                 ...
# 2883                                           32.50861
# 2884                                           31.23827
# 2885                                           31.09062
# 2886                                           29.53635
# 2887                                           29.30200
#
#       Estimated number of road traffic deaths  \
# 0                                    733.7519
# 1                                   3556.0000
# 2                                   3757.0000
# 3                                   3891.0000
# 4                                   3101.3450
# ...                                       ...
# 2883                                3914.8810
# 2884                                1154.7830
# 2885                                4162.5460
# 2886                                5601.0000
# 2887                                5702.4520
#
#       Estimated road traffic death rate (per 100 000 population)  \
# 0                                              14.91542
# 1                                              22.57145
# 2                                              15.19411
# 3                                              15.16706
# 4                                              22.76401
# ...                                                 ...
# 2883                                           61.65923
# 2884                                           37.91205
# 2885                                           63.36865
# 2886                                           65.42435
# 2887                                           16.72851
#
#       Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)_x  \
# 0                                              0.007574
# 1                                              0.007574
# 2                                              0.007574
# 3                                              0.000840
# 4                                              0.007860
# ...                                                 ...
# 2883                                           4.110000
# 2884                                           4.220000
# 2885                                           3.840000
# 2886                                           3.760000
# 2887                                           3.820000
#
#       Mortality rate attributed to unintentional poisoning (per 100 000 population)  \
# 0                                               0.83120
# 1                                               4.20601
# 2                                               0.86953
# 3                                               0.79841
# 4                                               1.92925
# ...                                                 ...
# 2883                                            5.33527
# 2884                                            5.11943
# 2885                                            5.14483
# 2886                                            5.02317
# 2887                                            3.68102
#
#       Crude suicide rates (per 100 000 population)  \
# 0                                           5.3500
# 1                                           4.9500
# 2                                           5.3900
# 3                                           4.5400
# 4                                           4.4400
# ...                                            ...
# 2883                                       14.5466
# 2884                                       22.4379
# 2885                                       23.8332
# 2886                                       11.5503
# 2887                                        9.5900
#
#       Number of incident tuberculosis cases  \
# 0                                   40000.0
# 1                                   43000.0
# 2                                   44000.0
# 3                                   46000.0
# 4                                   48000.0
# ...                                     ...
# 2883                                41000.0
# 2884                                39000.0
# 2885                                34000.0
# 2886                                34000.0
# 2887                                33000.0
#
#       Number of deaths due to tuberculosis, excluding HIV  \
# 0                                               12000.0
# 1                                               13000.0
# 2                                               12000.0
# 3                                               11000.0
# 4                                               11000.0
# ...                                                 ...
# 2883                                             1300.0
# 2884                                             1500.0
# 2885                                             1100.0
# 2886                                             1200.0
# 2887                                             1200.0
#
#       Estimates of number of homicides  \
# 0                            2010.9130
# 1                            2137.9780
# 2                             330.4790
# 3                            2118.9150
# 4                            2500.9800
# ...                                ...
# 2883                         1809.1010
# 2884                          425.2974
# 2885                          431.2020
# 2886                         1896.0920
# 2887                          422.4477
#
#       Estimates of rates of homicides per 100 000 population  \
# 0                                              10.17557
# 1                                              10.40177
# 2                                              16.27195
# 3                                               2.80481
# 4                                               9.46156
# ...                                                 ...
# 2883                                           21.83616
# 2884                                           21.64277
# 2885                                           13.43061
# 2886                                            5.84840
# 2887                                            5.66318
#
#       Neonatal mortality rate (per 1000 live births)  \
# 0                                           58.47403
# 1                                           57.19492
# 2                                           55.93963
# 3                                           54.58337
# 4                                           53.18653
# ...                                              ...
# 2883                                        28.71256
# 2884                                        28.18007
# 2885                                        27.76433
# 2886                                        27.41742
# 2887                                        27.01455
#
#       Stillbirth rate (per 1000 total births)  \
# 0                                    35.98287
# 1                                    35.66648
# 2                                    35.32785
# 3                                    35.01817
# 4                                    34.56518
# ...                                       ...
# 2883                                 21.30467
# 2884                                 19.37633
# 2885                                 17.64418
# 2886                                 16.58867
# 2887                                 16.02393
#
#       Age-standardized NCD mortality rate  (per 100 000 population)  \
# 0                                             1081.2480
# 1                                             1066.8560
# 2                                             1019.6070
# 3                                             1027.3780
# 4                                             1004.6730
# ...                                                 ...
# 2883                                           810.2175
# 2884                                           804.2693
# 2885                                           889.5754
# 2886                                           782.6051
# ...
# ...                                                 ...
# 2883                                           81.73310
# 2884                                           83.07337
# 2885                                           84.33350
# 2886                                           84.76789
# 2887                                           85.04859
#
#       Number of women of reproductive age (aged 15-49 years) with anaemia (thousands)  \
# 0                                                1650.0
# 1                                                1740.0
# 2                                                1830.0
# 3                                                1920.0
# 4                                                1990.0
# ...                                                 ...
# 2883                                             1030.0
# 2884                                             1040.0
# 2885                                             1050.0
# 2886                                             1050.0
# 2887                                             1060.0
#
#       Number of children aged 6–59 months with anaemia (thousands)  \
# 0                                                2170.0
# 1                                                2190.0
# 2                                                2210.0
# 3                                                2230.0
# 4                                                2260.0
# ...                                                 ...
# 2883                                              971.0
# 2884                                              958.0
# 2885                                              941.0
# 2886                                              923.0
# 2887                                              892.0
#
#       Number of pregnant women (aged 15-49 years) with anaemia (thousands)  \
# 0                                                 297.0
# 1                                                 299.0
# 2                                                 301.0
# 3                                                 302.0
# 4                                                 302.0
# ...                                                 ...
# 2883                                               98.8
# 2884                                               97.2
# 2885                                               95.2
# 2886                                               93.0
# 2887                                               90.6
#
#       Prevalence of anaemia in children aged 6–59 months (%)  \
# 0                                                  48.3
# 1                                                  47.1
# 2                                                  46.2
# 3                                                  45.5
# 4                                                  44.9
# ...                                                 ...
# 2883                                               44.3
# 2884                                               42.8
# 2885                                               41.7
# 2886                                               40.5
# 2887                                               39.6
#
#       Prevalence of treatment (taking medicine) for hypertension among adults aged 30-79 with hypertension, crude  \
# 0                                                  20.5
# 1                                                  21.2
# 2                                                  22.0
# 3                                                  22.8
# 4                                                  23.6
# ...                                                 ...
# 2883                                               18.9
# 2884                                               19.6
# 2885                                               20.3
# 2886                                               21.0
# 2887                                               21.8
#
#       Mean total cholesterol,  age-standardized  \
# 0                                           4.3
# 1                                           4.3
# 2                                           4.3
# 3                                           4.2
# 4                                           4.2
# ...                                         ...
# 2883                                        4.1
# 2884                                        4.0
# 2885                                        4.0
# 2886                                        4.0
# 2887                                        4.0
#
#       Number of deaths among children ages 10 to 14 years  \
# 0                                                2744.0
# 1                                                2789.0
# 2                                                2851.0
# 3                                                2926.0
# 4                                                3037.0
# ...                                                 ...
# 2883                                             2609.0
# 2884                                             2743.0
# 2885                                             2896.0
# 2886                                             3040.0
# 2887                                             3172.0
#
#       Proportion of population with primary reliance on polluting fuels and technologies for cooking (%)  \
# 0                                                  62.6
# 1                                                  58.2
# 2                                                  53.3
# 3                                                  48.9
# 4                                                  44.1
# ...                                                 ...
# 2883                                               19.7
# 2884                                               20.3
# 2885                                               20.4
# 2886                                               20.7
# 2887                                               20.7
#
#       Prevalence of previous diagnosis of hypertension among adults aged 30-79 with hypertension, crude  \
# 0                                                  28.2
# 1                                                  28.9
# 2                                                  29.6
# 3                                                  30.3
# 4                                                  31.1
# ...                                                 ...
# 2883                                               28.5
# 2884                                               29.3
# 2885                                               30.2
# 2886                                               31.0
# 2887                                               31.9
#
#       Mean hemoglobin level of women of reproductive age (aged 15-49 years)  \
# 0                                                 123.0
# 1                                                 123.0
# 2                                                 123.0
# 3                                                 123.0
# 4                                                 123.0
# ...                                                 ...
# 2883                                              126.0
# 2884                                              126.0
# 2885                                              126.0
# 2886                                              126.0
# 2887                                              126.0
#
#       Number of deaths among children ages 5 to 9 years  \
# 0                                                4420.0
# 1                                                4532.0
# 2                                                4676.0
# 3                                                4821.0
# 4                                                5047.0
# ...                                                 ...
# 2883                                             2494.0
# 2884                                             2363.0
# 2885                                             2229.0
# 2886                                             2094.0
# 2887                                             1997.0
#
#       Mortality rate among children ages 10 to 14 years (per 1000 children aged 10)  \
# 0                                               4.67688
# 1                                               4.55469
# 2                                               4.47444
# 3                                               4.43099
# 4                                               4.44194
# ...                                                 ...
# 2883                                            8.04556
# 2884                                            8.32632
# 2885                                            8.60679
# 2886                                            8.84993
# 2887                                            8.99209
#
#       Mean Non-HDL cholesterol, age-standardized  \
# 0                                            3.1
# 1                                            3.1
# 2                                            3.1
# 3                                            3.1
# 4                                            3.1
# ...                                          ...
# 2883                                         2.9
# 2884                                         2.9
# 2885                                         2.9
# 2886                                         2.9
# 2887                                         2.8
#
#       Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)  \
# 0                                                1360.0
# 1                                                1440.0
# 2                                                1530.0
# 3                                                1620.0
# 4                                                1690.0
# ...                                                 ...
# 2883                                              934.0
# 2884                                              941.0
# 2885                                              950.0
# 2886                                              959.0
# 2887                                              971.0
#
#       Prevalence of anaemia in pregnant women (aged 15-49) (%)  \
# 0                                                  43.4
# 1                                                  42.9
# 2                                                  42.4
# 3                                                  41.9
# 4                                                  41.4
# ...                                                 ...
# 2883                                               32.9
# 2884                                               32.7
# 2885                                               32.4
# 2886                                               32.2
# 2887                                               32.0
#
#       Mean hemoglobin level of non-pregnant women (aged 15-49 years)  num_nan
# 0                                                 125.0                     1
# 1                                                 124.0                     1
# 2                                                 124.0                     1
# 3                                                 124.0                     0
# 4                                                 124.0                     0
# ...                                                 ...                   ...
# 2883                                              127.0                     0
# 2884                                              127.0                     0
# 2885                                              127.0                     0
# 2886                                              127.0                     0
# 2887                                              127.0                     0
#
# [2888 rows x 109 columns]

# %%
menlist = ["Measles-containing-vaccine first-dose (MCV1) immunization coverage among 1-year-olds (%)",]

# %%
data1.columns[:70]
# Out:
# Index(['per_capita-Meningitis',
#        'per_capita-Alzheimer's Disease and Other Dementias',
#        'per_capita-Parkinson's Disease', 'per_capita-Nutritional Deficiencies',
#        'per_capita-Malaria', 'per_capita-Drowning',
#        'per_capita-Interpersonal Violence', 'per_capita-Maternal Disorders',
#        'per_capita-HIV/AIDS', 'per_capita-Drug Use Disorders',
#        'per_capita-Tuberculosis', 'per_capita-Cardiovascular Diseases',
#        'per_capita-Lower Respiratory Infections',
#        'per_capita-Neonatal Disorders', 'per_capita-Alcohol Use Disorders',
#        'per_capita-Self-harm', 'per_capita-Exposure to Forces of Nature',
#        'per_capita-Diarrheal Diseases',
#        'per_capita-Environmental Heat and Cold Exposure',
#        'per_capita-Neoplasms', 'per_capita-Conflict and Terrorism',
#        'per_capita-Diabetes Mellitus', 'per_capita-Chronic Kidney Disease',
#        'per_capita-Poisonings', 'per_capita-Protein-Energy Malnutrition',
#        'per_capita-Road Injuries', 'per_capita-Chronic Respiratory Diseases',
#        'per_capita-Cirrhosis and Other Chronic Liver Diseases',
#        'per_capita-Digestive Diseases',
#        'per_capita-Fire, Heat, and Hot Substances',
#        'per_capita-Acute Hepatitis', 'gdp', 'gdp/percap',
#        'Mortality rate for 5-14 year-olds (probability of dying per 1000 children aged 5-14 years)',
#        'Number of under-five deaths', 'Number of infant deaths',
#        'Number of neonatal deaths',
#        'Current health expenditure (CHE) per capita in PPP int$',
#        'Current health expenditure (CHE) per capita in US$',
#        'Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)',
#        'Domestic general government health expenditure (GGHE-D) per capita in PPP int$',
#        'Domestic general government health expenditure (GGHE-D) per capita in US$',
#        'Domestic general government health expenditure (GGHE-D) as percentage of current health expenditure (CHE) (%)',
#        'Domestic general government health expenditure (GGHE-D) as percentage of gross domestic product (GDP) (%)',
#        'Domestic general government health expenditure (GGHE-D) as percentage of general government expenditure (GGE) (%)',
#        'Out-of-pocket expenditure (OOP) per capita in PPP int$',
#        'Out-of-pocket expenditure (OOP) per capita in US$',
#        'Out-of-pocket expenditure as percentage of current health expenditure (CHE) (%)',
#        'Domestic private health expenditure (PVT-D) per capita in PPP int$',
#        'Domestic private health expenditure (PVT-D) per capita in US$',
#        'Domestic private health expenditure (PVT-D) as percentage of current health expenditure (CHE) (%)',
#        'Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)',
#        'Under-five mortality rate (probability of dying by age 5 per 1000 live births)',
#        'Deaths due to tuberculosis among HIV-negative people (per 100 000 population)',
#        'Incidence of tuberculosis (per 100 000 population per year)',
#        'Age-standardized suicide rates (per 100 000 population)',
#        'Number of deaths', 'Deaths per 1 000 live births',
#        'Total NCD Deaths (in thousands)',
#        'Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease',
#        'Estimated number of road traffic deaths',
#        'Estimated road traffic death rate (per 100 000 population)',
#        'Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)_x',
#        'Mortality rate attributed to unintentional poisoning (per 100 000 population)',
#        'Crude suicide rates (per 100 000 population)',
#        'Number of incident tuberculosis cases',
#        'Number of deaths due to tuberculosis, excluding HIV',
#        'Estimates of number of homicides',
#        'Estimates of rates of homicides per 100 000 population',
#        'Neonatal mortality rate (per 1000 live births)'],
#       dtype='object')

# %%
target_alz=data1.drop("per_capita-Alzheimer's Disease and Other Dementias", axis=1).apply(lambda x: x.corr(data1["per_capita-Alzheimer's Disease and Other Dementias"]))

# %%
type(target_alz)
# Out:
# pandas.core.series.Series

# %%
target_alz
# Out:
# per_capita-Meningitis                                                      -0.390116
# per_capita-Parkinson's Disease                                              0.932980
# per_capita-Nutritional Deficiencies                                        -0.374382
# per_capita-Malaria                                                         -0.309720
# per_capita-Drowning                                                        -0.303619
#                                                                               ...
# Mean Non-HDL cholesterol, age-standardized                                  0.460414
# Number of non-pregnant women (aged 15-49 years) with anaemia (thousands)   -0.083260
# Prevalence of anaemia in pregnant women (aged 15-49) (%)                   -0.667108
# Mean hemoglobin level of non-pregnant women (aged 15-49 years)              0.586157
# num_nan                                                                     0.025158
# Length: 108, dtype: float64

# %%
import pandas as pd
from pandas.plotting import scatter_matrix

import statsmodels.api as sm
from statsmodels.formula.api import ols

import xgboost as xgb

from hyperopt import fmin, hp, tpe, Trials, space_eval, STATUS_OK

from sklearn.metrics import mean_squared_error as mse
from sklearn.model_selection import train_test_split as tts
